# %%
import pandas as pd
import os

# %%
tx_file = pd.read_csv("./tx_2022_gen_vtd/tx_2022_gen_vtd.csv")
tx_names = pd.read_csv("./field_names.csv")
print(tx_names)
tx_names["Clean"] = tx_names["0"].apply(lambda x: x.split("-:-")[-1] + " ("+x.split("-:-")[-2]+") "+x.split("-:-")[-3])
# Out:
#                                                0           1
# 0           Election-:-2022-:-Ag Comm-:-D-:-Hays  G22AGRDHAY
# 1         Election-:-2022-:-Ag Comm-:-R-:-Miller  G22AGRRMIL
# 2     Election-:-2022-:-Attorney Gen-:-D-:-Garza  G22ATGDGAR
# 3       Election-:-2022-:-Attorney Gen-:-L-:-Ash  G22ATGLASH
# 4    Election-:-2022-:-Attorney Gen-:-R-:-Paxton  G22ATGRPAX
# ..                                           ...         ...
# 361     Election-:-2022-:-U.S. Rep 8-:-D-:-Jones  GCON08DJON
# 362   Election-:-2022-:-U.S. Rep 8-:-L-:-Eriksen  GCON08LERI
# 363  Election-:-2022-:-U.S. Rep 8-:-R-:-Luttrell  GCON08RLUT
# 364     Election-:-2022-:-U.S. Rep 9-:-D-:-Green  GCON09DGRE
# 365      Election-:-2022-:-U.S. Rep 9-:-R-:-Leon  GCON09RLEO
#
# [366 rows x 2 columns]

# %%
tx_names["Clean"]
# Out:
# 0             Hays (D) Ag Comm
# 1           Miller (R) Ag Comm
# 2       Garza (D) Attorney Gen
# 3         Ash (L) Attorney Gen
# 4      Paxton (R) Attorney Gen
#                 ...
# 361       Jones (D) U.S. Rep 8
# 362     Eriksen (L) U.S. Rep 8
# 363    Luttrell (R) U.S. Rep 8
# 364       Green (D) U.S. Rep 9
# 365        Leon (R) U.S. Rep 9
# Name: Clean, Length: 366, dtype: object

# %%
fields_dict = dict(zip(tx_names["1"], tx_names["Clean"]))
myKeys = list(fields_dict.keys())
myKeys.sort()
fields_dict = {i: fields_dict[i] for i in myKeys}

# %%
fields_dict
# Out:
# {'G22AGRDHAY': 'Hays (D) Ag Comm',
#  'G22AGRRMIL': 'Miller (R) Ag Comm',
#  'G22ATGDGAR': 'Garza (D) Attorney Gen',
#  'G22ATGLASH': 'Ash (L) Attorney Gen',
#  'G22ATGRPAX': 'Paxton (R) Attorney Gen',
#  'G22COMDDUD': 'Dudding (D) Comptroller',
#  'G22COMLECH': 'Echevarria-Garza (L) Comptroller',
#  'G22COMRHEG': 'Hegar (R) Comptroller',
#  "G22GOVDO'R": "O'Rourke (D) Governor",
#  'G22GOVGBAR': 'Barrios (G) Governor',
#  'G22GOVLTIP': 'Tippetts (L) Governor',
#  'G22GOVOWRI': 'Write-In (W) Governor',
#  'G22GOVRABB': 'Abbott (R) Governor',
#  'G22LANDKLE': 'Kleberg (D) Land Comm',
#  'G22LANGMOL': 'Molison (G) Land Comm',
#  'G22LANOMEN': 'Menger (W) Land Comm',
#  'G22LANRBUC': 'Buckingham (R) Land Comm',
#  'G22LTGDCOL': 'Collier (D) Lt. Governor',
#  'G22LTGLSTE': 'Steele (L) Lt. Governor',
#  'G22LTGRPAT': 'Patrick (R) Lt. Governor',
#  'GCCA05DHUF': 'Huffman (D) CCA 5',
#  'GCCA05RWAL': 'Walker (R) CCA 5',
#  'GCCA06DJOH': 'Johnson (D) CCA 6',
#  'GCCA06RMCC': 'McClure (R) CCA 6',
#  'GCON01DJEF': 'Jefferson (D) U.S. Rep 1',
#  'GCON01RMOR': 'Moran (R) U.S. Rep 1',
#  'GCON02DFUL': 'Fulford (D) U.S. Rep 2',
#  'GCON02RCRE': 'Crenshaw (R) U.S. Rep 2',
#  'GCON03DSRI': 'Srivastava (D) U.S. Rep 3',
#  'GCON03LCLA': 'Claytor (L) U.S. Rep 3',
#  'GCON03RSEL': 'Self (R) U.S. Rep 3',
#  'GCON04DOME': 'Omere (D) U.S. Rep 4',
#  'GCON04LSIM': 'Simmons (L) U.S. Rep 4',
#  'GCON04RFAL': 'Fallon (R) U.S. Rep 4',
#  'GCON05DHIL': 'Hill (D) U.S. Rep 5',
#  'GCON05LHAL': 'Hale (L) U.S. Rep 5',
#  'GCON05OTOR': 'Torres (W) U.S. Rep 5',
#  'GCON05RGOO': 'Gooden (R) U.S. Rep 5',
#  'GCON07DFLE': 'Fletcher (D) U.S. Rep 7',
#  'GCON07RTEA': 'Teague (R) U.S. Rep 7',
#  'GCON08DJON': 'Jones (D) U.S. Rep 8',
#  'GCON08LERI': 'Eriksen (L) U.S. Rep 8',
#  'GCON08RLUT': 'Luttrell (R) U.S. Rep 8',
#  'GCON09DGRE': 'Green (D) U.S. Rep 9',
#  'GCON09RLEO': 'Leon (R) U.S. Rep 9',
#  'GCON10DNUN': 'Nuno (D) U.S. Rep 10',
#  'GCON10LKEL': 'Kelsey (L) U.S. Rep 10',
#  'GCON10RMCC': 'McCaul (R) U.S. Rep 10',
#  'GCON12DHUN': 'Hunt (D) U.S. Rep 12',
#  'GCON12RGRA': 'Granger (R) U.S. Rep 12',
#  'GCON13DBRO': 'Brown (D) U.S. Rep 13',
#  'GCON13RJAC': 'Jackson (R) U.S. Rep 13',
#  'GCON14DWIL': 'Williams (D) U.S. Rep 14',
#  'GCON14RWEB': 'Weber (R) U.S. Rep 14',
#  'GCON15DVAL': 'Vallejo (D) U.S. Rep 15',
#  'GCON15LLEO': 'Leone (L) U.S. Rep 15',
#  'GCON15RDEL': 'De La Cruz (R) U.S. Rep 15',
#  'GCON16DESC': 'Escobar (D) U.S. Rep 16',
#  'GCON16RARM': 'Armendariz-Jackson (R) U.S. Rep 16',
#  'GCON17DWOO': 'Woods (D) U.S. Rep 17',
#  'GCON17RSES': 'Sessions (R) U.S. Rep 17',
#  'GCON18DJAC': 'Jackson Lee (D) U.S. Rep 18',
#  'GCON18IDUN': 'Duncan (I) U.S. Rep 18',
#  'GCON18LKUR': 'Kurtz (L) U.S. Rep 18',
#  'GCON18RMON': 'Montiel (R) U.S. Rep 18',
#  'GCON19ILEW': 'Lewis (I) U.S. Rep 19',
#  'GCON19RARR': 'Arrington (R) U.S. Rep 19',
#  'GCON20DCAS': 'Castro (D) U.S. Rep 20',
#  'GCON20OJON': 'Jonasz (W) U.S. Rep 20',
#  'GCON20RSIN': 'Sinclair (R) U.S. Rep 20',
#  'GCON21DZAP': 'Zapata (D) U.S. Rep 21',
#  'GCON21RROY': 'Roy (R) U.S. Rep 21',
#  'GCON22DJOR': 'Jordan (D) U.S. Rep 22',
#  'GCON22LLEB': 'LeBlanc (L) U.S. Rep 22',
#  'GCON22OSQU': 'Squires (W) U.S. Rep 22',
#  'GCON22RNEH': 'Nehls (R) U.S. Rep 22',
#  'GCON23DLIR': 'Lira (D) U.S. Rep 23',
#  'GCON23ILOP': 'Lopez (I) U.S. Rep 23',
#  'GCON23RGON': 'Gonzales (R) U.S. Rep 23',
#  'GCON24DMCD': 'McDowell (D) U.S. Rep 24',
#  'GCON24RVAN': 'Van Duyne (R) U.S. Rep 24',
#  'GCON26LKOL': 'Kolls (L) U.S. Rep 26',
#  'GCON26RBUR': 'Burgess (R) U.S. Rep 26',
#  'GCON27DPER': 'Perez (D) U.S. Rep 27',
#  'GCON27RCLO': 'Cloud (R) U.S. Rep 27',
#  'GCON28DCUE': 'Cuellar (D) U.S. Rep 28',
#  'GCON28RGAR': 'Garcia (R) U.S. Rep 28',
#  'GCON29DGAR': 'Garcia (D) U.S. Rep 29',
#  'GCON29RSCH': 'Schafranek (R) U.S. Rep 29',
#  'GCON30DCRO': 'Crockett (D) U.S. Rep 30',
#  'GCON30IMAN': 'Manning (I) U.S. Rep 30',
#  'GCON30LGRA': 'Gray (L) U.S. Rep 30',
#  'GCON30OWAL': 'Walker (W) U.S. Rep 30',
#  'GCON30RROD': 'Rodgers (R) U.S. Rep 30',
#  'GCON32DALL': 'Allred (D) U.S. Rep 32',
#  'GCON32RSWA': 'Swad (R) U.S. Rep 32',
#  'GCON33DVEA': 'Veasey (D) U.S. Rep 33',
#  'GCON33LASH': 'Ashby (L) U.S. Rep 33',
#  'GCON33RGIL': 'Gillespie (R) U.S. Rep 33',
#  'GCON34DGON': 'Gonzalez (D) U.S. Rep 34',
#  'GCON34IROY': 'Royal (I) U.S. Rep 34',
#  'GCON34RFLO': 'Flores (R) U.S. Rep 34',
#  'GCON35DCAS': 'Casar (D) U.S. Rep 35',
#  'GCON35RMCQ': 'McQueen (R) U.S. Rep 35',
#  'GCON36DHAI': 'Haire (D) U.S. Rep 36',
#  'GCON36RBAB': 'Babin (R) U.S. Rep 36',
#  'GCON37DDOG': 'Doggett (D) U.S. Rep 37',
#  'GCON37LPAT': 'Patterson (L) U.S. Rep 37',
#  'GCON37OTAY': 'Taylor (W) U.S. Rep 37',
#  'GCON37RGAR': 'Garcia Sharon (R) U.S. Rep 37',
#  'GCON38DKLU': 'Klussmann (D) U.S. Rep 38',
#  'GCON38IDEJ': 'Dejean (I) U.S. Rep 38',
#  'GCON38RHUN': 'Hunt (R) U.S. Rep 38',
#  'GRRC01DWAR': 'Warford (D) RR Comm 1',
#  'GRRC01GCRO': 'Crow (G) RR Comm 1',
#  'GRRC01LDIE': 'Diez (L) RR Comm 1',
#  'GRRC01RCHR': 'Christian (R) RR Comm 1',
#  'GSL004LSAV': 'Savino (L) State Rep 4',
#  'GSL004RBEL': 'Bell (R) State Rep 4',
#  'GSL006DGRA': 'Grace (D) State Rep 6',
#  'GSL006RSCH': 'Schaefer (R) State Rep 6',
#  'GSL008LADA': 'Adams (L) State Rep 8',
#  'GSL008RHAR': 'Harris (R) State Rep 8',
#  'GSL009DROG': 'Rogers (D) State Rep 9',
#  'GSL009RASH': 'Ashby (R) State Rep 9',
#  'GSL013DDAV': 'Davis (D) State Rep 13',
#  'GSL013RORR': 'Orr (R) State Rep 13',
#  'GSL014LMIL': 'Miller (L) State Rep 14',
#  'GSL014RRAN': 'Raney (R) State Rep 14',
#  'GSL015DJOH': 'Johnson (D) State Rep 15',
#  'GSL015RTOT': 'Toth (R) State Rep 15',
#  'GSL017DEDE': 'Eden (D) State Rep 17',
#  'GSL017ICUR': 'Curtis (I) State Rep 17',
#  'GSL017RGER': 'Gerdes (R) State Rep 17',
#  'GSL019DBAG': 'Baggett (D) State Rep 19',
#  'GSL019RTRO': 'Troxclair (R) State Rep 19',
#  'GSL020DCAM': 'Camacho (D) State Rep 20',
#  'GSL020RWIL': 'Wilson (R) State Rep 20',
#  'GSL022DHAY': 'Hayes (D) State Rep 22',
#  'GSL022RRAN': 'Randle (R) State Rep 22',
#  'GSL023DHEN': 'Henry (D) State Rep 23',
#  'GSL023RLEO': 'Leo-Wilson (R) State Rep 23',
#  'GSL024DCRE': 'Creedon (D) State Rep 24',
#  'GSL024LMCC': 'McCamy (L) State Rep 24',
#  'GSL024RBON': 'Bonnen (R) State Rep 24',
#  'GSL026DLEE': 'Lee (D) State Rep 26',
#  'GSL026RJET': 'Jetton (R) State Rep 26',
#  'GSL027DREY': 'Reynolds (D) State Rep 27',
#  'GSL027RGIL': 'Gilani (R) State Rep 27',
#  'GSL028DADR': 'Adriatico (D) State Rep 28',
#  'GSL028RGAT': 'Gates (R) State Rep 28',
#  'GSL031DGUT': 'Gutierrez (D) State Rep 31',
#  'GSL031RGUI': 'Guillen (R) State Rep 31',
#  'GSL033DLYN': 'Lynskey (D) State Rep 33',
#  'GSL033RHOL': 'Holland (R) State Rep 33',
#  'GSL034DHER': 'Herrero (D) State Rep 34',
#  'GSL034RVAU': 'Vaughn (R) State Rep 34',
#  'GSL035DLON': 'Longoria (D) State Rep 35',
#  'GSL035RROS': 'Rosa (R) State Rep 35',
#  'GSL037DVIL': 'Villarreal (D) State Rep 37',
#  'GSL037RLOP': 'Lopez (R) State Rep 37',
#  'GSL039DMAR': 'Martinez (D) State Rep 39',
#  'GSL039RGAR': 'Garcia (R) State Rep 39',
#  'GSL041DGUE': 'Guerra (D) State Rep 41',
#  'GSL041RGUE': 'Guerra (R) State Rep 41',
#  'GSL042DRAY': 'Raymond (D) State Rep 42',
#  'GSL042RBRE': 'Brennan (R) State Rep 42',
#  'GSL044DBOH': 'Bohmfalk (D) State Rep 44',
#  'GSL044RKUE': 'Kuempel (R) State Rep 44',
#  'GSL045DZWI': 'Zwiener (D) State Rep 45',
#  'GSL045RLOP': 'Lopez (R) State Rep 45',
#  'GSL046DCOL': 'Cole (D) State Rep 46',
#  'GSL046LKOS': 'Kost (L) State Rep 46',
#  'GSL046RSTR': 'Strasser (R) State Rep 46',
#  'GSL047DGOO': 'Goodwin (D) State Rep 47',
#  'GSL047RMCC': 'McCarthy (R) State Rep 47',
#  'GSL048DHOW': 'Howard (D) State Rep 48',
#  'GSL048LMCC': 'McCarthy (L) State Rep 48',
#  'GSL049DHIN': 'Hinojosa (D) State Rep 49',
#  'GSL049LROB': 'Roberson (L) State Rep 49',
#  'GSL049RGRI': 'Griffin (R) State Rep 49',
#  'GSL050DTAL': 'Talarico (D) State Rep 50',
#  'GSL050LBRO': 'Brown (L) State Rep 50',
#  'GSL050RJOH': 'Johnson (R) State Rep 50',
#  'GSL051DFLO': 'Flores (D) State Rep 51',
#  'GSL051RREY': 'Reynolds (R) State Rep 51',
#  'GSL052DECH': 'Echegaray (D) State Rep 52',
#  'GSL052RHAR': 'Harris (R) State Rep 52',
#  'GSL053DHER': 'Herrera (D) State Rep 53',
#  'GSL053RMUR': 'Murr (R) State Rep 53',
#  'GSL054DHIL': 'Hildner (D) State Rep 54',
#  'GSL054RBUC': 'Buckley (R) State Rep 54',
#  'GSL055DSAN': 'Sanders (D) State Rep 55',
#  'GSL055RSHI': 'Shine (R) State Rep 55',
#  'GSL056DSHA': 'Shank (D) State Rep 56',
#  'GSL056RAND': 'Anderson (R) State Rep 56',
#  'GSL057LHAM': 'Hamilton (L) State Rep 57',
#  'GSL057RHAY': 'Hayes (R) State Rep 57',
#  'GSL061DKIN': 'King (D) State Rep 61',
#  'GSL061RFRA': 'Frazier (R) State Rep 61',
#  'GSL063DWOO': 'Wooten (D) State Rep 63',
#  'GSL063RBUM': 'Bumgarner (R) State Rep 63',
#  'GSL065DVER': 'Verdell (D) State Rep 65',
#  'GSL065RTHI': 'Thimesch (R) State Rep 65',
#  'GSL066DRIN': 'Ringness (D) State Rep 66',
#  'GSL066RSHA': 'Shaheen (R) State Rep 66',
#  'GSL067DMOR': 'Morris (D) State Rep 67',
#  'GSL067RLEA': 'Leach (R) State Rep 67',
#  'GSL069DCOP': 'Coppage (D) State Rep 69',
#  'GSL069LNEU': 'Neumann (L) State Rep 69',
#  'GSL069RFRA': 'Frank (R) State Rep 69',
#  'GSL070DPLE': 'Plesa (D) State Rep 70',
#  'GSL070RJOL': 'Jolly (R) State Rep 70',
#  'GSL071DGOO': 'Goolsbee (D) State Rep 71',
#  'GSL071RLAM': 'Lambert (R) State Rep 71',
#  'GSL073DCAL': 'Calhoun (D) State Rep 73',
#  'GSL073RISA': 'Isaac (R) State Rep 73',
#  'GSL074DMOR': 'Morales (D) State Rep 74',
#  'GSL074RPAR': 'Parker (R) State Rep 74',
#  'GSL075DGON': 'Gonzalez (D) State Rep 75',
#  'GSL075LMUL': 'Mullins (L) State Rep 75',
#  'GSL076DLAL': 'Lalani (D) State Rep 76',
#  'GSL076RMAT': 'Mathews (R) State Rep 76',
#  'GSL085DBAG': 'Baggett (D) State Rep 85',
#  'GSL085LMIL': 'Miller (L) State Rep 85',
#  'GSL085RKIT': 'Kitzman (R) State Rep 85',
#  'GSL087LHEA': 'Hearn (L) State Rep 87',
#  'GSL087RPRI': 'Price (R) State Rep 87',
#  'GSL092DBHO': 'Bhojani (D) State Rep 92',
#  'GSL092RLIV': 'Livingston (R) State Rep 92',
#  'GSL093DCHO': 'Chowdhury (D) State Rep 93',
#  'GSL093RSCH': 'Schatzline (R) State Rep 93',
#  'GSL094DSHE': 'Sherrard (D) State Rep 94',
#  'GSL094RTIN': 'Tinderholt (R) State Rep 94',
#  'GSL095DCOL': 'Collier (D) State Rep 95',
#  'GSL095RMON': 'Mondick (R) State Rep 95',
#  'GSL097DMCL': 'McLaurin (D) State Rep 97',
#  'GSL097RGOL': 'Goldman (R) State Rep 97',
#  'GSL098DELK': 'Elkins (D) State Rep 98',
#  'GSL098RCAP': 'Capriglione (R) State Rep 98',
#  'GSL099DCOF': 'Coffey (D) State Rep 99',
#  'GSL099RGER': 'Geren (R) State Rep 99',
#  'GSL100DJON': 'Jones (D) State Rep 100',
#  'GSL100LROB': 'Roberts (L) State Rep 100',
#  'GSL102DRAM': 'Ramos (D) State Rep 102',
#  'GSL102RFIS': 'Fischer (R) State Rep 102',
#  'GSL103DANC': 'Anchia (D) State Rep 103',
#  'GSL103IARR': 'Arrieta (I) State Rep 103',
#  'GSL105DMEZ': 'Meza (D) State Rep 105',
#  'GSL105RMEA': 'Meagher (R) State Rep 105',
#  'GSL107DNEA': 'Neave (D) State Rep 107',
#  'GSL107LNEW': 'Newsom (L) State Rep 107',
#  'GSL108DGIN': 'Ginsberg (D) State Rep 108',
#  'GSL108RMEY': 'Meyer (R) State Rep 108',
#  'GSL111DDAV': 'Davis (D) State Rep 111',
#  'GSL111RFLO': 'Flores Yrigollen (R) State Rep 111',
#  'GSL112DCUR': 'Curl (D) State Rep 112',
#  'GSL112RBUT': 'Button (R) State Rep 112',
#  'GSL114DBRY': 'Bryant (D) State Rep 114',
#  'GSL114RLAM': 'Lamb (R) State Rep 114',
#  'GSL115DJOH': 'Johnson (D) State Rep 115',
#  'GSL115RDEN': 'Denis (R) State Rep 115',
#  'GSL117DCOR': 'Cortez (D) State Rep 117',
#  'GSL117RSCH': 'Schwope (R) State Rep 117',
#  'GSL118DRAM': 'Ramirez (D) State Rep 118',
#  'GSL118RLUJ': 'Lujan (R) State Rep 118',
#  'GSL119DCAM': 'Campos (D) State Rep 119',
#  'GSL119LTHO': 'Thomas (L) State Rep 119',
#  'GSL120DGER': 'Gervin-Hawkins (D) State Rep 120',
#  'GSL120RPAY': 'Payne (R) State Rep 120',
#  'GSL121DMOY': 'Moyer DeFelice (D) State Rep 121',
#  'GSL121RALL': 'Allison (R) State Rep 121',
#  'GSL122DARA': 'Aramburu (D) State Rep 122',
#  'GSL122LBER': 'Berlin (L) State Rep 122',
#  'GSL122RDOR': 'Dorazio (R) State Rep 122',
#  'GSL123DBER': 'Bernal (D) State Rep 123',
#  'GSL123RVAL': 'Valdez (R) State Rep 123',
#  'GSL124DGAR': 'Garcia (D) State Rep 124',
#  'GSL124RARR': 'Arredondo (R) State Rep 124',
#  'GSL125DLOP': 'Lopez (D) State Rep 125',
#  'GSL125RRAY': 'Raymond (R) State Rep 125',
#  'GSL128DCRE': 'Crews (D) State Rep 128',
#  'GSL128RCAI': 'Cain (R) State Rep 128',
#  'GSL129DMAR': 'Marvel (D) State Rep 129',
#  'GSL129RPAU': 'Paul (R) State Rep 129',
#  'GSL131DALL': 'Allen (D) State Rep 131',
#  'GSL131RMON': 'Monroe (R) State Rep 131',
#  'GSL132DCAM': 'Campbell (D) State Rep 132',
#  'GSL132RSCH': 'Schofield (R) State Rep 132',
#  'GSL133DMAA': 'Maarouf (D) State Rep 133',
#  'GSL133LHAR': 'Harren (L) State Rep 133',
#  'GSL133RDEA': 'DeAyala (R) State Rep 133',
#  'GSL134DJOH': 'Johnson (D) State Rep 134',
#  'GSL134LUNS': 'Unsicker (L) State Rep 134',
#  'GSL134RMCC': 'McConnico (R) State Rep 134',
#  'GSL135DROS': 'Rosenthal (D) State Rep 135',
#  'GSL135RMAY': 'May (R) State Rep 135',
#  'GSL136DBUC': 'Bucy (D) State Rep 136',
#  'GSL136LCUL': 'Culley (L) State Rep 136',
#  'GSL136REVA': 'Evans (R) State Rep 136',
#  'GSL137DWU': 'Wu (D) State Rep 137',
#  'GSL137LSHA': 'Sharp (L) State Rep 137',
#  'GSL138DMOR': 'Morales (D) State Rep 138',
#  'GSL138RHUL': 'Hull (R) State Rep 138',
#  'GSL145DMOR': 'Morales (D) State Rep 145',
#  'GSL145RMAB': 'Mabry (R) State Rep 145',
#  'GSL148DMOR': 'Morales Shaw (D) State Rep 148',
#  'GSL148LTRO': 'Trojacek (L) State Rep 148',
#  'GSL148RSMI': 'Smith (R) State Rep 148',
#  'GSL149DVO': 'Vo (D) State Rep 149',
#  'GSL149LBOG': 'Bogue (L) State Rep 149',
#  'GSL149RTRU': 'Truong (R) State Rep 149',
#  'GSL150DBRO': 'Brown Daniel (D) State Rep 150',
#  'GSL150RSWA': 'Swanson (R) State Rep 150',
#  'GSSC03DNOW': 'Nowell (D) Sup Ct 3',
#  'GSSC03LOXF': 'Oxford (L) Sup Ct 3',
#  'GSSC03RLEH': 'Lehrmann (R) Sup Ct 3',
#  'GSSC05DREI': 'Reichek (D) Sup Ct 5',
#  'GSSC05RHUD': 'Huddle (R) Sup Ct 5',
#  'GSSC09DMAL': 'Maldonado (D) Sup Ct 9',
#  'GSSC09RYOU': 'Young (R) Sup Ct 9',
#  'GSU02DGIA': 'Giadolor (D) State Sen 2',
#  'GSU02RHAL': 'Hall (R) State Sen 2',
#  'GSU03DRUS': 'Russell (D) State Sen 3',
#  'GSU03LLIN': 'Lindsey (L) State Sen 3',
#  'GSU03RNIC': 'Nichols (R) State Sen 3',
#  'GSU04DBIS': 'Bishop (D) State Sen 4',
#  'GSU04RCRE': 'Creighton (R) State Sen 4',
#  'GSU05LEST': 'Estes (L) State Sen 5',
#  'GSU05RSCH': 'Schwertner (R) State Sen 5',
#  'GSU08DCOC': 'Cocks (D) State Sen 8',
#  'GSU08LKLE': 'Kless (L) State Sen 8',
#  'GSU08RPAX': 'Paxton (R) State Sen 8',
#  'GSU09DBUR': 'Burud (D) State Sen 9',
#  'GSU09RHAN': 'Hancock (R) State Sen 9',
#  'GSU12DLY': 'Ly (D) State Sen 12',
#  'GSU12RPAR': 'Parker (R) State Sen 12',
#  'GSU14DECK': 'Eckhardt (D) State Sen 14',
#  'GSU14LHAS': 'Haskett (L) State Sen 14',
#  'GSU15DWHI': 'Whitmire (D) State Sen 15',
#  'GSU15RVAC': 'Vachris (R) State Sen 15',
#  'GSU16DJOH': 'Johnson (D) State Sen 16',
#  'GSU16RCOP': 'Copeland (R) State Sen 16',
#  'GSU17DBEN': 'Benton (D) State Sen 17',
#  'GSU17RHUF': 'Huffman (R) State Sen 17',
#  'GSU18DTUT': 'Tutt (D) State Sen 18',
#  'GSU18RKOL': 'Kolkhorst (R) State Sen 18',
#  'GSU19DGUT': 'Gutierrez (D) State Sen 19',
#  'GSU19RGAR': 'Garza (R) State Sen 19',
#  'GSU20DHIN': 'Hinojosa (D) State Sen 20',
#  'GSU20RWRI': 'Wright (R) State Sen 20',
#  'GSU21DZAF': 'Zaffirini (D) State Sen 21',
#  'GSU21LDIB': 'DiBianca (L) State Sen 21',
#  'GSU21RDAH': 'Dahlberg (R) State Sen 21',
#  'GSU22LSCH': 'Schroppel (L) State Sen 22',
#  'GSU22RBIR': 'Birdwell (R) State Sen 22',
#  'GSU24DJON': 'Jones-Hospod (D) State Sen 24',
#  'GSU24RFLO': 'Flores (R) State Sen 24',
#  'GSU25DWAL': 'Walsh (D) State Sen 25',
#  'GSU25RCAM': 'Campbell (R) State Sen 25',
#  'GSU26DMEN': 'Menendez (D) State Sen 26',
#  'GSU26RMUR': 'Murray (R) State Sen 26',
#  'GSU27DLAM': 'LaMantia (D) State Sen 27',
#  'GSU27RHIN': 'Hinojosa (R) State Sen 27',
#  'GSU29DBLA': 'Blanco (D) State Sen 29',
#  'GSU29RZUB': 'Zubeldia (R) State Sen 29'}

# %%
tx_file.columns
# Out:
# Index(['UNIQUE_ID', 'COUNTYFP', 'County', 'TX_VTD', 'G22AGRDHAY', 'G22AGRRMIL',
#        'G22ATGDGAR', 'G22ATGLASH', 'G22ATGRPAX', 'G22COMDDUD',
#        ...
#        'GSU24DJON', 'GSU24RFLO', 'GSU25DWAL', 'GSU25RCAM', 'GSU26DMEN',
#        'GSU26RMUR', 'GSU27DLAM', 'GSU27RHIN', 'GSU29DBLA', 'GSU29RZUB'],
#       dtype='object', length=370)

# %%
### Create README

fields_dict['UNIQUE_ID']='Unique ID for each precinct'
fields_dict['COUNTYFP']='County FIP identifier'
fields_dict['County']='County Name'
fields_dict['TX_VTD']='Texas Voting Tabulation District ID'

title = "Georgia 2022 General Election Precinct-Level Results"
retrieval_date = "01/31/23"
fields_dict = fields_dict
github_link = "UPDATE LINK"
file_folder = "./tx_2022_gen_vtd/"
source = "Georgia Secretary of State"

# %%
def full_readme_text(title, retrieval_date, source, fields_dict, github_link):

#First section of README
    readme_p1 = '''{title}\n
## RDH Date Retrieval
{retrieval_date}

## Sources
{source}

## Fields:
'''.format(title = title, source = source, retrieval_date = retrieval_date)

#Second section of README
    fields_table = pd.DataFrame.from_dict(fields_dict.items())
    fields_table.columns = ["Field Name", "Description"]
    readme_p2 = fields_table.to_string(formatters={'Description':'{{:<{}s}}'.format(fields_table['Description'].str.len().max()).format, 'Field Name':'{{:<{}s}}'.format(fields_table['Field Name'].str.len().max()).format}, index=False, justify = "left")

#Third section of README
    readme_p3 = '''\n
## Processing Steps
Visit the RDH GitHub and the processing script for this code [here]({github_link})

Please direct questions related to processing this dataset to info@redistrictingdatahub.org.
'''.format(github_link=github_link)
    
    full_readme = str(readme_p1)+str(readme_p2)+str(readme_p3)
    return full_readme

# %%
if not os.path.exists(file_folder):
    os.mkdir(file_folder)

with open(file_folder+"README_copy.txt", 'w') as tf:
        tf.write(full_readme_text(title, retrieval_date, source, fields_dict, github_link))
