# %%
import pandas as pd
import os

# %%
#Set the working directory
project_folder = '/Users/grantschwab/Desktop/RDH/Projects/florida_primary2022'
os.chdir(project_folder)

# %%
#Import csv of contests and column names
fl_names = pd.read_csv("./field_names.csv")

#Cleaning how contest descriptions appear
fl_names["0"] = fl_names["0"].apply(lambda x: " ".join(x.split("-:-")[:2])+" ("+x.split("-:-")[2].replace("PARTY:","")+")")

#Preview
fl_names
# Out:
#      Unnamed: 0                                                 0
# 0    P22USSDRUS            United States Senator Brian Rush (DEM)
# 1    P22USSDDEL  United States Senator Ricardo De La Fuente (DEM)
# 2    P22USSDDEM           United States Senator Val Demings (DEM)
# 3    P22USSDSAN       United States Senator William Sanchez (DEM)
# 4    P22ATGDAYA               Attorney General Aramis Ayala (DEM)
# ..          ...                                               ...
# 349  PSL113RLOP            State Representative Vicki Lopez (REP)
# 350  PSL107DFRA       State Representative Wancito Francius (DEM)
# 351  PSL029RBAR        State Representative Webster Barnaby (REP)
# 352  PSL062DNEW   State Representative Wengay "Newt" Newton (DEM)
# 353  PSL051ROLS   State Representative William "Bill" Olson (REP)
#
# [354 rows x 2 columns]

# %%
#Create sorted dictionary of contests and column names
contest_dict = dict(zip(fl_names["Unnamed: 0"], fl_names["0"]))
myKeys = list(contest_dict.keys())
contest_dict = {i: contest_dict[i] for i in myKeys}

# %%
contest_dict
# Out:
# {'P22USSDRUS': 'United States Senator Brian Rush (DEM)',
#  'P22USSDDEL': 'United States Senator Ricardo De La Fuente (DEM)',
#  'P22USSDDEM': 'United States Senator Val Demings (DEM)',
#  'P22USSDSAN': 'United States Senator William Sanchez (DEM)',
#  'P22ATGDAYA': 'Attorney General Aramis Ayala (DEM)',
#  'P22ATGDUHL': 'Attorney General Daniel Uhlfelder (DEM)',
#  'P22ATGDLEW': 'Attorney General Jim Lewis (DEM)',
#  'P22COADGAI': 'Commissioner of Agriculture J. R. Gaillot (DEM)',
#  'P22COARSHA': 'Commissioner of Agriculture James W. Shaw (REP)',
#  'P22COADBLE': 'Commissioner of Agriculture Naomi Esther Blemur (DEM)',
#  'P22COADMOR': 'Commissioner of Agriculture Ryan Morales (DEM)',
#  'P22COARSIM': 'Commissioner of Agriculture Wilton Simpson (REP)',
#  'P22GOVDDAN': 'Governor Cadance Daniel (DEM)',
#  'P22GOVDCRI': 'Governor Charlie Crist (DEM)',
#  'P22GOVDFRI': 'Governor Nicole "Nikki" Fried (DEM)',
#  'P22GOVDWIL': 'Governor Robert L. Willis (DEM)',
#  'PCON04RBEA': 'Representative in Congress Aaron Bean (REP)',
#  'PCON09RMOR': 'Representative in Congress Adianis Morales (REP)',
#  'PCON07DKRU': 'Representative in Congress Al Krulick (DEM)',
#  'PCON10DAGR': 'Representative in Congress Alan Grayson (DEM)',
#  'PCON15DCOH': 'Representative in Congress Alan M. Cohn (DEM)',
#  'PCON07DPAS': 'Representative in Congress Allek Pastrana (DEM)',
#  'PCON23DELL': 'Representative in Congress Allen Ellison (DEM)',
#  'PCON13RMAK': 'Representative in Congress Amanda Makki (REP)',
#  'PCON27DMON': 'Representative in Congress Angel Montalvo (DEM)',
#  'PCON20DOMP': 'Representative in Congress Anika Omphroy (DEM)',
#  'PCON13RLUN': 'Representative in Congress Anna Paulina Luna (REP)',
#  'PCON27DTAD': 'Representative in Congress Annette Taddeo (DEM)',
#  'PCON04DHIL': 'Representative in Congress Anthony "Tony" Hill (DEM)',
#  'PCON07RSAB': 'Representative in Congress Anthony Sabatini (REP)',
#  'PCON07RSAN': 'Representative in Congress Armando Al Santos (REP)',
#  'PCON23DSOR': 'Representative in Congress Ben Sorensen (DEM)',
#  'PCON07RDUK': 'Representative in Congress Brady Duke (REP)',
#  'PCON21RMAS': 'Representative in Congress Brian Mast (REP)',
#  'PCON12RPER': 'Representative in Congress Brian Perras (REP)',
#  'PCON19RDON': 'Representative in Congress Byron Donalds (REP)',
#  'PCON10RWIM': 'Representative in Congress Calvin B. Wimbish (REP)',
#  'PCON25RSPA': 'Representative in Congress Carla Spalding (REP)',
#  'PCON28RGIM': 'Representative in Congress Carlos A. Gimenez (REP)',
#  'PCON28RGAR': 'Representative in Congress Carlos Garin (REP)',
#  'PCON22RLAW': 'Representative in Congress Carrie Lawlor (REP)',
#  'PCON15DRAM': 'Representative in Congress Cesar Ramirez (DEM)',
#  'PCON06RDAV': 'Representative in Congress Charles E. Davis (REP)',
#  'PCON12RLEI': 'Representative in Congress Chris Leiser (REP)',
#  'PCON13RQUI': 'Representative in Congress Christine Y. Quinn (REP)',
#  'PCON14DBRA': 'Representative in Congress Christopher Bradley (DEM)',
#  'PCON23RMCL': 'Representative in Congress Christy McLaughlin (REP)',
#  'PCON10DBRO': 'Representative in Congress Corrine Brown (DEM)',
#  'PCON07RMIL': 'Representative in Congress Cory Mills (REP)',
#  'PCON20DHOL': 'Representative in Congress Dale V.C. Holness (DEM)',
#  'PCON22RFRA': 'Representative in Congress Dan Franzese (REP)',
#  'PCON08DDOD': 'Representative in Congress Danelle Dodge (DEM)',
#  'PCON11RWEB': 'Representative in Congress Daniel Webster (REP)',
#  'PCON03DHAW': 'Representative in Congress Danielle Hawk (DEM)',
#  'PCON23RCER': 'Representative in Congress Darlene Cerezo Swaffar (REP)',
#  'PCON26RAQU': 'Representative in Congress Darren Aquino (REP)',
#  'PCON25DSCH': 'Representative in Congress Debbie Wasserman Schultz (DEM)',
#  'PCON22RADE': 'Representative in Congress Deborah Adeimy (REP)',
#  'PCON15RGRI': 'Representative in Congress Demetries "Commander" Grimes (REP)',
#  'PCON15DGEL': 'Representative in Congress Eddie Geller (DEM)',
#  'PCON18RTAR': 'Representative in Congress Eduardo "Eddie" G. Tarazona (REP)',
#  'PCON04RAGU': 'Representative in Congress Erick Aguilar (REP)',
#  'PCON07RBEN': 'Representative in Congress Erika Benfield (REP)',
#  'PCON27RPOL': 'Representative in Congress Frank Polo (REP)',
#  'PCON24DWIL': 'Representative in Congress Frederica Wilson (DEM)',
#  'PCON15DBRO': 'Representative in Congress Gavin Brown (DEM)',
#  'PCON11RSOR': 'Representative in Congress Gavriel E. Soriano (REP)',
#  'PCON01RMER': 'Representative in Congress Greg Merk (REP)',
#  'PCON12RBIL': 'Representative in Congress Gus Michael Bilirakis (REP)',
#  'PCON23DHOL': 'Representative in Congress Hava Holzhauer (DEM)',
#  'PCON07DFER': 'Representative in Congress Hilsia "Tatiana" Fernandez (DEM)',
#  'PCON23RWEI': 'Representative in Congress Ira Weinstein (REP)',
#  'PCON10DACH': 'Representative in Congress Jack Achenbach (DEM)',
#  'PCON12RMAR': 'Representative in Congress Jack Martin (REP)',
#  'PCON15RTOL': 'Representative in Congress Jackie Toledo (REP)',
#  'PCON23RPRU': 'Representative in Congress James "Jim" Pruden (REP)',
#  'PCON14RJUD': 'Representative in Congress James Judge (REP)',
#  'PCON23DMOS': 'Representative in Congress Jared Moskowitz (DEM)',
#  'PCON21RBUO': 'Representative in Congress Jeff Buongiorno (REP)',
#  'PCON10DBOO': 'Representative in Congress Jeffrey Boone (DEM)',
#  'PCON18RRAY': 'Representative in Congress Jennifer Raybon (REP)',
#  'PCON14RTOR': 'Representative in Congress Jerry Torres (REP)',
#  'PCON24RNAV': 'Representative in Congress Jesus G. Navarro (REP)',
#  'PCON19RHUF': 'Representative in Congress Jim Huff (REP)',
#  'PCON08DTER': 'Representative in Congress Joanne Terry (DEM)',
#  'PCON23RBUD': 'Representative in Congress Joe Budd (REP)',
#  'PCON05RRUT': 'Representative in Congress John H. Rutherford (REP)',
#  'PCON04RCHU': 'Representative in Congress Jon Chuba (REP)',
#  'PCON09RCAS': 'Representative in Congress Jose Castillo (REP)',
#  'PCON28DPAR': 'Representative in Congress Juan Paredes (DEM)',
#  'PCON03RWAT': 'Representative in Congress Justin Waters (REP)',
#  'PCON07DGRE': 'Representative in Congress Karen Green (DEM)',
#  'PCON28RMIL': 'Representative in Congress Karl "KW" Miller (REP)',
#  'PCON03RCAM': 'Representative in Congress Kat Cammack (REP)',
#  'PCON14DCAS': 'Representative in Congress Kathy Castor (DEM)',
#  'PCON15RSTA': 'Representative in Congress Kelli Stargel (REP)',
#  'PCON27DRUS': 'Representative in Congress Ken Russell (DEM)',
#  'PCON18RHAR': 'Representative in Congress Kenneth "Kenny" James Hartpence (REP)',
#  'PCON15RMCG': 'Representative in Congress Kevin "Mac" McGovern (REP)',
#  'PCON24DHAR': 'Representative in Congress Kevin C. Harris (DEM)',
#  'PCON13RHAY': 'Representative in Congress Kevin Hayslett (REP)',
#  'PCON10DMUN': 'Representative in Congress Khalid Muneer (DEM)',
#  'PCON04DHOL': 'Representative in Congress LaShonda "L.J." Holloway (DEM)',
#  'PCON10RJON': 'Representative in Congress Lateresa "L.A." Jones (REP)',
#  'PCON11RLOO': 'Representative in Congress Laura Loomer (REP)',
#  'PCON15RLEE': 'Representative in Congress Laurel Lee (REP)',
#  'PCON24RSPI': 'Representative in Congress Lavern Spicer (REP)',
#  'PCON05RLOP': 'Representative in Congress Leigha "Luna" Lopez (REP)',
#  'PCON21RSKR': 'Representative in Congress Ljubo Skrbic (REP)',
#  'PCON05RMAC': 'Representative in Congress Mara H. Macie (REP)',
#  'PCON26RDIA': 'Representative in Congress Mario Diaz-Balart (REP)',
#  'PCON01RLOM': 'Representative in Congress Mark Lombardo (REP)',
#  'PCON16RHYD': 'Representative in Congress Martin Hyde (REP)',
#  'PCON27RSAL': 'Representative in Congress María Elvira Salazar (REP)',
#  'PCON01RGAE': 'Representative in Congress Matt Gaetz (REP)',
#  'PCON10DFRO': 'Representative in Congress Maxwell Alejandro Frost (DEM)',
#  'PCON21RMAR': 'Representative in Congress Melissa Martz (REP)',
#  'PCON06RWAL': 'Representative in Congress Michael Waltz (REP)',
#  'PCON23DHAM': 'Representative in Congress Michaelangelo Collins Hamilton (DEM)',
#  'PCON13RKHE': 'Representative in Congress Moneer Kheireddine (REP)',
#  'PCON23RPER': 'Representative in Congress Myles Perrone (REP)',
#  'PCON10DJAC': 'Representative in Congress Natalie Jackson (DEM)',
#  'PCON01DSCH': 'Representative in Congress Peggy Schiller (DEM)',
#  'PCON22RARI': 'Representative in Congress Peter Steven Arianas (REP)',
#  'PCON10RWEE': 'Representative in Congress Peter Weed (REP)',
#  'PCON10DBRA': 'Representative in Congress Randolph Bracy (DEM)',
#  'PCON01DJON': 'Representative in Congress Rebekah Jones (DEM)',
#  'PCON28DASE': 'Representative in Congress Robert Asencio (DEM)',
#  'PCON25DMIL': 'Representative in Congress Robert Millwee (DEM)',
#  'PCON22RDOR': 'Representative in Congress Rod Dorilás (REP)',
#  'PCON25RYOU': 'Representative in Congress Rubin Young (REP)',
#  'PCON07RROB': 'Representative in Congress Rusty Roberts (REP)',
#  'PCON14RNAS': 'Representative in Congress Samar "Sam" Nashagh (REP)',
#  'PCON18RFRA': 'Representative in Congress Scott Franklin (REP)',
#  'PCON07RSTU': 'Representative in Congress Scott Sturgill (REP)',
#  'PCON09RMOO': 'Representative in Congress Scotty Moore (REP)',
#  'PCON09RORT': 'Representative in Congress Sergio E. Ortiz (REP)',
#  'PCON20DCHE': 'Representative in Congress Sheila Cherfilus-McCormick (DEM)',
#  'PCON12RPRE': 'Representative in Congress Sid Preskitt (REP)',
#  'PCON23RCHE': 'Representative in Congress Steven Chess (REP)',
#  'PCON07REDW': 'Representative in Congress Ted Edwards (REP)',
#  'PCON10DTGR': 'Representative in Congress Terence R. Gray (DEM)',
#  'PCON10DTAC': 'Representative in Congress Teresa Tachon (DEM)',
#  'PCON10RLOW': 'Representative in Congress Thuy "Twee" Lowe (REP)',
#  'PCON03DWEL': 'Representative in Congress Tom Wells (DEM)',
#  'PCON10RLE': 'Representative in Congress Tuan Le (REP)',
#  'PCON16RBUC': 'Representative in Congress Vern Buchanan (REP)',
#  'PCON23DTRO': 'Representative in Congress W. Michael "Mike" Trout (DEM)',
#  'PCON18RSCH': 'Representative in Congress Wendy June Schmeling (REP)',
#  'PCON15DVAN': 'Representative in Congress William VanHorn (DEM)',
#  'PCON10RMON': 'Representative in Congress Willie Montague (REP)',
#  'PSU08DWIL': 'State Senator Andrea Williams (DEM)',
#  'PSU35DSHA': 'State Senator Barbara Sharief (DEM)',
#  'PSU10RCHA': 'State Senator Denali Charres (REP)',
#  'PSU01RBRO': 'State Senator Doug Broxson (REP)',
#  'PSU34DIGH': 'State Senator Erhabor Ighodaro (DEM)',
#  'PSU15DTHO': 'State Senator Geraldine F. Thompson (DEM)',
#  'PSU07RJAM': 'State Senator Gerry James (REP)',
#  'PSU10RBRO': 'State Senator Jason Brodeur (REP)',
#  'PSU02RTRU': 'State Senator Jay Trumbull (REP)',
#  'PSU20RBOY': 'State Senator Jim Boyd (REP)',
#  'PSU22RGRU': 'State Senator Joe Gruters (REP)',
#  'PSU20RHOU': 'State Senator John Houman (REP)',
#  'PSU01RMIL': 'State Senator John Mills (REP)',
#  'PSU15DBRO': 'State Senator Kamia Brown (DEM)',
#  'PSU35DBOO': 'State Senator Lauren Book (DEM)',
#  'PSU22RJOH': 'State Senator Michael Johnson (REP)',
#  'PSU34DESC': 'State Senator Pitchie "Peachy" Escarment (DEM)',
#  'PSU05DGAF': 'State Senator Reggie Gaffney (DEM)',
#  'PSU02RPIA': 'State Senator Regina Piazza (REP)',
#  'PSU08DDEM': 'State Senator Richard Paul Dembinsky (DEM)',
#  'PSU34DJON': 'State Senator Shevrin "Shev" Jones (DEM)',
#  'PSU26RBYE': 'State Senator Steve Byers (REP)',
#  'PSU05DDAV': 'State Senator Tracie Davis (DEM)',
#  'PSU07RHUT': 'State Senator Travis Hutson (REP)',
#  'PSU26RWHE': 'State Senator William Wheelen (REP)',
#  'PSL120DGEN': 'State Representative Adam Gentle (DEM)',
#  'PSL113RPER': 'State Representative Alberto Perosch (REP)',
#  'PSL113DDAM': 'State Representative Alessandro "A.J." DAmico (DEM)',
#  'PSL002RAND': 'State Representative Alex Andrade (REP)',
#  'PSL113DALT': 'State Representative Andrés Althabe (DEM)',
#  'PSL036RPER': 'State Representative Angelique "Angel" Perry (REP)',
#  'PSL013DNIX': 'State Representative Angie Nixon (DEM)',
#  'PSL053RKOC': 'State Representative Anthony Kocovic (REP)',
#  'PSL047DNIE': 'State Representative Anthony Nieves (DEM)',
#  'PSL119RALV': 'State Representative Ashley Alvarez (REP)',
#  'PSL109DGAN': 'State Representative Ashley V. Gantt (DEM)',
#  'PSL058DFEN': 'State Representative Bernard "Bernie" Fensterwald (DEM)',
#  'PSL059RJAC': 'State Representative Berny Jacques (REP)',
#  'PSL020RPAY': 'State Representative Bobby Payne (REP)',
#  'PSL042RJAC': 'State Representative Bonnie Jackson (REP)',
#  'PSL055RSOL': 'State Representative Brad Sollberger (REP)',
#  'PSL056RYEA': 'State Representative Brad Yeager (REP)',
#  'PSL022DPET': 'State Representative Brandon Peters (DEM)',
#  'PSL006RCLO': 'State Representative Brian Clowdus (REP)',
#  'PSL041DANT': 'State Representative Bruce H. Antone (DEM)',
#  'PSL045RPOR': 'State Representative Bruno Portigliatti (REP)',
#  'PSL098DJON': 'State Representative Carmen Jones (DEM)',
#  'PSL045RAME': 'State Representative Carolina Amesty (REP)',
#  'PSL039RHAR': 'State Representative Charles Hart (REP)',
#  'PSL030RTRA': 'State Representative Chase Tramont (REP)',
#  'PSL016RSTO': 'State Representative Chet Stokes (REP)',
#  'PSL091RDUC': 'State Representative Christina DuCasse (REP)',
#  'PSL017RMER': 'State Representative Christina Meredith (REP)',
#  'PSL107DBEN': 'State Representative Christopher Benjamin (DEM)',
#  'PSL043RWRI': 'State Representative Christopher Wright (REP)',
#  'PSL022RCLE': 'State Representative Chuck Clemons (REP)',
#  'PSL101DMIL': 'State Representative Clay Miller (DEM)',
#  'PSL005RPAT': 'State Representative Clint Pate (REP)',
#  'PSL044DMOR': 'State Representative Daisy Morales (DEM)',
#  'PSL047DMAR': 'State Representative Dan Marquith (DEM)',
#  'PSL120DHOR': 'State Representative Daniel "Dan" Horton-Diaz (DEM)',
#  'PSL069RALV': 'State Representative Daniel "Danny" Alvarez (REP)',
#  'PSL118RSOT': 'State Representative Daniel Sotelo (REP)',
#  'PSL099DCAM': 'State Representative Daryl Campbell (DEM)',
#  'PSL042RDWY': 'State Representative David Dwyer (REP)',
#  'PSL038RSMI': 'State Representative David Smith (REP)',
#  'PSL015RBLA': 'State Representative Dean Black (REP)',
#  'PSL036DPOU': 'State Representative Deborah Poulalion (DEM)',
#  'PSL013DSMI': 'State Representative Delaine Smith (DEM)',
#  'PSL035RLIE': 'State Representative Dianna Liebnitzky (REP)',
#  'PSL059RNAD': 'State Representative Dipak D. Nadkarni (REP)',
#  'PSL038DDOU': 'State Representative Dominique B. Douglas (DEM)',
#  'PSL108DJOS': 'State Representative Dotie Joseph (DEM)',
#  'PSL039RBAN': 'State Representative Doug Bankson (REP)',
#  'PSL106RROS': 'State Representative Douglas John Ross (REP)',
#  'PSL105DSID': 'State Representative Dr. Imran Uddin Siddiqui (DEM)',
#  'PSL038RWUE': 'State Representative Drake Wuertz (REP)',
#  'PSL038DMEA': 'State Representative Ed Measom (DEM)',
#  'PSL099DMAN': 'State Representative Elijah Manley (DEM)',
#  'PSL029RFET': 'State Representative Elizabeth Fetterhoff (REP)',
#  'PSL015RNUN': 'State Representative Emily Nunez (REP)',
#  'PSL106RBAS': 'State Representative Fabián Basabe (REP)',
#  'PSL077ROCO': 'State Representative Ford OConnell (REP)',
#  'PSL118RROD': 'State Representative Francisco Rodriguez (REP)',
#  'PSL035RHAW': 'State Representative Fred Hawkins (REP)',
#  'PSL119DGON': 'State Representative Gabriel Gonzalez (DEM)',
#  'PSL055RPAP': 'State Representative Gabriel Papadopoulos (REP)',
#  'PSL008DFRA': 'State Representative Gallop P. Franklin (DEM)',
#  'PSL014DDEN': 'State Representative Garrett Dennis (DEM)',
#  'PSL002RLIT': 'State Representative Greg Litton (REP)',
#  'PSL008DJAM': 'State Representative Gregory James (DEM)',
#  'PSL006RGRI': 'State Representative Griff Griffitts (REP)',
#  'PSL106DORT': 'State Representative Gustavo Ortega (DEM)',
#  'PSL092DZAH': 'State Representative Hasan Zahangir (DEM)',
#  'PSL101DCAS': 'State Representative Hillary Cassel (DEM)',
#  'PSL047DJEN': 'State Representative Horng "Andrew" Jeng (DEM)',
#  'PSL008DBRO': 'State Representative Hubert Brown (DEM)',
#  'PSL014DHIN': 'State Representative Iris Hinton (DEM)',
#  'PSL065RHOF': 'State Representative Jake Hoffman (REP)',
#  'PSL120RMOO': 'State Representative James "Jim" V. Mooney Jr (REP)',
#  'PSL119DCUE': 'State Representative James A. Cueva (DEM)',
#  'PSL109DBUS': 'State Representative James Bush III (DEM)',
#  'PSL087RJUS': 'State Representative Jane Justice (REP)',
#  'PSL045RFRE': 'State Representative Janet Frevola (REP)',
#  'PSL058RHOL': 'State Representative Jason Holloway (REP)',
#  'PSL043RROD': 'State Representative Jay J. Rodriguez (REP)',
#  'PSL056RCOC': 'State Representative Jayden Cocuzza (REP)',
#  'PSL053RHOL': 'State Representative Jeff Holcomb (REP)',
#  'PSL044DHAR': 'State Representative Jennifer "Rita" Harris (DEM)',
#  'PSL050RCAN': 'State Representative Jennifer Canady (REP)',
#  'PSL059RWIL': 'State Representative Jennifer Wilson (REP)',
#  'PSL062DPHI': 'State Representative Jesse Philippe (DEM)',
#  'PSL017RBAK': 'State Representative Jessica Baker (REP)',
#  'PSL058RVRI': 'State Representative Jim Vricos (REP)',
#  'PSL003RRUD': 'State Representative Joel Rudman (REP)',
#  'PSL052RTEM': 'State Representative John Temple (REP)',
#  'PSL002RKAR': 'State Representative Jordan Karr (REP)',
#  'PSL106DLEO': 'State Representative Jordan W. Leonard (DEM)',
#  'PSL119RSOT': 'State Representative Jose Soto (REP)',
#  'PSL058DSAP': 'State Representative Joseph Saportas (DEM)',
#  'PSL051RTOM': 'State Representative Josie Tomkow (REP)',
#  'PSL119RPOR': 'State Representative Juan Carlos Porras (REP)',
#  'PSL118RFER': 'State Representative Juan Fernandez-Barquin (REP)',
#  'PSL065RGON': 'State Representative Karen Gonzalez Pittman (REP)',
#  'PSL034RHIL': 'State Representative Karen Hiltz (REP)',
#  'PSL093DWAL': 'State Representative Katherine M. Waldron (DEM)',
#  'PSL097DSCU': 'State Representative Kelly N-L. Scurry (DEM)',
#  'PSL092DSKI': 'State Representative Kelly Skidmore (DEM)',
#  'PSL035RDAV': 'State Representative Kenneth Davenport (REP)',
#  'PSL055RSTE': 'State Representative Kevin M. Steele (REP)',
#  'PSL058RBER': 'State Representative Kimberly "Kim" Berfield (REP)',
#  'PSL014DDAN': 'State Representative Kimberly Daniels (DEM)',
#  'PSL016RMIC': 'State Representative Kiyan Michael (REP)',
#  'PSL037RSTA': 'State Representative Kris Stark (REP)',
#  'PSL040DBRA': 'State Representative LaVon Bracy Davis (DEM)',
#  'PSL016RRAY': 'State Representative Lake Ray (REP)',
#  'PSL068RMCC': 'State Representative Lawrence McClure (REP)',
#  'PSL097DDUN': 'State Representative Lisa Dunkley (DEM)',
#  'PSL025RCOR': 'State Representative Liz Cornell (REP)',
#  'PSL020RMIG': 'State Representative Luis Miguel (REP)',
#  'PSL106RSUT': 'State Representative Lynn Su Sutjapojnukul (REP)',
#  'PSL008DRAT': 'State Representative Marie Rattigan (DEM)',
#  'PSL105DWOO': 'State Representative Marie Woodson (DEM)',
#  'PSL003RCAL': 'State Representative Mariya Calkins (REP)',
#  'PSL025RSIL': 'State Representative Matthew R. Silbernagel (REP)',
#  'PSL069RPET': 'State Representative Megan Angel Petty (REP)',
#  'PSL040DMYE': 'State Representative Melissa S. Myers (DEM)',
#  'PSL108DETI': 'State Representative Michael A. Etienne (DEM)',
#  'PSL065RMIN': 'State Representative Michael C. Minardi (REP)',
#  'PSL062DRAY': 'State Representative Michele K. Rayner (DEM)',
#  'PSL001RSAL': 'State Representative Michelle Salzman (REP)',
#  'PSL087RCAR': 'State Representative Mike Caruso (REP)',
#  'PSL001RHIL': 'State Representative Mike Hill (REP)',
#  'PSL045RZHA': 'State Representative Mike Zhao (REP)',
#  'PSL014DPOL': 'State Representative Mincy Pollock (DEM)',
#  'PSL022DMAG': 'State Representative Olysha Magruder (DEM)',
#  'PSL041DPOW': 'State Representative Pam Powell (DEM)',
#  'PSL098DHAW': 'State Representative Patricia Hawkins-Williams (DEM)',
#  'PSL038RWEI': 'State Representative Patrick D. Weingart (REP)',
#  'PSL068RHAT': 'State Representative Paul D. Hatfield (REP)',
#  'PSL023RREI': 'State Representative Paul John Reinhardt (REP)',
#  'PSL091RGOS': 'State Representative Peggy Gossett-Seidman (REP)',
#  'PSL050RWAL': 'State Representative Phillip Walker (REP)',
#  'PSL036RPLA': 'State Representative Rachel Plakon (REP)',
#  'PSL023RMAS': 'State Representative Ralph E. Massullo Jr (REP)',
#  'PSL039RROS': 'State Representative Randy Ross (REP)',
#  'PSL120RLOP': 'State Representative Rhonda Rebman Lopez (REP)',
#  'PSL036RSAN': 'State Representative Richard Santos (REP)',
#  'PSL119RTSA': 'State Representative Ricky Tsay (REP)',
#  'PSL035DBAG': 'State Representative Rishi Bagga (DEM)',
#  'PSL119RGON': 'State Representative Rob Gonzalez (REP)',
#  'PSL034RBRA': 'State Representative Robert Brackett (REP)',
#  'PSL120RALL': 'State Representative Robert Scott Allen (REP)',
#  'PSL030RHAT': 'State Representative Robyn Hattaway (REP)',
#  'PSL052RDAZ': 'State Representative Rock Daze (REP)',
#  'PSL036DJOS': 'State Representative Rod Joseph (DEM)',
#  'PSL108DHAR': 'State Representative Roy Hardemon (DEM)',
#  'PSL097DFAR': 'State Representative Saima Farooqui (DEM)',
#  'PSL038DHEN': 'State Representative Sarah Henry (DEM)',
#  'PSL056RMOO': 'State Representative Scott Moore (REP)',
#  'PSL093DDEN': 'State Representative Seth Densen (DEM)',
#  'PSL005RABB': 'State Representative Shane Abbott (REP)',
#  'PSL041DROS': 'State Representative Shaniqua "Shan" Rose (DEM)',
#  'PSL008DLET': 'State Representative Sharon Lettman-Hicks (DEM)',
#  'PSL093DALB': 'State Representative Shelly Lariz Albright (DEM)',
#  'PSL037RPLA': 'State Representative Susan Plasencia (REP)',
#  'PSL035DMUN': 'State Representative Tahitiana "T" Munoz-Chaffin (DEM)',
#  'PSL025RYAR': 'State Representative Taylor Yarkosky (REP)',
#  'PSL093DVAL': 'State Representative Thomas "Tom" Valeo (DEM)',
#  'PSL077RESP': 'State Representative Tiffany Esposito (REP)',
#  'PSL023RCLO': 'State Representative Tod Cloud (REP)',
#  'PSL101DDEL': 'State Representative Todd Delmay (DEM)',
#  'PSL035DKEE': 'State Representative Tom Keen (DEM)',
#  'PSL025RVAI': 'State Representative Tom Vail (REP)',
#  'PSL041DMCC': 'State Representative Travaris McCurdy (DEM)',
#  'PSL022RAPP': 'State Representative Ty Appiah (REP)',
#  'PSL005RCOL': 'State Representative Vance D. Coley (REP)',
#  'PSL045RFRA': 'State Representative Vennia Francois (REP)',
#  'PSL113RLOP': 'State Representative Vicki Lopez (REP)',
#  'PSL107DFRA': 'State Representative Wancito Francius (DEM)',
#  'PSL029RBAR': 'State Representative Webster Barnaby (REP)',
#  'PSL062DNEW': 'State Representative Wengay "Newt" Newton (DEM)',
#  'PSL051ROLS': 'State Representative William "Bill" Olson (REP)'}

# %%
###Create README

base_dict = {'UNIQUE_ID':'Unique ID for each precinct',
'COUNTYFP':'County FIP identifier',
'CNTY_CODE':'County Code (Three-character abbreviation)',
'CNTY_NAME':'County Name',
'PREC_ID':'Unique Precinct Identifier',
'POLL_LOC':'Precinct Polling Location'}

fields_dict = {**base_dict, **contest_dict}

title = "Florida 2022 Primary Election Precinct-Level Results"
retrieval_date = "09/05/23"
fields_dict = fields_dict
github_link = "https://github.com/nonpartisan-redistricting-datahub/pber_collection"
file_folder = "./output/fl_2022_pri_prec/"
source = "Florida Division of Elections"

# %%
fields_dict
# Out:
# {'UNIQUE_ID': 'Unique ID for each precinct',
#  'COUNTYFP': 'County FIP identifier',
#  'CNTY_CODE': 'County Code (Three-character abbreviation)',
#  'CNTY_NAME': 'County Name',
#  'PREC_ID': 'Unique Precinct Identifier',
#  'POLL_LOC': 'Precinct Polling Location',
#  'P22USSDRUS': 'United States Senator Brian Rush (DEM)',
#  'P22USSDDEL': 'United States Senator Ricardo De La Fuente (DEM)',
#  'P22USSDDEM': 'United States Senator Val Demings (DEM)',
#  'P22USSDSAN': 'United States Senator William Sanchez (DEM)',
#  'P22ATGDAYA': 'Attorney General Aramis Ayala (DEM)',
#  'P22ATGDUHL': 'Attorney General Daniel Uhlfelder (DEM)',
#  'P22ATGDLEW': 'Attorney General Jim Lewis (DEM)',
#  'P22COADGAI': 'Commissioner of Agriculture J. R. Gaillot (DEM)',
#  'P22COARSHA': 'Commissioner of Agriculture James W. Shaw (REP)',
#  'P22COADBLE': 'Commissioner of Agriculture Naomi Esther Blemur (DEM)',
#  'P22COADMOR': 'Commissioner of Agriculture Ryan Morales (DEM)',
#  'P22COARSIM': 'Commissioner of Agriculture Wilton Simpson (REP)',
#  'P22GOVDDAN': 'Governor Cadance Daniel (DEM)',
#  'P22GOVDCRI': 'Governor Charlie Crist (DEM)',
#  'P22GOVDFRI': 'Governor Nicole "Nikki" Fried (DEM)',
#  'P22GOVDWIL': 'Governor Robert L. Willis (DEM)',
#  'PCON04RBEA': 'Representative in Congress Aaron Bean (REP)',
#  'PCON09RMOR': 'Representative in Congress Adianis Morales (REP)',
#  'PCON07DKRU': 'Representative in Congress Al Krulick (DEM)',
#  'PCON10DAGR': 'Representative in Congress Alan Grayson (DEM)',
#  'PCON15DCOH': 'Representative in Congress Alan M. Cohn (DEM)',
#  'PCON07DPAS': 'Representative in Congress Allek Pastrana (DEM)',
#  'PCON23DELL': 'Representative in Congress Allen Ellison (DEM)',
#  'PCON13RMAK': 'Representative in Congress Amanda Makki (REP)',
#  'PCON27DMON': 'Representative in Congress Angel Montalvo (DEM)',
#  'PCON20DOMP': 'Representative in Congress Anika Omphroy (DEM)',
#  'PCON13RLUN': 'Representative in Congress Anna Paulina Luna (REP)',
#  'PCON27DTAD': 'Representative in Congress Annette Taddeo (DEM)',
#  'PCON04DHIL': 'Representative in Congress Anthony "Tony" Hill (DEM)',
#  'PCON07RSAB': 'Representative in Congress Anthony Sabatini (REP)',
#  'PCON07RSAN': 'Representative in Congress Armando Al Santos (REP)',
#  'PCON23DSOR': 'Representative in Congress Ben Sorensen (DEM)',
#  'PCON07RDUK': 'Representative in Congress Brady Duke (REP)',
#  'PCON21RMAS': 'Representative in Congress Brian Mast (REP)',
#  'PCON12RPER': 'Representative in Congress Brian Perras (REP)',
#  'PCON19RDON': 'Representative in Congress Byron Donalds (REP)',
#  'PCON10RWIM': 'Representative in Congress Calvin B. Wimbish (REP)',
#  'PCON25RSPA': 'Representative in Congress Carla Spalding (REP)',
#  'PCON28RGIM': 'Representative in Congress Carlos A. Gimenez (REP)',
#  'PCON28RGAR': 'Representative in Congress Carlos Garin (REP)',
#  'PCON22RLAW': 'Representative in Congress Carrie Lawlor (REP)',
#  'PCON15DRAM': 'Representative in Congress Cesar Ramirez (DEM)',
#  'PCON06RDAV': 'Representative in Congress Charles E. Davis (REP)',
#  'PCON12RLEI': 'Representative in Congress Chris Leiser (REP)',
#  'PCON13RQUI': 'Representative in Congress Christine Y. Quinn (REP)',
#  'PCON14DBRA': 'Representative in Congress Christopher Bradley (DEM)',
#  'PCON23RMCL': 'Representative in Congress Christy McLaughlin (REP)',
#  'PCON10DBRO': 'Representative in Congress Corrine Brown (DEM)',
#  'PCON07RMIL': 'Representative in Congress Cory Mills (REP)',
#  'PCON20DHOL': 'Representative in Congress Dale V.C. Holness (DEM)',
#  'PCON22RFRA': 'Representative in Congress Dan Franzese (REP)',
#  'PCON08DDOD': 'Representative in Congress Danelle Dodge (DEM)',
#  'PCON11RWEB': 'Representative in Congress Daniel Webster (REP)',
#  'PCON03DHAW': 'Representative in Congress Danielle Hawk (DEM)',
#  'PCON23RCER': 'Representative in Congress Darlene Cerezo Swaffar (REP)',
#  'PCON26RAQU': 'Representative in Congress Darren Aquino (REP)',
#  'PCON25DSCH': 'Representative in Congress Debbie Wasserman Schultz (DEM)',
#  'PCON22RADE': 'Representative in Congress Deborah Adeimy (REP)',
#  'PCON15RGRI': 'Representative in Congress Demetries "Commander" Grimes (REP)',
#  'PCON15DGEL': 'Representative in Congress Eddie Geller (DEM)',
#  'PCON18RTAR': 'Representative in Congress Eduardo "Eddie" G. Tarazona (REP)',
#  'PCON04RAGU': 'Representative in Congress Erick Aguilar (REP)',
#  'PCON07RBEN': 'Representative in Congress Erika Benfield (REP)',
#  'PCON27RPOL': 'Representative in Congress Frank Polo (REP)',
#  'PCON24DWIL': 'Representative in Congress Frederica Wilson (DEM)',
#  'PCON15DBRO': 'Representative in Congress Gavin Brown (DEM)',
#  'PCON11RSOR': 'Representative in Congress Gavriel E. Soriano (REP)',
#  'PCON01RMER': 'Representative in Congress Greg Merk (REP)',
#  'PCON12RBIL': 'Representative in Congress Gus Michael Bilirakis (REP)',
#  'PCON23DHOL': 'Representative in Congress Hava Holzhauer (DEM)',
#  'PCON07DFER': 'Representative in Congress Hilsia "Tatiana" Fernandez (DEM)',
#  'PCON23RWEI': 'Representative in Congress Ira Weinstein (REP)',
#  'PCON10DACH': 'Representative in Congress Jack Achenbach (DEM)',
#  'PCON12RMAR': 'Representative in Congress Jack Martin (REP)',
#  'PCON15RTOL': 'Representative in Congress Jackie Toledo (REP)',
#  'PCON23RPRU': 'Representative in Congress James "Jim" Pruden (REP)',
#  'PCON14RJUD': 'Representative in Congress James Judge (REP)',
#  'PCON23DMOS': 'Representative in Congress Jared Moskowitz (DEM)',
#  'PCON21RBUO': 'Representative in Congress Jeff Buongiorno (REP)',
#  'PCON10DBOO': 'Representative in Congress Jeffrey Boone (DEM)',
#  'PCON18RRAY': 'Representative in Congress Jennifer Raybon (REP)',
#  'PCON14RTOR': 'Representative in Congress Jerry Torres (REP)',
#  'PCON24RNAV': 'Representative in Congress Jesus G. Navarro (REP)',
#  'PCON19RHUF': 'Representative in Congress Jim Huff (REP)',
#  'PCON08DTER': 'Representative in Congress Joanne Terry (DEM)',
#  'PCON23RBUD': 'Representative in Congress Joe Budd (REP)',
#  'PCON05RRUT': 'Representative in Congress John H. Rutherford (REP)',
#  'PCON04RCHU': 'Representative in Congress Jon Chuba (REP)',
#  'PCON09RCAS': 'Representative in Congress Jose Castillo (REP)',
#  'PCON28DPAR': 'Representative in Congress Juan Paredes (DEM)',
#  'PCON03RWAT': 'Representative in Congress Justin Waters (REP)',
#  'PCON07DGRE': 'Representative in Congress Karen Green (DEM)',
#  'PCON28RMIL': 'Representative in Congress Karl "KW" Miller (REP)',
#  'PCON03RCAM': 'Representative in Congress Kat Cammack (REP)',
#  'PCON14DCAS': 'Representative in Congress Kathy Castor (DEM)',
#  'PCON15RSTA': 'Representative in Congress Kelli Stargel (REP)',
#  'PCON27DRUS': 'Representative in Congress Ken Russell (DEM)',
#  'PCON18RHAR': 'Representative in Congress Kenneth "Kenny" James Hartpence (REP)',
#  'PCON15RMCG': 'Representative in Congress Kevin "Mac" McGovern (REP)',
#  'PCON24DHAR': 'Representative in Congress Kevin C. Harris (DEM)',
#  'PCON13RHAY': 'Representative in Congress Kevin Hayslett (REP)',
#  'PCON10DMUN': 'Representative in Congress Khalid Muneer (DEM)',
#  'PCON04DHOL': 'Representative in Congress LaShonda "L.J." Holloway (DEM)',
#  'PCON10RJON': 'Representative in Congress Lateresa "L.A." Jones (REP)',
#  'PCON11RLOO': 'Representative in Congress Laura Loomer (REP)',
#  'PCON15RLEE': 'Representative in Congress Laurel Lee (REP)',
#  'PCON24RSPI': 'Representative in Congress Lavern Spicer (REP)',
#  'PCON05RLOP': 'Representative in Congress Leigha "Luna" Lopez (REP)',
#  'PCON21RSKR': 'Representative in Congress Ljubo Skrbic (REP)',
#  'PCON05RMAC': 'Representative in Congress Mara H. Macie (REP)',
#  'PCON26RDIA': 'Representative in Congress Mario Diaz-Balart (REP)',
#  'PCON01RLOM': 'Representative in Congress Mark Lombardo (REP)',
#  'PCON16RHYD': 'Representative in Congress Martin Hyde (REP)',
#  'PCON27RSAL': 'Representative in Congress María Elvira Salazar (REP)',
#  'PCON01RGAE': 'Representative in Congress Matt Gaetz (REP)',
#  'PCON10DFRO': 'Representative in Congress Maxwell Alejandro Frost (DEM)',
#  'PCON21RMAR': 'Representative in Congress Melissa Martz (REP)',
#  'PCON06RWAL': 'Representative in Congress Michael Waltz (REP)',
#  'PCON23DHAM': 'Representative in Congress Michaelangelo Collins Hamilton (DEM)',
#  'PCON13RKHE': 'Representative in Congress Moneer Kheireddine (REP)',
#  'PCON23RPER': 'Representative in Congress Myles Perrone (REP)',
#  'PCON10DJAC': 'Representative in Congress Natalie Jackson (DEM)',
#  'PCON01DSCH': 'Representative in Congress Peggy Schiller (DEM)',
#  'PCON22RARI': 'Representative in Congress Peter Steven Arianas (REP)',
#  'PCON10RWEE': 'Representative in Congress Peter Weed (REP)',
#  'PCON10DBRA': 'Representative in Congress Randolph Bracy (DEM)',
#  'PCON01DJON': 'Representative in Congress Rebekah Jones (DEM)',
#  'PCON28DASE': 'Representative in Congress Robert Asencio (DEM)',
#  'PCON25DMIL': 'Representative in Congress Robert Millwee (DEM)',
#  'PCON22RDOR': 'Representative in Congress Rod Dorilás (REP)',
#  'PCON25RYOU': 'Representative in Congress Rubin Young (REP)',
#  'PCON07RROB': 'Representative in Congress Rusty Roberts (REP)',
#  'PCON14RNAS': 'Representative in Congress Samar "Sam" Nashagh (REP)',
#  'PCON18RFRA': 'Representative in Congress Scott Franklin (REP)',
#  'PCON07RSTU': 'Representative in Congress Scott Sturgill (REP)',
#  'PCON09RMOO': 'Representative in Congress Scotty Moore (REP)',
#  'PCON09RORT': 'Representative in Congress Sergio E. Ortiz (REP)',
#  'PCON20DCHE': 'Representative in Congress Sheila Cherfilus-McCormick (DEM)',
#  'PCON12RPRE': 'Representative in Congress Sid Preskitt (REP)',
#  'PCON23RCHE': 'Representative in Congress Steven Chess (REP)',
#  'PCON07REDW': 'Representative in Congress Ted Edwards (REP)',
#  'PCON10DTGR': 'Representative in Congress Terence R. Gray (DEM)',
#  'PCON10DTAC': 'Representative in Congress Teresa Tachon (DEM)',
#  'PCON10RLOW': 'Representative in Congress Thuy "Twee" Lowe (REP)',
#  'PCON03DWEL': 'Representative in Congress Tom Wells (DEM)',
#  'PCON10RLE': 'Representative in Congress Tuan Le (REP)',
#  'PCON16RBUC': 'Representative in Congress Vern Buchanan (REP)',
#  'PCON23DTRO': 'Representative in Congress W. Michael "Mike" Trout (DEM)',
#  'PCON18RSCH': 'Representative in Congress Wendy June Schmeling (REP)',
#  'PCON15DVAN': 'Representative in Congress William VanHorn (DEM)',
#  'PCON10RMON': 'Representative in Congress Willie Montague (REP)',
#  'PSU08DWIL': 'State Senator Andrea Williams (DEM)',
#  'PSU35DSHA': 'State Senator Barbara Sharief (DEM)',
#  'PSU10RCHA': 'State Senator Denali Charres (REP)',
#  'PSU01RBRO': 'State Senator Doug Broxson (REP)',
#  'PSU34DIGH': 'State Senator Erhabor Ighodaro (DEM)',
#  'PSU15DTHO': 'State Senator Geraldine F. Thompson (DEM)',
#  'PSU07RJAM': 'State Senator Gerry James (REP)',
#  'PSU10RBRO': 'State Senator Jason Brodeur (REP)',
#  'PSU02RTRU': 'State Senator Jay Trumbull (REP)',
#  'PSU20RBOY': 'State Senator Jim Boyd (REP)',
#  'PSU22RGRU': 'State Senator Joe Gruters (REP)',
#  'PSU20RHOU': 'State Senator John Houman (REP)',
#  'PSU01RMIL': 'State Senator John Mills (REP)',
#  'PSU15DBRO': 'State Senator Kamia Brown (DEM)',
#  'PSU35DBOO': 'State Senator Lauren Book (DEM)',
#  'PSU22RJOH': 'State Senator Michael Johnson (REP)',
#  'PSU34DESC': 'State Senator Pitchie "Peachy" Escarment (DEM)',
#  'PSU05DGAF': 'State Senator Reggie Gaffney (DEM)',
#  'PSU02RPIA': 'State Senator Regina Piazza (REP)',
#  'PSU08DDEM': 'State Senator Richard Paul Dembinsky (DEM)',
#  'PSU34DJON': 'State Senator Shevrin "Shev" Jones (DEM)',
#  'PSU26RBYE': 'State Senator Steve Byers (REP)',
#  'PSU05DDAV': 'State Senator Tracie Davis (DEM)',
#  'PSU07RHUT': 'State Senator Travis Hutson (REP)',
#  'PSU26RWHE': 'State Senator William Wheelen (REP)',
#  'PSL120DGEN': 'State Representative Adam Gentle (DEM)',
#  'PSL113RPER': 'State Representative Alberto Perosch (REP)',
#  'PSL113DDAM': 'State Representative Alessandro "A.J." DAmico (DEM)',
#  'PSL002RAND': 'State Representative Alex Andrade (REP)',
#  'PSL113DALT': 'State Representative Andrés Althabe (DEM)',
#  'PSL036RPER': 'State Representative Angelique "Angel" Perry (REP)',
#  'PSL013DNIX': 'State Representative Angie Nixon (DEM)',
#  'PSL053RKOC': 'State Representative Anthony Kocovic (REP)',
#  'PSL047DNIE': 'State Representative Anthony Nieves (DEM)',
#  'PSL119RALV': 'State Representative Ashley Alvarez (REP)',
#  'PSL109DGAN': 'State Representative Ashley V. Gantt (DEM)',
#  'PSL058DFEN': 'State Representative Bernard "Bernie" Fensterwald (DEM)',
#  'PSL059RJAC': 'State Representative Berny Jacques (REP)',
#  'PSL020RPAY': 'State Representative Bobby Payne (REP)',
#  'PSL042RJAC': 'State Representative Bonnie Jackson (REP)',
#  'PSL055RSOL': 'State Representative Brad Sollberger (REP)',
#  'PSL056RYEA': 'State Representative Brad Yeager (REP)',
#  'PSL022DPET': 'State Representative Brandon Peters (DEM)',
#  'PSL006RCLO': 'State Representative Brian Clowdus (REP)',
#  'PSL041DANT': 'State Representative Bruce H. Antone (DEM)',
#  'PSL045RPOR': 'State Representative Bruno Portigliatti (REP)',
#  'PSL098DJON': 'State Representative Carmen Jones (DEM)',
#  'PSL045RAME': 'State Representative Carolina Amesty (REP)',
#  'PSL039RHAR': 'State Representative Charles Hart (REP)',
#  'PSL030RTRA': 'State Representative Chase Tramont (REP)',
#  'PSL016RSTO': 'State Representative Chet Stokes (REP)',
#  'PSL091RDUC': 'State Representative Christina DuCasse (REP)',
#  'PSL017RMER': 'State Representative Christina Meredith (REP)',
#  'PSL107DBEN': 'State Representative Christopher Benjamin (DEM)',
#  'PSL043RWRI': 'State Representative Christopher Wright (REP)',
#  'PSL022RCLE': 'State Representative Chuck Clemons (REP)',
#  'PSL101DMIL': 'State Representative Clay Miller (DEM)',
#  'PSL005RPAT': 'State Representative Clint Pate (REP)',
#  'PSL044DMOR': 'State Representative Daisy Morales (DEM)',
#  'PSL047DMAR': 'State Representative Dan Marquith (DEM)',
#  'PSL120DHOR': 'State Representative Daniel "Dan" Horton-Diaz (DEM)',
#  'PSL069RALV': 'State Representative Daniel "Danny" Alvarez (REP)',
#  'PSL118RSOT': 'State Representative Daniel Sotelo (REP)',
#  'PSL099DCAM': 'State Representative Daryl Campbell (DEM)',
#  'PSL042RDWY': 'State Representative David Dwyer (REP)',
#  'PSL038RSMI': 'State Representative David Smith (REP)',
#  'PSL015RBLA': 'State Representative Dean Black (REP)',
#  'PSL036DPOU': 'State Representative Deborah Poulalion (DEM)',
#  'PSL013DSMI': 'State Representative Delaine Smith (DEM)',
#  'PSL035RLIE': 'State Representative Dianna Liebnitzky (REP)',
#  'PSL059RNAD': 'State Representative Dipak D. Nadkarni (REP)',
#  'PSL038DDOU': 'State Representative Dominique B. Douglas (DEM)',
#  'PSL108DJOS': 'State Representative Dotie Joseph (DEM)',
#  'PSL039RBAN': 'State Representative Doug Bankson (REP)',
#  'PSL106RROS': 'State Representative Douglas John Ross (REP)',
#  'PSL105DSID': 'State Representative Dr. Imran Uddin Siddiqui (DEM)',
#  'PSL038RWUE': 'State Representative Drake Wuertz (REP)',
#  'PSL038DMEA': 'State Representative Ed Measom (DEM)',
#  'PSL099DMAN': 'State Representative Elijah Manley (DEM)',
#  'PSL029RFET': 'State Representative Elizabeth Fetterhoff (REP)',
#  'PSL015RNUN': 'State Representative Emily Nunez (REP)',
#  'PSL106RBAS': 'State Representative Fabián Basabe (REP)',
#  'PSL077ROCO': 'State Representative Ford OConnell (REP)',
#  'PSL118RROD': 'State Representative Francisco Rodriguez (REP)',
#  'PSL035RHAW': 'State Representative Fred Hawkins (REP)',
#  'PSL119DGON': 'State Representative Gabriel Gonzalez (DEM)',
#  'PSL055RPAP': 'State Representative Gabriel Papadopoulos (REP)',
#  'PSL008DFRA': 'State Representative Gallop P. Franklin (DEM)',
#  'PSL014DDEN': 'State Representative Garrett Dennis (DEM)',
#  'PSL002RLIT': 'State Representative Greg Litton (REP)',
#  'PSL008DJAM': 'State Representative Gregory James (DEM)',
#  'PSL006RGRI': 'State Representative Griff Griffitts (REP)',
#  'PSL106DORT': 'State Representative Gustavo Ortega (DEM)',
#  'PSL092DZAH': 'State Representative Hasan Zahangir (DEM)',
#  'PSL101DCAS': 'State Representative Hillary Cassel (DEM)',
#  'PSL047DJEN': 'State Representative Horng "Andrew" Jeng (DEM)',
#  'PSL008DBRO': 'State Representative Hubert Brown (DEM)',
#  'PSL014DHIN': 'State Representative Iris Hinton (DEM)',
#  'PSL065RHOF': 'State Representative Jake Hoffman (REP)',
#  'PSL120RMOO': 'State Representative James "Jim" V. Mooney Jr (REP)',
#  'PSL119DCUE': 'State Representative James A. Cueva (DEM)',
#  'PSL109DBUS': 'State Representative James Bush III (DEM)',
#  'PSL087RJUS': 'State Representative Jane Justice (REP)',
#  'PSL045RFRE': 'State Representative Janet Frevola (REP)',
#  'PSL058RHOL': 'State Representative Jason Holloway (REP)',
#  'PSL043RROD': 'State Representative Jay J. Rodriguez (REP)',
#  'PSL056RCOC': 'State Representative Jayden Cocuzza (REP)',
#  'PSL053RHOL': 'State Representative Jeff Holcomb (REP)',
#  'PSL044DHAR': 'State Representative Jennifer "Rita" Harris (DEM)',
#  'PSL050RCAN': 'State Representative Jennifer Canady (REP)',
#  'PSL059RWIL': 'State Representative Jennifer Wilson (REP)',
#  'PSL062DPHI': 'State Representative Jesse Philippe (DEM)',
#  'PSL017RBAK': 'State Representative Jessica Baker (REP)',
#  'PSL058RVRI': 'State Representative Jim Vricos (REP)',
#  'PSL003RRUD': 'State Representative Joel Rudman (REP)',
#  'PSL052RTEM': 'State Representative John Temple (REP)',
#  'PSL002RKAR': 'State Representative Jordan Karr (REP)',
#  'PSL106DLEO': 'State Representative Jordan W. Leonard (DEM)',
#  'PSL119RSOT': 'State Representative Jose Soto (REP)',
#  'PSL058DSAP': 'State Representative Joseph Saportas (DEM)',
#  'PSL051RTOM': 'State Representative Josie Tomkow (REP)',
#  'PSL119RPOR': 'State Representative Juan Carlos Porras (REP)',
#  'PSL118RFER': 'State Representative Juan Fernandez-Barquin (REP)',
#  'PSL065RGON': 'State Representative Karen Gonzalez Pittman (REP)',
#  'PSL034RHIL': 'State Representative Karen Hiltz (REP)',
#  'PSL093DWAL': 'State Representative Katherine M. Waldron (DEM)',
#  'PSL097DSCU': 'State Representative Kelly N-L. Scurry (DEM)',
#  'PSL092DSKI': 'State Representative Kelly Skidmore (DEM)',
#  'PSL035RDAV': 'State Representative Kenneth Davenport (REP)',
#  'PSL055RSTE': 'State Representative Kevin M. Steele (REP)',
#  'PSL058RBER': 'State Representative Kimberly "Kim" Berfield (REP)',
#  'PSL014DDAN': 'State Representative Kimberly Daniels (DEM)',
#  'PSL016RMIC': 'State Representative Kiyan Michael (REP)',
#  'PSL037RSTA': 'State Representative Kris Stark (REP)',
#  'PSL040DBRA': 'State Representative LaVon Bracy Davis (DEM)',
#  'PSL016RRAY': 'State Representative Lake Ray (REP)',
#  'PSL068RMCC': 'State Representative Lawrence McClure (REP)',
#  'PSL097DDUN': 'State Representative Lisa Dunkley (DEM)',
#  'PSL025RCOR': 'State Representative Liz Cornell (REP)',
#  'PSL020RMIG': 'State Representative Luis Miguel (REP)',
#  'PSL106RSUT': 'State Representative Lynn Su Sutjapojnukul (REP)',
#  'PSL008DRAT': 'State Representative Marie Rattigan (DEM)',
#  'PSL105DWOO': 'State Representative Marie Woodson (DEM)',
#  'PSL003RCAL': 'State Representative Mariya Calkins (REP)',
#  'PSL025RSIL': 'State Representative Matthew R. Silbernagel (REP)',
#  'PSL069RPET': 'State Representative Megan Angel Petty (REP)',
#  'PSL040DMYE': 'State Representative Melissa S. Myers (DEM)',
#  'PSL108DETI': 'State Representative Michael A. Etienne (DEM)',
#  'PSL065RMIN': 'State Representative Michael C. Minardi (REP)',
#  'PSL062DRAY': 'State Representative Michele K. Rayner (DEM)',
#  'PSL001RSAL': 'State Representative Michelle Salzman (REP)',
#  'PSL087RCAR': 'State Representative Mike Caruso (REP)',
#  'PSL001RHIL': 'State Representative Mike Hill (REP)',
#  'PSL045RZHA': 'State Representative Mike Zhao (REP)',
#  'PSL014DPOL': 'State Representative Mincy Pollock (DEM)',
#  'PSL022DMAG': 'State Representative Olysha Magruder (DEM)',
#  'PSL041DPOW': 'State Representative Pam Powell (DEM)',
#  'PSL098DHAW': 'State Representative Patricia Hawkins-Williams (DEM)',
#  'PSL038RWEI': 'State Representative Patrick D. Weingart (REP)',
#  'PSL068RHAT': 'State Representative Paul D. Hatfield (REP)',
#  'PSL023RREI': 'State Representative Paul John Reinhardt (REP)',
#  'PSL091RGOS': 'State Representative Peggy Gossett-Seidman (REP)',
#  'PSL050RWAL': 'State Representative Phillip Walker (REP)',
#  'PSL036RPLA': 'State Representative Rachel Plakon (REP)',
#  'PSL023RMAS': 'State Representative Ralph E. Massullo Jr (REP)',
#  'PSL039RROS': 'State Representative Randy Ross (REP)',
#  'PSL120RLOP': 'State Representative Rhonda Rebman Lopez (REP)',
#  'PSL036RSAN': 'State Representative Richard Santos (REP)',
#  'PSL119RTSA': 'State Representative Ricky Tsay (REP)',
#  'PSL035DBAG': 'State Representative Rishi Bagga (DEM)',
#  'PSL119RGON': 'State Representative Rob Gonzalez (REP)',
#  'PSL034RBRA': 'State Representative Robert Brackett (REP)',
#  'PSL120RALL': 'State Representative Robert Scott Allen (REP)',
#  'PSL030RHAT': 'State Representative Robyn Hattaway (REP)',
#  'PSL052RDAZ': 'State Representative Rock Daze (REP)',
#  'PSL036DJOS': 'State Representative Rod Joseph (DEM)',
#  'PSL108DHAR': 'State Representative Roy Hardemon (DEM)',
#  'PSL097DFAR': 'State Representative Saima Farooqui (DEM)',
#  'PSL038DHEN': 'State Representative Sarah Henry (DEM)',
#  'PSL056RMOO': 'State Representative Scott Moore (REP)',
#  'PSL093DDEN': 'State Representative Seth Densen (DEM)',
#  'PSL005RABB': 'State Representative Shane Abbott (REP)',
#  'PSL041DROS': 'State Representative Shaniqua "Shan" Rose (DEM)',
#  'PSL008DLET': 'State Representative Sharon Lettman-Hicks (DEM)',
#  'PSL093DALB': 'State Representative Shelly Lariz Albright (DEM)',
#  'PSL037RPLA': 'State Representative Susan Plasencia (REP)',
#  'PSL035DMUN': 'State Representative Tahitiana "T" Munoz-Chaffin (DEM)',
#  'PSL025RYAR': 'State Representative Taylor Yarkosky (REP)',
#  'PSL093DVAL': 'State Representative Thomas "Tom" Valeo (DEM)',
#  'PSL077RESP': 'State Representative Tiffany Esposito (REP)',
#  'PSL023RCLO': 'State Representative Tod Cloud (REP)',
#  'PSL101DDEL': 'State Representative Todd Delmay (DEM)',
#  'PSL035DKEE': 'State Representative Tom Keen (DEM)',
#  'PSL025RVAI': 'State Representative Tom Vail (REP)',
#  'PSL041DMCC': 'State Representative Travaris McCurdy (DEM)',
#  'PSL022RAPP': 'State Representative Ty Appiah (REP)',
#  'PSL005RCOL': 'State Representative Vance D. Coley (REP)',
#  'PSL045RFRA': 'State Representative Vennia Francois (REP)',
#  'PSL113RLOP': 'State Representative Vicki Lopez (REP)',
#  'PSL107DFRA': 'State Representative Wancito Francius (DEM)',
#  'PSL029RBAR': 'State Representative Webster Barnaby (REP)',
#  'PSL062DNEW': 'State Representative Wengay "Newt" Newton (DEM)',
#  'PSL051ROLS': 'State Representative William "Bill" Olson (REP)'}

# %%
def full_readme_text(title, retrieval_date, source, fields_dict, github_link):

#First section of README
  readme_p1 = '''{title}\n
## RDH Date Retrieval
{retrieval_date}

## Sources
{source}'''.format(title = title, source = source, retrieval_date = retrieval_date)

#Second section of README
  readme_p2 = '''\n
## Notes on Field Names (adapted from VEST):
Columns reporting votes generally follow the pattern:
One example is:
G16PRERTRU
The first character is G for a general election, P for a primary, S for a special, and R for a runoff.
Characters 2 and 3 are the year of the election.*
Characters 4-6 represent the office type (see list below).
Character 7 represents the party of the candidate.
Characters 8-10 are the first three letters of the candidate's last name.

*To fit within the GIS 10 character limit for field names, the naming convention is slightly different for the State Legislature and US House of Representatives. All fields are listed below with definitions.

Office Codes Used:
USS - U.S. Senate
ATG - Attorney General
COA - Commissioner of Agriculture
GOV - Governor and Lieutenant Governor
CON## - U.S. Congress
SU##  - State Legislative Upper
SL###  - State Legislative Lower


Party Codes Used:
D - Democratic
R - Republican
'''

#Third section of README
  fields_table = pd.DataFrame.from_dict(fields_dict.items())
  fields_table.columns = ["Field Name", "Description"]
  readme_p3 = '''\n## Fields:\n''' + fields_table.to_string(formatters={'Description':'{{:<{}s}}'.format(fields_table['Description'].str.len().max()).format, 'Field Name':'{{:<{}s}}'.format(fields_table['Field Name'].str.len().max()).format}, index=False, justify = "left")

#Fourth section
  readme_p4 = '''\n
## Additional Notes
Files were checked against separate countywide election result files from the Florida Department of State Election Archive (https://results.elections.myflorida.com/Index.asp?ElectionDate=8/23/2022&DATAMODE=)

For the races we were able to check, totals matched in every county except for the following: Walton, Seminole, Palm Beach, Clay, Nassau, Volusia.

Walton's precinct-level results are missing the Democratic US Senate primary results.

Seminole County had numerous small differences. The largest difference was 32 fewer votes in the precinct-level file for candidates PSU10RBRO and P22USSDDEM. Palm Beach, Clay, Nassau and Volusia counties have differences of less than three votes in one contest each. Full details can be found in the notebook linked below. It is not immediately clear why these differences exist.
'''

#Fifth section of README
  readme_p5 = '''\n
## Processing Steps
Visit the RDH GitHub and the processing script for this code [here]({github_link})

Please direct questions related to processing this dataset to info@redistrictingdatahub.org.
'''.format(github_link=github_link)

  full_readme = str(readme_p1)+str(readme_p2)+str(readme_p3)+str(readme_p4)+str(readme_p5)
  return full_readme

# %%
if not os.path.exists(file_folder):
    os.mkdir(file_folder)

with open(file_folder+"README.txt", 'w') as tf:
        tf.write(full_readme_text(title, retrieval_date, source, fields_dict, github_link))
