# %%
import geopandas as gp
import pandas as pd
import os
import numpy as np
import re
import pdv_functions as pdv

# %% [markdown]
# # Florida 2022 Election Results Processing
#
# Precinct-Level Data from [Florida Division of Elections](https://dos.myflorida.com/elections/data-statistics/elections-data/precinct-level-election-results/)
#
# County-Level Data to Run Checks from [Florida Department of State Election Archive](https://results.elections.myflorida.com/Index.asp?ElectionDate=11/8/2022&DATAMODE=)

# %%
#This Data is from the FL department of state, and can only be downloaded county by county
all_files = os.listdir("./raw-from-source/2022-gen-outputofficial/")

li = []
for i in all_files:
    if i not in [".DS_Store","DAD_PctResults20221108_Recount.txt"]:
        ref = "./raw-from-source/2022-gen-outputofficial/"
        file_ref = ref+i
        file_prev = pd.read_csv(file_ref,sep="\t",engine='python',index_col=None, header=None, dtype = str)
        li.append(file_prev)
frame = pd.concat(li, axis=0, ignore_index=True)
print(frame.shape)

# %%
# Rename the columns in the file

col_rename_dict = {0: 'County Code (Three-character abbreviation)',
 1: 'County Name',
 2: 'Election Number',
 3: 'Election Date',
 4: 'Election Name',
 5: 'Unique Precinct Identifier',
 6: 'Precinct Polling Location',
 7: 'Total Registered Voters',
 8: 'Total Registered Republicans',
 9: 'Total Registered Democrats',
 10: 'Total Registered All Other Parties',
 11: 'Contest Name',
 12: 'District',
 13: 'Contest Code (Florida’s 6 digit contest codes)',
 14: 'Candidate/Retention/IssueName/WriteInsCast/OverVotes/UnderVotes',
 15: 'Candidate Party (abbreviation)',
 16: 'Candidate Florida Voter Registration System ID Number',
 17: 'DOE Assigned Candidate Number or Retention/Issue Number',
 18: 'Vote Total'}

# %% [markdown]
# ## Compare the Dade Recount Data for State Leg 106:
#
# Note: The totals seemed much too large here, so I just used the original

# %%
# dade_og = pd.read_csv("./raw-from-source/2022-gen-outputofficial/DAD_PctResults20221108.txt",sep="\t",engine='python',index_col=None, header=None)
# recount = pd.read_csv("./raw-from-source/2022-gen-outputofficial/DAD_PctResults20221108_Recount.txt",sep="\t",engine='python',index_col=None, header=None)
# frame = frame[~((frame[0]=="DAD") & (frame[12]==" District 106"))]
# frame = pd.concat([frame, recount])

# %%
# Rename the columns and clean the dataframe
frame.rename(columns = col_rename_dict, inplace = True)
frame['Vote Total'] = frame['Vote Total'].astype(int)

# Set the Unique Precinct Identifier to the Precinct Polling Location, where the Unique Identifier is "N/A"
frame["Unique Precinct Identifier"] = np.where(frame["Unique Precinct Identifier"].isna(), frame["Precinct Polling Location"], frame["Unique Precinct Identifier"])

# %%
# Confirm there are no more "N/A" unique precinct identifiers
frame[frame["Unique Precinct Identifier"].isna()]
# Out:
# Empty DataFrame
# Columns: [County Code (Three-character abbreviation), County Name, Election Number, Election Date, Election Name, Unique Precinct Identifier, Precinct Polling Location, Total Registered Voters, Total Registered Republicans, Total Registered Democrats, Total Registered All Other Parties, Contest Name, District, Contest Code (Florida’s 6 digit contest codes), Candidate/Retention/IssueName/WriteInsCast/OverVotes/UnderVotes, Candidate Party (abbreviation), Candidate Florida Voter Registration System ID Number, DOE Assigned Candidate Number or Retention/Issue Number, Vote Total]
# Index: []

# %% [markdown]
# ## Filter Down to Relevant Races

# %%
races_list = ['United States Senator', 'Representative in Congress',
       'Governor and Lieutenant Governor', 'Attorney General',
       'Chief Financial Officer', 'Commissioner of Agriculture',
       'State Senator', 'State Representative',
 'Retention of Charles T. Canady','Retention of John D. Couriel','Retention of Jamie Grosshans',
 'Retention of Jorge Labarga','Retention of Ricky Polston',
 'Amendment No. 1: Limitation on Assessment of Real Property Used for Residential Purposes',
 'Amendment No. 2: Abolishing the Constitution Revision Commission',
 'Amendment No. 3: Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce']

# %%
#Filter to the presidential results
frame =frame[frame['Contest Name'].isin(races_list)]

#Filter out the OverVotes and UnderVotes
filtered_frame = frame[~frame['Candidate/Retention/IssueName/WriteInsCast/OverVotes/UnderVotes'].isin(['OverVotes', 'UnderVotes'])]

#Clean up the precinct column
filtered_frame['Precinct Polling Location'] = filtered_frame['Precinct Polling Location'].astype(str)

# #Deal with Dade County - note I did this for FL 2020 to join with the shapefile
# filtered_frame["mod_col"]=filtered_frame.apply(lambda row:int(float(row['Precinct Polling Location'].split("PRECINCT ")[1])) if row['County Code (Three-character abbreviation)']=="DAD" else row['Unique Precinct Identifier'], axis=1)

#Make the precinct column at least 4 digits
filtered_frame["mod_col"] = filtered_frame["Unique Precinct Identifier"].astype(str).str.zfill(4)
filtered_frame["modified_pre"]=filtered_frame["mod_col"].str.zfill(4)

#Make a column with the 3 letter county code and the precincts
filtered_frame["pct_std"]=filtered_frame['County Code (Three-character abbreviation)']+"-"+filtered_frame["modified_pre"]
# Out:
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/2598821685.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame['Precinct Polling Location'] = filtered_frame['Precinct Polling Location'].astype(str)
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/2598821685.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["mod_col"] = filtered_frame["Unique Precinct Identifier"].astype(str).str.zfill(4)
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/2598821685.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["mod_col"]=filtered_frame["mod_col"]
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/2598821685.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["modified_pre"]=filtered_frame["mod_col"].str.zfill(4)
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/2598821685.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["pct_std"]=filtered_frame['County Code (Three-character abbreviation)']+"-"+filtered_frame["modified_pre"]

# %%
# Cast the contest name and code columns to string to make the pivot col
filtered_frame["Contest Name"] = filtered_frame["Contest Name"].astype(str)
filtered_frame["Contest Code (Florida’s 6 digit contest codes)"] = filtered_frame["Candidate/Retention/IssueName/WriteInsCast/OverVotes/UnderVotes"].astype(str)

# Fill in the blank candidate party with "WRI"
filtered_frame['Candidate Party (abbreviation)'] = filtered_frame['Candidate Party (abbreviation)'].map({' ':'WRI'}).fillna(filtered_frame['Candidate Party (abbreviation)'])

# Create the pivot column with the contest name and the candidate
filtered_frame["pivot_col"] = filtered_frame["Contest Name"] + "-:-" + filtered_frame["Contest Code (Florida’s 6 digit contest codes)"] + "-:-" + "PARTY:" +filtered_frame['Candidate Party (abbreviation)']

# Where it exists, add in the district to the pivot column
filtered_frame["pivot_col"] = np.where(filtered_frame["District"]!=" ",filtered_frame["pivot_col"] + "-:-" + filtered_frame["District"], filtered_frame["pivot_col"])

# Removing all of the specific party registration data, as it looks like the state doesn't have that
for val in ['Total Registered Republicans','Total Registered Democrats', 'Total Registered All Other Parties']:
    print(filtered_frame[val].unique())
    
filtered_frame.drop(['Election Number', 'Election Date', 'Total Registered Republicans','Total Registered Democrats', 'Total Registered All Other Parties','Candidate Florida Voter Registration System ID Number','DOE Assigned Candidate Number or Retention/Issue Number'], axis = 1, inplace = True)
# Out:
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/3180966468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["Contest Name"] = filtered_frame["Contest Name"].astype(str)
# /var/folders/1t/0q4w6hm92mg_zxd84dfxmq3m0000gn/T/ipykernel_75893/3180966468.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_frame["Contest Code (Florida’s 6 digit contest codes)"] = filtered_frame["Candidate/Retention/IssueName/WriteInsCast/OverVotes/UnderVotes"].astype(str)

# %%
#Pivot the data so that each row has all the results from that precinct
pivoted_2022 = pd.pivot_table(filtered_frame, values=['Vote Total'], index=["pct_std",'County Code (Three-character abbreviation)','County Name',"Unique Precinct Identifier","Precinct Polling Location"],columns=['pivot_col'],aggfunc=sum)

#Clean up the indices
pivoted_2022.reset_index(inplace=True,drop=False)

pivoted_2022.columns = [' '.join(col).strip() for col in pivoted_2022.columns.values]

pivoted_2022.columns = pivoted_2022.columns.str.replace("Vote Total ","")

pivoted_2022 = pivoted_2022.fillna(0)

# %% [markdown]
# # Rename Columns

# %%
keep_names = ['pct_std', 'County Code (Three-character abbreviation)', 'County Name',
       'Unique Precinct Identifier', 'Precinct Polling Location']

# %%
def get_race(contest):
    if "President" in contest:
        level = "PRE"
    elif ("Representative in Congress" in contest or "State Senator" in contest or "State Representative" in contest):
        contest_info = get_level_dist(contest)
        level = contest_info[0]+contest_info[1]        
    else:
        print(contest)
        raise ValueError
    return level

# %%
def get_election_type(contest):
    return "G"


def get_race(contest):
    mod_level = ""
    level = contest.split("-:-")[0]
    level_change_dict = {
        'Attorney General':'ATG',
        'Court of Appeals Judge':'CAJ',
        'Governor':'GOV',
        'State Controller':'CNT',
        'STATE QUESTION':'SQ',
        'Secretary of State':'SOS',
        'State Representative':'SL',
        'State Senator':'SU',
        'President':'PRE',
        'United States Senator':'USS',
        'Amendment':'A',
        'State Treasurer':'TRE',
        'Retention of':'SCJ',
        'Representative in Congress':'CON',
        'Chief Financial Officer':'CFO',
        'Commissioner of Agriculture':'COA'}
    for val in level_change_dict.keys():
        if val in level:
            mod_level = level_change_dict[val]
            break
    if mod_level == "":
        print("NO CONTEST", contest)
    if mod_level == 'A':
        mod_level += level.split(":")[0].split(" ")[-1]
        
    return mod_level

def get_party(contest):
    if "Amendment" in contest:
        return ""
    elif "Retention of" in contest:
        return contest.split("-:-")[1][0].upper()
    elif "PARTY:DEM" in contest:
        return "D"
    elif "PARTY:REP" in contest:
        return "R"
    elif "PARTY:LPF" in contest:
        return "L"
    ## Reform -> F
    elif "PARTY:REF" in contest:
        return "O"
    elif "PARTY:PSL" in contest:
        return "S"
    elif "PARTY:GRE" in contest:
        return "G"
    elif "PARTY:CPF" in contest:
        return "C"
    elif "PARTY:WRI" in contest:
        return "O"
    elif "PARTY:NPA" or "PARTY:NOP" in contest:
        return "N"
    else:
        print(contest)
        return ValueError
    
def get_name(contest):
    if "No for Rejection" in contest:
        return "NO"
    elif "Yes for Approval" in contest:
        return "YES"
    
    if "Retention of" in contest:
        candidate = contest.split("-:-")[0]
        return candidate.upper().split(" ")[-1][0:3]
    else:
        candidate = contest.split("-:-")[1]
        if candidate == "None Of These Candidates":
            return "WRI"
        candidate = candidate.upper()
        if "Governor" in contest:
            likely_last = candidate.split(" ")[0]
        else:
            likely_last = candidate.split(" ")[-1]
        if likely_last in ["JR","III","II","SR"]:
            return candidate.split(" ")[-2][0:3]
        else:
            return likely_last[0:3]
    
def get_district(contest):
    district_string = contest.split("-:-")[3]
    district_string = district_string.strip()
    likely = district_string.split(" ")[1]
    if "Representative in Congress" in contest or 'State Senator' in contest:
        level = 2
    elif 'State Representative' in contest:
        level = 3
    return likely.zfill(level)

contest_name_change_dict = {}

duplicate_value_list = []
for contest in pivoted_2022.columns:
    if contest not in keep_names:
        # Add in a condition about the 20
#         print("E-type", get_election_type(contest))
#         print("Race", get_race(contest))
#         print("Party", get_party(contest))
#         print("Name", get_name(contest))
        if "Representative in Congress" in contest or 'State Representative' in contest or 'State Senator' in contest:
            value = get_election_type(contest) + get_race(contest) + get_district(contest) + get_party(contest) + get_name(contest)
        else:
            value = get_election_type(contest) + "22" + get_race(contest) + get_party(contest) + get_name(contest)
        if value in contest_name_change_dict.values():
            duplicate_value_list.append(value)
        print(len(value))
        contest_name_change_dict[contest] = value 

if len(duplicate_value_list) > 0:
    print("DUPLICATE VALUES")
    for val in [(k,v) for k, v in contest_name_change_dict.items() if v in duplicate_value_list]:
        print(val)
# Out:
# 7
# 8
# 7
# 8
# 7
# 8
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 10
# 10
# 10
# 10
# 10
# 10

# %%
# Clean up edge cases
contest_name_change_dict['Representative in Congress-:-Corinna Balderramos Robinson-:-PARTY:DEM-:- District 21'] = 'GCON21DBAL'
contest_name_change_dict['State Representative-:-Christian De La Torre-:-PARTY:REP-:- District 46']= 'GSL046RDEL'
contest_name_change_dict['State Representative-:-Karen Gonzalez Pittman-:-PARTY:REP-:- District 65']= 'GSL065RGON'
contest_name_change_dict['State Representative-:-LaVon Bracy Davis-:-PARTY:DEM-:- District 40']= 'GSL040DBRA'
contest_name_change_dict['State Representative-:-Maura Cruz Lanz-:-PARTY:REP-:- District 64']='GSL064RCRU'
contest_name_change_dict['State Representative-:-Yvonne Hayes Hinson-:-PARTY:DEM-:- District 21']='GSL021DHAY'

# Create a sorted dictionary to sort the columns of the final dataframe
sorted_contest_name_change_dict = dict(sorted(contest_name_change_dict.items(), key=lambda x:x[1]))

# %%
# Export the candidate name change dictionary for the README
holder = pd.DataFrame(sorted_contest_name_change_dict.values(),sorted_contest_name_change_dict.keys())
holder.to_csv("./field_names.csv", index = True)

# %%
# Rename the dataframe using this dictionary
pivoted_2022.rename(columns = contest_name_change_dict, inplace = True)

# Define a reversed version of the dictionary
contest_name_change_dict_rev = {v:k for k,v in contest_name_change_dict.items()}

# %% [markdown]
# ## Add a COUNTYFP column

# %%
FIPS_dict = {'Alachua': '001',
 'Baker': '003',
 'Bay': '005',
 'Bradford': '007',
 'Brevard': '009',
 'Broward': '011',
 'Calhoun': '013',
 'Charlotte': '015',
 'Citrus': '017',
 'Clay': '019',
 'Collier': '021',
 'Columbia': '023',
 'Desoto': '027',
 'Dixie': '029',
 'Duval': '031',
 'Escambia': '033',
 'Flagler': '035',
 'Franklin': '037',
 'Gadsden': '039',
 'Gilchrist': '041',
 'Glades': '043',
 'Gulf': '045',
 'Hamilton': '047',
 'Hardee': '049',
 'Hendry': '051',
 'Hernando': '053',
 'Highlands': '055',
 'Hillsborough': '057',
 'Holmes': '059',
 'Indian River': '061',
 'Jackson': '063',
 'Jefferson': '065',
 'Lafayette': '067',
 'Lake': '069',
 'Lee': '071',
 'Leon': '073',
 'Levy': '075',
 'Liberty': '077',
 'Madison': '079',
 'Manatee': '081',
 'Marion': '083',
 'Martin': '085',
 'Miami-Dade': '086',
 'Monroe': '087',
 'Nassau': '089',
 'Okaloosa': '091',
 'Okeechobee': '093',
 'Orange': '095',
 'Osceola': '097',
 'Palm Beach': '099',
 'Pasco': '101',
 'Pinellas': '103',
 'Polk': '105',
 'Putnam': '107',
 'St. Johns': '109',
 'St. Lucie': '111',
 'Santa Rosa': '113',
 'Sarasota': '115',
 'Seminole': '117',
 'Sumter': '119',
 'Suwannee': '121',
 'Taylor': '123',
 'Union': '125',
 'Volusia': '127',
 'Wakulla': '129',
 'Walton': '131',
 'Washington': '133'}

# %%
pivoted_2022["COUNTYFP"] = pivoted_2022["County Name"].map(FIPS_dict).fillna(pivoted_2022["County Name"])
print(pivoted_2022["COUNTYFP"].unique())

# %% [markdown]
# ## Additional Cleaning

# %%
pivoted_2022.rename(columns = {"pct_std":"UNIQUE_ID"}, inplace = True)
pivoted_2022[pivoted_2022["UNIQUE_ID"].str.contains("nan")]
for col in list(contest_name_change_dict.values()):
    pivoted_2022[col] = pivoted_2022[col].astype(int)

# %% [markdown]
# ## Election Totals Checks

# %%
alt_source = pd.read_csv("./raw-from-source/11082022Election.txt", encoding = "latin-1", sep="\t")

interested_races = ['United States Senator', 'United States Representative',
       'Governor', 'Attorney General', 'Chief Financial Officer',
       'Commissioner of Agriculture',  'State Senator',
       'State Representative',
       'Shall Justice Ricky Polston be retained in Office?',
       'Shall Justice Charles T. Canady be retained in Office?',
       'Shall Justice John D. Couriel be retained in Office?',
       'Shall Justice Jamie Grosshans be retained in Office?',
       'Shall Justice Jorge Labarga be retained in Office?',
      
       'Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce',
       'Limitation on Assessment of Real Property Used for Residential Purposes',
       'Abolishing the Constitution Revision Commission']

alt_source = alt_source[alt_source["OfficeDesc"].isin(interested_races)]

# Add in the District Number where relevant
alt_source["OfficeDesc_Detailed"] = alt_source.apply(lambda x: x["OfficeDesc"] + " "+str(int(x["Juris1num"])) if not pd.isna(x["Juris1num"]) else x["OfficeDesc"], axis = 1)

# %%
# Combine the office, candidate first name and candidate last name, clean where all of that info isn't available
alt_source["cand_col"] = alt_source["OfficeDesc_Detailed"] + "-:-" + alt_source["CanNameLast"] + ", " + alt_source["CanNameFirst"] + "-:-" + alt_source["PartyCode"]
alt_source.loc[alt_source["CanNameFirst"].isna(),"cand_col"] = alt_source["OfficeDesc_Detailed"] + "-:-" + alt_source["CanNameLast"]  + "-:-" + alt_source["PartyCode"]

# %%
pivoted_alt = pd.pivot_table(alt_source, index = "CountyName", columns = "cand_col", values = "CanVotes", aggfunc = sum)

pivoted_alt.reset_index(inplace = True, drop = False)

pivoted_alt = pivoted_alt.fillna(0)

# %%
def get_election_type(contest):
    return "G"


def get_race(contest):
    mod_level = ""
    level = contest.split("-:-")[0]
    level_change_dict = {
        'Attorney General':'ATG',
        'Court of Appeals Judge':'CAJ',
        'Lieutenant Governor':'LTG',
        'Governor':'GOV',
        'State Controller':'CNT',
        'STATE QUESTION':'SQ',
        'Secretary of State':'SOS',
        'State Representative':'SL',
        'State Senator':'SU',
        'President':'PRE',
        'United States Senator':'USS',
        'Amendment':'A',
        'State Treasurer':'TRE',
        'retained in Office':'SCJ',
        'United States Representative':'CON',
        'Chief Financial Officer':'CFO',
        'Commissioner of Agriculture':'COA'}
    for val in level_change_dict.keys():
        if val in level:
            mod_level = level_change_dict[val]
            break
    if mod_level == "":
        print("NO CONTEST", contest)
    if mod_level == 'A':
        mod_level += level.split(":")[0].split(" ")[-1]
        
    return mod_level

def get_party(contest):
    contest = contest.split("-:-")[2]
    if "Amendment" in contest:
        return ""
    elif "Retention of" in contest:
        return contest.split("-:-")[1][0].upper()
    elif "DEM" in contest:
        return "D"
    elif "REP" in contest:
        return "R"
    elif "LPF" in contest:
        return "L"
    ## Reform -> F
    elif "REF" in contest:
        return "O"
    elif "PSL" in contest:
        return "S"
    elif "GRE" in contest:
        return "G"
    elif "CPF" in contest:
        return "C"
    elif "WRI" in contest:
        return "O"
    elif "NPA" or "NOP" in contest:
        return "N"
    else:
        print(contest)
        return ValueError
    
def get_name(contest):
    if "No for Rejection" in contest:
        return "NO"
    elif "Yes for Approval" in contest:
        return "YES"
    
    if "Retention of" in contest:
        candidate = contest.split("-:-")[0]
        return candidate.upper().split(" ")[-1][0:3]
    else:
        candidate = contest.split("-:-")[1]
        if candidate == "None Of These Candidates":
            return "WRI"
        candidate = candidate.upper()
#         candidate = candidate.replace(" ", "")
        if "Governor" in contest:
            likely_last = candidate.split(" ")[1]
        else:
            likely_last = candidate.split(" ")[0]
        if likely_last in ["JR","III","II","SR"]:
            return candidate.split(" ")[-2][0:3]
        else:
            return likely_last[0:3]
    
def get_district(contest):
    district_string = contest.split("-:-")[0]
    district_string = district_string.strip()
    likely = district_string.split(" ")[-1]
    if 'State Representative' in contest:
        level = 3
    else:
        level = 2

    return likely.zfill(level)

contest_name_change_dict_second = {}

duplicate_value_list = []
for contest in pivoted_alt.columns:
    if contest != "CountyName":
        print(contest)
        print("E-type", get_election_type(contest))
        print("Race", get_race(contest))
        print("Party", get_party(contest))
        print("Name", get_name(contest))
        if "United States Representative" in contest or 'State Representative' in contest or 'State Senator' in contest:
            value = get_election_type(contest) + get_race(contest) + get_district(contest) + get_party(contest) + get_name(contest)
        else:
            value = get_election_type(contest) + "22" + get_race(contest) + get_party(contest) + get_name(contest)
        if value in contest_name_change_dict_second.values():
            duplicate_value_list.append(value)
        print(len(value))
        contest_name_change_dict_second[contest] = value 

if len(duplicate_value_list) > 0:
    print("DUPLICATE VALUES")
    for val in [(k,v) for k, v in contest_name_change_dict_second.items() if v in duplicate_value_list]:
        print(val)
# Out:
# Abolishing the Constitution Revision Commission-:-No for Rejection-:-NOP
# E-type G
# NO CONTEST Abolishing the Constitution Revision Commission-:-No for Rejection-:-NOP
# Race
# Party N
# Name NO
# NO CONTEST Abolishing the Constitution Revision Commission-:-No for Rejection-:-NOP
# 6
# Abolishing the Constitution Revision Commission-:-Yes for Approval-:-NOP
# E-type G
# NO CONTEST Abolishing the Constitution Revision Commission-:-Yes for Approval-:-NOP
# Race
# Party N
# Name YES
# NO CONTEST Abolishing the Constitution Revision Commission-:-Yes for Approval-:-NOP
# 7
# Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-No for Rejection-:-NOP
# E-type G
# NO CONTEST Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-No for Rejection-:-NOP
# Race
# Party N
# Name NO
# NO CONTEST Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-No for Rejection-:-NOP
# 6
# Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-Yes for Approval-:-NOP
# E-type G
# NO CONTEST Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-Yes for Approval-:-NOP
# Race
# Party N
# Name YES
# NO CONTEST Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-Yes for Approval-:-NOP
# 7
# Attorney General-:-Ayala, Aramis-:-DEM
# E-type G
# Race ATG
# Party D
# Name AYA
# 10
# Attorney General-:-Moody, Ashley-:-REP
# E-type G
# Race ATG
# Party R
# Name MOO
# 10
# Chief Financial Officer-:-Hattersley, Adam-:-DEM
# E-type G
# Race CFO
# Party D
# Name HAT
# 10
# Chief Financial Officer-:-Patronis, Jimmy-:-REP
# E-type G
# Race CFO
# Party R
# Name PAT
# 10
# Commissioner of Agriculture-:-Blemur, Naomi-:-DEM
# E-type G
# Race COA
# Party D
# Name BLE
# 10
# Commissioner of Agriculture-:-Simpson, Wilton-:-REP
# E-type G
# Race COA
# Party R
# Name SIM
# 10
# Governor-:-Gibson, Gimenez-:-NPA
# E-type G
# Race GOV
# Party N
# Name GIM
# 10
# Governor-:-Hernandez, Crist-:-DEM
# E-type G
# Race GOV
# Party D
# Name CRI
# 10
# Governor-:-Nuñez, DeSantis-:-REP
# E-type G
# Race GOV
# Party R
# Name DES
# 10
# Governor-:-Rorabaugh, Roos-:-LPF
# E-type G
# Race GOV
# Party L
# Name ROO
# 10
# Limitation on Assessment of Real Property Used for Residential Purposes-:-No for Rejection-:-NOP
# E-type G
# NO CONTEST Limitation on Assessment of Real Property Used for Residential Purposes-:-No for Rejection-:-NOP
# Race
# Party N
# Name NO
# NO CONTEST Limitation on Assessment of Real Property Used for Residential Purposes-:-No for Rejection-:-NOP
# 6
# Limitation on Assessment of Real Property Used for Residential Purposes-:-Yes for Approval-:-NOP
# E-type G
# NO CONTEST Limitation on Assessment of Real Property Used for Residential Purposes-:-Yes for Approval-:-NOP
# Race
# Party N
# Name YES
# NO CONTEST Limitation on Assessment of Real Property Used for Residential Purposes-:-Yes for Approval-:-NOP
# 7
# Shall Justice Charles T. Canady be retained in Office?-:-No-:-NOP
# E-type G
# Race SCJ
# Party N
# Name NO
# 9
# Shall Justice Charles T. Canady be retained in Office?-:-Yes-:-NOP
# E-type G
# Race SCJ
# Party N
# Name YES
# 10
# Shall Justice Jamie Grosshans be retained in Office?-:-No-:-NOP
# E-type G
# Race SCJ
# Party N
# Name NO
# 9
# Shall Justice Jamie Grosshans be retained in Office?-:-Yes-:-NOP
# E-type G
# Race SCJ
# Party N
# Name YES
# 10
# Shall Justice John D. Couriel be retained in Office?-:-No-:-NOP
# E-type G
# Race SCJ
# Party N
# Name NO
# 9
# Shall Justice John D. Couriel be retained in Office?-:-Yes-:-NOP
# E-type G
# Race SCJ
# Party N
# Name YES
# 10
# Shall Justice Jorge Labarga be retained in Office?-:-No-:-NOP
# E-type G
# Race SCJ
# Party N
# Name NO
# 9
# Shall Justice Jorge Labarga be retained in Office?-:-Yes-:-NOP
# E-type G
# Race SCJ
# Party N
# Name YES
# 10
# Shall Justice Ricky Polston be retained in Office?-:-No-:-NOP
# E-type G
# Race SCJ
# Party N
# Name NO
# 9
# Shall Justice Ricky Polston be retained in Office?-:-Yes-:-NOP
# E-type G
# Race SCJ
# Party N
# Name YES
# 10
# State Representative 1-:-Mathis, Franscine-:-DEM
# E-type G
# Race SL
# Party D
# Name MAT
# 10
# State Representative 1-:-Salzman, Michelle-:-REP
# E-type G
# Race SL
# Party R
# Name SAL
# 10
# State Representative 100-:-Gonzalez, Linda-:-DEM
# E-type G
# Race SL
# Party D
# Name GON
# 10
# State Representative 100-:-LaMarca, Chip-:-REP
# E-type G
# Race SL
# Party R
# Name LAM
# 10
# State Representative 101-:-Cassel, Hillary-:-DEM
# E-type G
# Race SL
# Party D
# Name CAS
# 10
# State Representative 101-:-Silla, Guy-:-REP
# E-type G
# Race SL
# Party R
# Name SIL
# 10
# State Representative 103-:-Bartleman, Robin-:-DEM
# E-type G
# Race SL
# Party D
# Name BAR
# 10
# State Representative 103-:-Navarini, George-:-REP
# E-type G
# Race SL
# Party R
# Name NAV
# 10
# State Representative 105-:-Parlatore, Vincent-:-REP
# E-type G
# Race SL
# Party R
# Name PAR
# 10
# State Representative 105-:-Woodson, Marie-:-DEM
# E-type G
# Race SL
# Party D
# Name WOO
# 10
# State Representative 106-:-Basabe, Fabián-:-REP
# E-type G
# Race SL
# Party R
# Name BAS
# 10
# State Representative 106-:-Leonard, Jordan-:-DEM
# E-type G
# Race SL
# Party D
# Name LEO
# 10
# State Representative 11-:-Garrison, Sam-:-REP
# E-type G
# Race SL
# Party R
# Name GAR
# 10
# State Representative 11-:-Jones, Cornelius-:-DEM
# E-type G
# Race SL
# Party D
# Name JON
# 10
# State Representative 113-:-D'Amico, Alessandro 'A.J.'-:-DEM
# E-type G
# Race SL
# Party D
# Name D'A
# 10
# State Representative 113-:-Lopez, Vicki-:-REP
# E-type G
# Race SL
# Party R
# Name LOP
# 10
# State Representative 114-:-Benna, Adam-:-DEM
# E-type G
# Race SL
# Party D
# Name BEN
# 10
# State Representative 114-:-Cabrera, Demi-:-REP
# E-type G
# Race SL
# Party R
# Name CAB
# 10
# State Representative 115-:-Davis, Christie-:-DEM
# E-type G
# Race SL
# Party D
# Name DAV
# 10
# State Representative 115-:-Garcia, Alina-:-REP
# E-type G
# Race SL
# Party R
# Name GAR
# 10
# State Representative 118-:-Farias, Johnny-:-DEM
# E-type G
# Race SL
# Party D
# Name FAR
# 10
# State Representative 118-:-Fernandez-Barquin, Juan-:-REP
# E-type G
# Race SL
# Party R
# Name FER
# 10
# State Representative 119-:-Gonzalez, Gabriel-:-DEM
# E-type G
# Race SL
# Party D
# Name GON
# 10
# State Representative 119-:-Porras, Juan-:-REP
# E-type G
# Race SL
# Party R
# Name POR
# 10
# State Representative 120-:-Gentle, Adam-:-DEM
# E-type G
# Race SL
# Party D
# Name GEN
# 10
# State Representative 120-:-Mooney, James 'Jim'-:-REP
# E-type G
# Race SL
# Party R
# Name MOO
# 10
# State Representative 13-:-Masline, LaCiara-:-NPA
# E-type G
# Race SL
# Party N
# Name MAS
# 10
# State Representative 13-:-Nixon, Angie-:-DEM
# E-type G
# Race SL
# Party D
# Name NIX
# 10
# State Representative 15-:-Black, Dean-:-REP
# E-type G
# Race SL
# Party R
# Name BLA
# 10
# State Representative 15-:-Steckloff, Jerry-:-WRI
# E-type G
# Race SL
# Party O
# Name STE
# 10
# State Representative 16-:-Hartley, Richard-:-WRI
# E-type G
# Race SL
# Party O
# Name HAR
# 10
# State Representative 16-:-Michael, Kiyan-:-REP
# E-type G
# Race SL
# Party R
# Name MIC
# 10
# State Representative 16-:-Moore, Harley-:-WRI
# E-type G
# Race SL
# Party O
# Name MOO
# 10
# State Representative 17-:-Anderson, Michael-:-DEM
# E-type G
# Race SL
# Party D
# Name AND
# 10
# State Representative 17-:-Baker, Jessica-:-REP
# E-type G
# Race SL
# Party R
# Name BAK
# 10
# State Representative 19-:-Morley, Adam-:-DEM
# E-type G
# Race SL
# Party D
# Name MOR
# 10
# State Representative 19-:-Renner, Paul-:-REP
# E-type G
# Race SL
# Party R
# Name REN
# 10
# State Representative 2-:-Andrade, Alex-:-REP
# E-type G
# Race SL
# Party R
# Name AND
# 10
# State Representative 2-:-Taylor, Carollyn-:-DEM
# E-type G
# Race SL
# Party D
# Name TAY
# 10
# State Representative 21-:-Hayes Hinson, Yvonne-:-DEM
# E-type G
# Race SL
# Party D
# Name HAY
# 10
# State Representative 21-:-Merton, Hollye-:-REP
# E-type G
# Race SL
# Party R
# Name MER
# 10
# State Representative 22-:-Clemons, Chuck-:-REP
# E-type G
# Race SL
# Party R
# Name CLE
# 10
# State Representative 22-:-Peters, Brandon-:-DEM
# E-type G
# Race SL
# Party D
# Name PET
# 10
# State Representative 25-:-Helfrich, Banks-:-NPA
# E-type G
# Race SL
# Party N
# Name HEL
# 10
# State Representative 25-:-Yarkosky, Taylor-:-REP
# E-type G
# Race SL
# Party R
# Name YAR
# 10
# State Representative 26-:-Kero, Linda-:-DEM
# E-type G
# Race SL
# Party D
# Name KER
# 10
# State Representative 26-:-Truenow, Keith-:-REP
# E-type G
# Race SL
# Party R
# Name TRU
# 10
# State Representative 28-:-Leek, Tom-:-REP
# E-type G
# Race SL
# Party R
# Name LEE
# 10
# State Representative 28-:-Navarra, John-:-DEM
# E-type G
# Race SL
# Party D
# Name NAV
# 10
# State Representative 29-:-Barnaby, Webster-:-REP
# E-type G
# Race SL
# Party R
# Name BAR
# 10
# State Representative 29-:-Karl, Rick-:-DEM
# E-type G
# Race SL
# Party D
# Name KAR
# 10
# State Representative 3-:-Maddox, Sandra-:-WRI
# E-type G
# Race SL
# Party O
# Name MAD
# 10
# State Representative 3-:-Rudman, Joel-:-REP
# E-type G
# Race SL
# Party R
# Name RUD
# 10
# State Representative 30-:-Baker, Vic-:-WRI
# E-type G
# Race SL
# Party O
# Name BAK
# 10
# State Representative 30-:-Tramont, Chase-:-REP
# E-type G
# Race SL
# Party R
# Name TRA
# 10
# State Representative 33-:-Fine, Randy-:-REP
# E-type G
# Race SL
# Party R
# Name FIN
# 10
# State Representative 33-:-Yantz, Anthony-:-DEM
# E-type G
# Race SL
# Party D
# Name YAN
# 10
# State Representative 34-:-Brackett, Robert-:-REP
# E-type G
# Race SL
# Party R
# Name BRA
# 10
# State Representative 34-:-Greb, Karen-:-DEM
# E-type G
# Race SL
# Party D
# Name GRE
# 10
# State Representative 35-:-Bagga, Rishi-:-DEM
# E-type G
# Race SL
# Party D
# Name BAG
# 10
# State Representative 35-:-Hawkins, Fred-:-REP
# E-type G
# Race SL
# Party R
# Name HAW
# 10
# State Representative 36-:-Plakon, Rachel-:-REP
# E-type G
# Race SL
# Party R
# Name PLA
# 10
# State Representative 36-:-Poulalion, Deborah-:-DEM
# E-type G
# Race SL
# Party D
# Name POU
# 10
# State Representative 37-:-Plasencia, Susan-:-REP
# E-type G
# Race SL
# Party R
# Name PLA
# 10
# State Representative 37-:-Smith, Carlos-:-DEM
# E-type G
# Race SL
# Party D
# Name SMI
# 10
# State Representative 38-:-Henry, Sarah-:-DEM
# E-type G
# Race SL
# Party D
# Name HEN
# 10
# State Representative 38-:-Smith, David-:-REP
# E-type G
# Race SL
# Party R
# Name SMI
# 10
# State Representative 39-:-Bankson, Doug-:-REP
# E-type G
# Race SL
# Party R
# Name BAN
# 10
# State Representative 39-:-Hughes, Tiffany-:-DEM
# E-type G
# Race SL
# Party D
# Name HUG
# 10
# State Representative 40-:-Bracy Davis, LaVon-:-DEM
# E-type G
# Race SL
# Party D
# Name BRA
# 10
# State Representative 40-:-Robertson, Nate-:-REP
# E-type G
# Race SL
# Party R
# Name ROB
# 10
# State Representative 41-:-Antone, Bruce-:-DEM
# E-type G
# Race SL
# Party D
# Name ANT
# 10
# State Representative 41-:-Harris, Robin-:-GRE
# E-type G
# Race SL
# Party G
# Name HAR
# 10
# State Representative 42-:-Eskamani, Anna-:-DEM
# E-type G
# Race SL
# Party D
# Name ESK
# 10
# State Representative 42-:-Jackson, Bonnie-:-REP
# E-type G
# Race SL
# Party R
# Name JAC
# 10
# State Representative 43-:-Lopez, Johanna-:-DEM
# E-type G
# Race SL
# Party D
# Name LOP
# 10
# State Representative 43-:-Wright, Christopher-:-REP
# E-type G
# Race SL
# Party R
# Name WRI
# 10
# State Representative 45-:-Amesty, Carolina-:-REP
# E-type G
# Race SL
# Party R
# Name AME
# 10
# State Representative 45-:-Braswell, Allie-:-DEM
# E-type G
# Race SL
# Party D
# Name BRA
# 10
# State Representative 46-:-Arrington, Kristen-:-DEM
# E-type G
# Race SL
# Party D
# Name ARR
# 10
# State Representative 46-:-De La Torre, Christian-:-REP
# E-type G
# Race SL
# Party R
# Name DE
# 9
# State Representative 46-:-Rivera, Ivan-:-NPA
# E-type G
# Race SL
# Party N
# Name RIV
# 10
# State Representative 47-:-Nieves, Anthony-:-DEM
# E-type G
# Race SL
# Party D
# Name NIE
# 10
# State Representative 47-:-Stark, Paula-:-REP
# E-type G
# Race SL
# Party R
# Name STA
# 10
# State Representative 52-:-Marwah, Ash-:-DEM
# E-type G
# Race SL
# Party D
# Name MAR
# 10
# State Representative 52-:-Temple, John-:-REP
# E-type G
# Race SL
# Party R
# Name TEM
# 10
# State Representative 53-:-Holcomb, Jeff-:-REP
# E-type G
# Race SL
# Party R
# Name HOL
# 10
# State Representative 53-:-Laufenberg, Keith-:-DEM
# E-type G
# Race SL
# Party D
# Name LAU
# 10
# State Representative 54-:-Maggard, Randy-:-REP
# E-type G
# Race SL
# Party R
# Name MAG
# 10
# State Representative 54-:-Otwell, Ryan-:-NPA
# E-type G
# Race SL
# Party N
# Name OTW
# 10
# State Representative 54-:-Staver, Brian-:-DEM
# E-type G
# Race SL
# Party D
# Name STA
# 10
# State Representative 55-:-Hacker, Charles 'C.J.'-:-CPF
# E-type G
# Race SL
# Party C
# Name HAC
# 10
# State Representative 55-:-Steele, Kevin-:-REP
# E-type G
# Race SL
# Party R
# Name STE
# 10
# State Representative 58-:-Berfield, Kimberly-:-REP
# E-type G
# Race SL
# Party R
# Name BER
# 10
# State Representative 58-:-Fensterwald, Bernard-:-DEM
# E-type G
# Race SL
# Party D
# Name FEN
# 10
# State Representative 59-:-Douglas, Dawn-:-DEM
# E-type G
# Race SL
# Party D
# Name DOU
# 10
# State Representative 59-:-Jacques, Berny-:-REP
# E-type G
# Race SL
# Party R
# Name JAC
# 10
# State Representative 60-:-Cross, Lindsay-:-DEM
# E-type G
# Race SL
# Party D
# Name CRO
# 10
# State Representative 60-:-Henson, Audrey-:-REP
# E-type G
# Race SL
# Party R
# Name HEN
# 10
# State Representative 61-:-Chaney, Linda-:-REP
# E-type G
# Race SL
# Party R
# Name CHA
# 10
# State Representative 61-:-Warwick, Janet-:-DEM
# E-type G
# Race SL
# Party D
# Name WAR
# 10
# State Representative 62-:-Brown, Jeremy-:-REP
# E-type G
# Race SL
# Party R
# Name BRO
# 10
# State Representative 62-:-Rayner, Michele-:-DEM
# E-type G
# Race SL
# Party D
# Name RAY
# 10
# State Representative 64-:-Cruz Lanz, Maura-:-REP
# E-type G
# Race SL
# Party R
# Name CRU
# 10
# State Representative 64-:-Valdés, Susan-:-DEM
# E-type G
# Race SL
# Party D
# Name VAL
# 10
# State Representative 65-:-Gonzalez Pittman, Karen-:-REP
# E-type G
# Race SL
# Party R
# Name GON
# 10
# State Representative 65-:-McDonald, Jen-:-DEM
# E-type G
# Race SL
# Party D
# Name MCD
# 10
# State Representative 66-:-Koster, Traci-:-REP
# E-type G
# Race SL
# Party R
# Name KOS
# 10
# State Representative 66-:-Tillery, David-:-DEM
# E-type G
# Race SL
# Party D
# Name TIL
# 10
# State Representative 67-:-Bonano, Lisette-:-REP
# E-type G
# Race SL
# Party R
# Name BON
# 10
# State Representative 67-:-Driskell, Fentrice-:-DEM
# E-type G
# Race SL
# Party D
# Name DRI
# 10
# State Representative 68-:-McClure, Lawrence-:-REP
# E-type G
# Race SL
# Party R
# Name MCC
# 10
# State Representative 68-:-Wright, Lorissa-:-DEM
# E-type G
# Race SL
# Party D
# Name WRI
# 10
# State Representative 69-:-Alvarez, Daniel-:-REP
# E-type G
# Race SL
# Party R
# Name ALV
# 10
# State Representative 69-:-Learned, Andrew-:-DEM
# E-type G
# Race SL
# Party D
# Name LEA
# 10
# State Representative 70-:-Beltran, Mike-:-REP
# E-type G
# Race SL
# Party R
# Name BEL
# 10
# State Representative 70-:-Salazar, Eleuterio 'Junior'-:-DEM
# E-type G
# Race SL
# Party D
# Name SAL
# 10
# State Representative 72-:-Dameus, Roberts-:-DEM
# E-type G
# Race SL
# Party D
# Name DAM
# 10
# State Representative 72-:-Gregory, Tommy-:-REP
# E-type G
# Race SL
# Party R
# Name GRE
# 10
# State Representative 73-:-McFarland, Fiona-:-REP
# E-type G
# Race SL
# Party R
# Name MCF
# 10
# State Representative 73-:-Reich, Derek-:-DEM
# E-type G
# Race SL
# Party D
# Name REI
# 10
# State Representative 77-:-Engelhart, Eric-:-DEM
# E-type G
# Race SL
# Party D
# Name ENG
# 10
# State Representative 77-:-Esposito, Tiffany-:-REP
# E-type G
# Race SL
# Party R
# Name ESP
# 10
# State Representative 78-:-Persons-Mulicka, Jenna-:-REP
# E-type G
# Race SL
# Party R
# Name PER
# 10
# State Representative 78-:-Sapp, Howard-:-DEM
# E-type G
# Race SL
# Party D
# Name SAP
# 10
# State Representative 8-:-Bender, Curt-:-REP
# E-type G
# Race SL
# Party R
# Name BEN
# 10
# State Representative 8-:-Franklin, Gallop-:-DEM
# E-type G
# Race SL
# Party D
# Name FRA
# 10
# State Representative 80-:-Botana, Adam-:-REP
# E-type G
# Race SL
# Party R
# Name BOT
# 10
# State Representative 80-:-Schlayer, Mitchel-:-DEM
# E-type G
# Race SL
# Party D
# Name SCH
# 10
# State Representative 84-:-Blanton, Forest-:-DEM
# E-type G
# Race SL
# Party D
# Name BLA
# 10
# State Representative 84-:-Trabulsy, Dana-:-REP
# E-type G
# Race SL
# Party R
# Name TRA
# 10
# State Representative 85-:-Overdorf, Toby-:-REP
# E-type G
# Race SL
# Party R
# Name OVE
# 10
# State Representative 85-:-Tucker, Curtis-:-DEM
# E-type G
# Race SL
# Party D
# Name TUC
# 10
# State Representative 86-:-Denzel, Raymond-:-DEM
# E-type G
# Race SL
# Party D
# Name DEN
# 10
# State Representative 86-:-Snyder, John-:-REP
# E-type G
# Race SL
# Party R
# Name SNY
# 10
# State Representative 87-:-Caruso, Mike-:-REP
# E-type G
# Race SL
# Party R
# Name CAR
# 10
# State Representative 87-:-Osta, Sienna-:-DEM
# E-type G
# Race SL
# Party D
# Name OST
# 10
# State Representative 88-:-Edmonds, Jervonte-:-DEM
# E-type G
# Race SL
# Party D
# Name EDM
# 10
# State Representative 88-:-Stevens, Roz-:-REP
# E-type G
# Race SL
# Party R
# Name STE
# 10
# State Representative 89-:-Silvers, David-:-DEM
# E-type G
# Race SL
# Party D
# Name SIL
# 10
# State Representative 89-:-Zapata, Daniel-:-REP
# E-type G
# Race SL
# Party R
# Name ZAP
# 10
# State Representative 90-:-Casello, Joseph-:-DEM
# E-type G
# Race SL
# Party D
# Name CAS
# 10
# State Representative 90-:-Feit, Keith-:-REP
# E-type G
# Race SL
# Party R
# Name FEI
# 10
# State Representative 91-:-Gossett-Seidman, Peggy-:-REP
# E-type G
# Race SL
# Party R
# Name GOS
# 10
# State Representative 91-:-Thomson, Andy-:-DEM
# E-type G
# Race SL
# Party D
# Name THO
# 10
# State Representative 92-:-Hernandez, Dorcas-:-REP
# E-type G
# Race SL
# Party R
# Name HER
# 10
# State Representative 92-:-Skidmore, Kelly-:-DEM
# E-type G
# Race SL
# Party D
# Name SKI
# 10
# State Representative 93-:-Banionis, Saulis-:-REP
# E-type G
# Race SL
# Party R
# Name BAN
# 10
# State Representative 93-:-Waldron, Katherine-:-DEM
# E-type G
# Race SL
# Party D
# Name WAL
# 10
# State Representative 94-:-Davis, Terence-:-DEM
# E-type G
# Race SL
# Party D
# Name DAV
# 10
# State Representative 94-:-Roth, Rick-:-REP
# E-type G
# Race SL
# Party R
# Name ROT
# 10
# State Representative 96-:-Daley, Dan-:-DEM
# E-type G
# Race SL
# Party D
# Name DAL
# 10
# State Representative 96-:-Hague, Jenna-:-REP
# E-type G
# Race SL
# Party R
# Name HAG
# 10
# State Senator 1-:-Broxson, Doug-:-REP
# E-type G
# Race SU
# Party R
# Name BRO
# 9
# State Senator 1-:-Nichols, Charlie-:-DEM
# E-type G
# Race SU
# Party D
# Name NIC
# 9
# State Senator 10-:-Brodeur, Jason-:-REP
# E-type G
# Race SU
# Party R
# Name BRO
# 9
# State Senator 10-:-Goff-Marcil, Joy-:-DEM
# E-type G
# Race SU
# Party D
# Name GOF
# 9
# State Senator 11-:-Ingoglia, Blaise-:-REP
# E-type G
# Race SU
# Party R
# Name ING
# 9
# State Senator 11-:-Moore, Brian-:-GRE
# E-type G
# Race SU
# Party G
# Name MOO
# 9
# State Senator 12-:-Burton, Colleen-:-REP
# E-type G
# Race SU
# Party R
# Name BUR
# 9
# State Senator 12-:-Dokur, Veysel-:-DEM
# E-type G
# Race SU
# Party D
# Name DOK
# 9
# State Senator 13-:-Baxley, Dennis-:-REP
# E-type G
# Race SU
# Party R
# Name BAX
# 9
# State Senator 13-:-Dukes, Stephanie-:-DEM
# E-type G
# Race SU
# Party D
# Name DUK
# 9
# State Senator 14-:-Collins, Jay-:-REP
# E-type G
# Race SU
# Party R
# Name COL
# 9
# State Senator 14-:-Cruz, Janet-:-DEM
# E-type G
# Race SU
# Party D
# Name CRU
# 9
# State Senator 16-:-Paylan, Christina-:-REP
# E-type G
# Race SU
# Party R
# Name PAY
# 9
# State Senator 16-:-Rouson, Darryl-:-DEM
# E-type G
# Race SU
# Party D
# Name ROU
# 9
# State Senator 17-:-Dixon, Steve-:-REP
# E-type G
# Race SU
# Party R
# Name DIX
# 9
# State Senator 17-:-Stewart, Linda-:-DEM
# E-type G
# Race SU
# Party D
# Name STE
# 9
# State Senator 18-:-DiCeglie, Nick-:-REP
# E-type G
# Race SU
# Party R
# Name DIC
# 9
# State Senator 18-:-Ortiz, Eunic-:-DEM
# E-type G
# Race SU
# Party D
# Name ORT
# 9
# State Senator 2-:-Trumbull, Jay-:-REP
# E-type G
# Race SU
# Party R
# Name TRU
# 9
# State Senator 2-:-Zonia, Carolynn-:-DEM
# E-type G
# Race SU
# Party D
# Name ZON
# 9
# State Senator 21-:-Hooper, Ed-:-REP
# E-type G
# Race SU
# Party R
# Name HOO
# 9
# State Senator 21-:-Lionheart, Amaro-:-DEM
# E-type G
# Race SU
# Party D
# Name LIO
# 9
# State Senator 23-:-Burgess, Danny-:-REP
# E-type G
# Race SU
# Party R
# Name BUR
# 9
# State Senator 23-:-Harvey, Mike-:-DEM
# E-type G
# Race SU
# Party D
# Name HAR
# 9
# State Senator 24-:-Ankner, Eric-:-REP
# E-type G
# Race SU
# Party R
# Name ANK
# 9
# State Senator 24-:-Powell, Bobby-:-DEM
# E-type G
# Race SU
# Party D
# Name POW
# 9
# State Senator 25-:-Torres, Victor-:-DEM
# E-type G
# Race SU
# Party D
# Name TOR
# 9
# State Senator 25-:-Vivaldi, Peter-:-REP
# E-type G
# Race SU
# Party R
# Name VIV
# 9
# State Senator 26-:-Berman, Lori-:-DEM
# E-type G
# Race SU
# Party D
# Name BER
# 9
# State Senator 26-:-Byers, Steve-:-REP
# E-type G
# Race SU
# Party R
# Name BYE
# 9
# State Senator 27-:-Albritton, Ben-:-REP
# E-type G
# Race SU
# Party R
# Name ALB
# 9
# State Senator 27-:-Proia, Christopher-:-DEM
# E-type G
# Race SU
# Party D
# Name PRO
# 9
# State Senator 3-:-Ausley, Loranne-:-DEM
# E-type G
# Race SU
# Party D
# Name AUS
# 9
# State Senator 3-:-Simon, Corey-:-REP
# E-type G
# Race SU
# Party R
# Name SIM
# 9
# State Senator 30-:-Polsky, Tina-:-DEM
# E-type G
# Race SU
# Party D
# Name POL
# 9
# State Senator 30-:-Reicherter, William 'Bill'-:-REP
# E-type G
# Race SU
# Party R
# Name REI
# 9
# State Senator 33-:-Martin, Jonathan-:-REP
# E-type G
# Race SU
# Party R
# Name MAR
# 9
# State Senator 33-:-Valenta, Robert-:-WRI
# E-type G
# Race SU
# Party O
# Name VAL
# 9
# State Senator 36-:-Garcia, Ileana-:-REP
# E-type G
# Race SU
# Party R
# Name GAR
# 9
# State Senator 36-:-Pacheco, Raquel-:-DEM
# E-type G
# Race SU
# Party D
# Name PAC
# 9
# State Senator 38-:-Calatayud, Alexis-:-REP
# E-type G
# Race SU
# Party R
# Name CAL
# 9
# State Senator 38-:-Perez, Janelle-:-DEM
# E-type G
# Race SU
# Party D
# Name PER
# 9
# State Senator 4-:-Smith, Sharmin-:-DEM
# E-type G
# Race SU
# Party D
# Name SMI
# 9
# State Senator 4-:-Yarborough, Clay-:-REP
# E-type G
# Race SU
# Party R
# Name YAR
# 9
# State Senator 5-:-Cooper, Patrick-:-WRI
# E-type G
# Race SU
# Party O
# Name COO
# 9
# State Senator 5-:-Davis, Tracie-:-DEM
# E-type G
# Race SU
# Party D
# Name DAV
# 9
# State Senator 5-:-Kumar, Binod-:-REP
# E-type G
# Race SU
# Party R
# Name KUM
# 9
# State Senator 8-:-Williams, Andrea-:-DEM
# E-type G
# Race SU
# Party D
# Name WIL
# 9
# State Senator 8-:-Wright, Tommy-:-REP
# E-type G
# Race SU
# Party R
# Name WRI
# 9
# State Senator 9-:-Long, Rodney-:-DEM
# E-type G
# Race SU
# Party D
# Name LON
# 9
# State Senator 9-:-Perry, Keith-:-REP
# E-type G
# Race SU
# Party R
# Name PER
# 9
# United States Representative 1-:-Gaetz, Matt-:-REP
# E-type G
# Race CON
# Party R
# Name GAE
# 10
# United States Representative 1-:-Jones, Rebekah-:-DEM
# E-type G
# Race CON
# Party D
# Name JON
# 10
# United States Representative 10-:-Frost, Maxwell-:-DEM
# E-type G
# Race CON
# Party D
# Name FRO
# 10
# United States Representative 10-:-Holic, Jason-:-NPA
# E-type G
# Race CON
# Party N
# Name HOL
# 10
# United States Representative 10-:-Jain, Usha-:-NPA
# E-type G
# Race CON
# Party N
# Name JAI
# 10
# United States Representative 10-:-Wimbish, Calvin-:-REP
# E-type G
# Race CON
# Party R
# Name WIM
# 10
# United States Representative 11-:-Munns, Shante-:-DEM
# E-type G
# Race CON
# Party D
# Name MUN
# 10
# United States Representative 11-:-Porter, Kevin-:-NPA
# E-type G
# Race CON
# Party N
# Name POR
# 10
# United States Representative 11-:-Webster, Daniel-:-REP
# E-type G
# Race CON
# Party R
# Name WEB
# 10
# United States Representative 12-:-Bilirakis, Gus-:-REP
# E-type G
# Race CON
# Party R
# Name BIL
# 10
# United States Representative 12-:-Smith, Charles-:-WRI
# E-type G
# Race CON
# Party O
# Name SMI
# 10
# United States Representative 12-:-Walker, Kimberly-:-DEM
# E-type G
# Race CON
# Party D
# Name WAL
# 10
# United States Representative 13-:-Craft, Frank-:-LPF
# E-type G
# Race CON
# Party L
# Name CRA
# 10
# United States Representative 13-:-Curnow, Jacob-:-WRI
# E-type G
# Race CON
# Party O
# Name CUR
# 10
# United States Representative 13-:-Luna, Anna-:-REP
# E-type G
# Race CON
# Party R
# Name LUN
# 10
# United States Representative 13-:-Lynn, Eric-:-DEM
# E-type G
# Race CON
# Party D
# Name LYN
# 10
# United States Representative 13-:-Young, Dwight-:-WRI
# E-type G
# Race CON
# Party O
# Name YOU
# 10
# United States Representative 14-:-Castor, Kathy-:-DEM
# E-type G
# Race CON
# Party D
# Name CAS
# 10
# United States Representative 14-:-Judge, James-:-REP
# E-type G
# Race CON
# Party R
# Name JUD
# 10
# United States Representative 15-:-Cohn, Alan-:-DEM
# E-type G
# Race CON
# Party D
# Name COH
# 10
# United States Representative 15-:-Lee, Laurel-:-REP
# E-type G
# Race CON
# Party R
# Name LEE
# 10
# United States Representative 16-:-Buchanan, Vern-:-REP
# E-type G
# Race CON
# Party R
# Name BUC
# 10
# United States Representative 16-:-Hartman, Ralph-:-WRI
# E-type G
# Race CON
# Party O
# Name HAR
# 10
# United States Representative 16-:-Schneider, Jan-:-DEM
# E-type G
# Race CON
# Party D
# Name SCH
# 10
# United States Representative 17-:-Kale, Andrea-:-DEM
# E-type G
# Race CON
# Party D
# Name KAL
# 10
# United States Representative 17-:-Murray, Theodore-:-NPA
# E-type G
# Race CON
# Party N
# Name MUR
# 10
# United States Representative 17-:-Steube, Greg-:-REP
# E-type G
# Race CON
# Party R
# Name STE
# 10
# United States Representative 18-:-Franklin, Scott-:-REP
# E-type G
# Race CON
# Party R
# Name FRA
# 10
# United States Representative 18-:-Hayden, Keith-:-NPA
# E-type G
# Race CON
# Party N
# Name HAY
# 10
# United States Representative 18-:-Serratore, Leonard-:-WRI
# E-type G
# Race CON
# Party O
# Name SER
# 10
# United States Representative 19-:-Banyai, Cindy-:-DEM
# E-type G
# Race CON
# Party D
# Name BAN
# 10
# United States Representative 19-:-Donalds, Byron-:-REP
# E-type G
# Race CON
# Party R
# Name DON
# 10
# United States Representative 19-:-Post, Patrick-:-WRI
# E-type G
# Race CON
# Party O
# Name POS
# 10
# United States Representative 2-:-Dunn, Neal-:-REP
# E-type G
# Race CON
# Party R
# Name DUN
# 10
# United States Representative 2-:-Lawson, Al-:-DEM
# E-type G
# Race CON
# Party D
# Name LAW
# 10
# United States Representative 20-:-Cherfilus-McCormick, Sheila-:-DEM
# E-type G
# Race CON
# Party D
# Name CHE
# 10
# United States Representative 20-:-Clark, Drew-:-REP
# E-type G
# Race CON
# Party R
# Name CLA
# 10
# United States Representative 21-:-Balderramos Robinson, Corinna-:-DEM
# E-type G
# Race CON
# Party D
# Name BAL
# 10
# United States Representative 21-:-Mast, Brian-:-REP
# E-type G
# Race CON
# Party R
# Name MAS
# 10
# United States Representative 22-:-Frankel, Lois-:-DEM
# E-type G
# Race CON
# Party D
# Name FRA
# 10
# United States Representative 22-:-Franzese, Dan-:-REP
# E-type G
# Race CON
# Party R
# Name FRA
# 10
# United States Representative 23-:-Budd, Joe-:-REP
# E-type G
# Race CON
# Party R
# Name BUD
# 10
# United States Representative 23-:-Moskowitz, Jared-:-DEM
# E-type G
# Race CON
# Party D
# Name MOS
# 10
# United States Representative 23-:-Napier, Mark-:-NPA
# E-type G
# Race CON
# Party N
# Name NAP
# 10
# United States Representative 23-:-Scott, Christine-:-NPA
# E-type G
# Race CON
# Party N
# Name SCO
# 10
# United States Representative 24-:-Navarro, Jesus-:-REP
# E-type G
# Race CON
# Party R
# Name NAV
# 10
# United States Representative 24-:-Wilson, Frederica-:-DEM
# E-type G
# Race CON
# Party D
# Name WIL
# 10
# United States Representative 25-:-Schultz, Debbie-:-DEM
# E-type G
# Race CON
# Party D
# Name SCH
# 10
# United States Representative 25-:-Spalding, Carla-:-REP
# E-type G
# Race CON
# Party R
# Name SPA
# 10
# United States Representative 26-:-Diaz-Balart, Mario-:-REP
# E-type G
# Race CON
# Party R
# Name DIA
# 10
# United States Representative 26-:-Olivo, Christine-:-DEM
# E-type G
# Race CON
# Party D
# Name OLI
# 10
# United States Representative 27-:-Salazar, María-:-REP
# E-type G
# Race CON
# Party R
# Name SAL
# 10
# United States Representative 27-:-Taddeo, Annette-:-DEM
# E-type G
# Race CON
# Party D
# Name TAD
# 10
# United States Representative 28-:-Asencio, Robert-:-DEM
# E-type G
# Race CON
# Party D
# Name ASE
# 10
# United States Representative 28-:-Gimenez, Carlos-:-REP
# E-type G
# Race CON
# Party R
# Name GIM
# 10
# United States Representative 28-:-Schaffer, Jeremiah-:-WRI
# E-type G
# Race CON
# Party O
# Name SCH
# 10
# United States Representative 3-:-Brooks, Linda-:-NPA
# E-type G
# Race CON
# Party N
# Name BRO
# 10
# United States Representative 3-:-Cammack, Kat-:-REP
# E-type G
# Race CON
# Party R
# Name CAM
# 10
# United States Representative 3-:-Hawk, Danielle-:-DEM
# E-type G
# Race CON
# Party D
# Name HAW
# 10
# United States Representative 4-:-Bean, Aaron-:-REP
# E-type G
# Race CON
# Party R
# Name BEA
# 10
# United States Representative 4-:-Holloway, LaShonda-:-DEM
# E-type G
# Race CON
# Party D
# Name HOL
# 10
# United States Representative 4-:-Koniz, Gary-:-WRI
# E-type G
# Race CON
# Party O
# Name KON
# 10
# United States Representative 6-:-Hannoush, Joseph-:-LPF
# E-type G
# Race CON
# Party L
# Name HAN
# 10
# United States Representative 6-:-Waltz, Michael-:-REP
# E-type G
# Race CON
# Party R
# Name WAL
# 10
# United States Representative 7-:-Green, Karen-:-DEM
# E-type G
# Race CON
# Party D
# Name GRE
# 10
# United States Representative 7-:-Mills, Cory-:-REP
# E-type G
# Race CON
# Party R
# Name MIL
# 10
# United States Representative 7-:-Pompey, Cardon-:-WRI
# E-type G
# Race CON
# Party O
# Name POM
# 10
# United States Representative 8-:-Posey, Bill-:-REP
# E-type G
# Race CON
# Party R
# Name POS
# 10
# United States Representative 8-:-Terry, Joanne-:-DEM
# E-type G
# Race CON
# Party D
# Name TER
# 10
# United States Representative 9-:-Moore, Scotty-:-REP
# E-type G
# Race CON
# Party R
# Name MOO
# 10
# United States Representative 9-:-Soto, Darren-:-DEM
# E-type G
# Race CON
# Party D
# Name SOT
# 10
# United States Senator-:-Demings, Val-:-DEM
# E-type G
# Race USS
# Party D
# Name DEM
# 10
# United States Senator-:-Ekpete, Uloma-:-WRI
# E-type G
# Race USS
# Party O
# Name EKP
# 10
# United States Senator-:-Grant, Steven-:-NPA
# E-type G
# Race USS
# Party N
# Name GRA
# 10
# United States Senator-:-Gray, Edward-:-WRI
# E-type G
# Race USS
# Party O
# Name GRA
# 10
# United States Senator-:-Knepper, Howard-:-WRI
# E-type G
# Race USS
# Party O
# Name KNE
# 10
# United States Senator-:-Misigoy, Dennis-:-LPF
# E-type G
# Race USS
# Party L
# Name MIS
# 10
# United States Senator-:-Nguyen, Tuan-:-NPA
# E-type G
# Race USS
# Party N
# Name NGU
# 10
# United States Senator-:-Quiles, Moses-:-WRI
# E-type G
# Race USS
# Party O
# Name QUI
# 10
# United States Senator-:-Rubio, Marco-:-REP
# E-type G
# Race USS
# Party R
# Name RUB
# 10
# DUPLICATE VALUES
# ('Abolishing the Constitution Revision Commission-:-No for Rejection-:-NOP', 'G22NNO')
# ('Abolishing the Constitution Revision Commission-:-Yes for Approval-:-NOP', 'G22NYES')
# ('Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-No for Rejection-:-NOP', 'G22NNO')
# ('Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-Yes for Approval-:-NOP', 'G22NYES')
# ('Limitation on Assessment of Real Property Used for Residential Purposes-:-No for Rejection-:-NOP', 'G22NNO')
# ('Limitation on Assessment of Real Property Used for Residential Purposes-:-Yes for Approval-:-NOP', 'G22NYES')
# ('Shall Justice Charles T. Canady be retained in Office?-:-No-:-NOP', 'G22SCJNNO')
# ('Shall Justice Charles T. Canady be retained in Office?-:-Yes-:-NOP', 'G22SCJNYES')
# ('Shall Justice Jamie Grosshans be retained in Office?-:-No-:-NOP', 'G22SCJNNO')
# ('Shall Justice Jamie Grosshans be retained in Office?-:-Yes-:-NOP', 'G22SCJNYES')
# ('Shall Justice John D. Couriel be retained in Office?-:-No-:-NOP', 'G22SCJNNO')
# ('Shall Justice John D. Couriel be retained in Office?-:-Yes-:-NOP', 'G22SCJNYES')
# ('Shall Justice Jorge Labarga be retained in Office?-:-No-:-NOP', 'G22SCJNNO')
# ('Shall Justice Jorge Labarga be retained in Office?-:-Yes-:-NOP', 'G22SCJNYES')
# ('Shall Justice Ricky Polston be retained in Office?-:-No-:-NOP', 'G22SCJNNO')
# ('Shall Justice Ricky Polston be retained in Office?-:-Yes-:-NOP', 'G22SCJNYES')

# %%
# Deal with edge cases
contest_name_change_dict_second['Abolishing the Constitution Revision Commission-:-No for Rejection-:-NOP']='G22A2NO'
contest_name_change_dict_second['Abolishing the Constitution Revision Commission-:-Yes for Approval-:-NOP']='G22A2YES'
contest_name_change_dict_second['Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-No for Rejection-:-NOP']= 'G22A3NO'
contest_name_change_dict_second['Additional Homestead Property Tax Exemption for Specified Critical Public Services Workforce-:-Yes for Approval-:-NOP']= 'G22A3YES'
contest_name_change_dict_second['Limitation on Assessment of Real Property Used for Residential Purposes-:-No for Rejection-:-NOP']= 'G22A1NO'
contest_name_change_dict_second['Limitation on Assessment of Real Property Used for Residential Purposes-:-Yes for Approval-:-NOP']= 'G22A1YES'
contest_name_change_dict_second['Shall Justice Charles T. Canady be retained in Office?-:-No-:-NOP']= 'G22SCJNCAN'
contest_name_change_dict_second['Shall Justice Charles T. Canady be retained in Office?-:-Yes-:-NOP']= 'G22SCJYCAN'
contest_name_change_dict_second['Shall Justice Jamie Grosshans be retained in Office?-:-No-:-NOP']= 'G22SCJNGRO'
contest_name_change_dict_second['Shall Justice Jamie Grosshans be retained in Office?-:-Yes-:-NOP']= 'G22SCJYGRO'
contest_name_change_dict_second['Shall Justice John D. Couriel be retained in Office?-:-No-:-NOP']= 'G22SCJNCOU'
contest_name_change_dict_second['Shall Justice John D. Couriel be retained in Office?-:-Yes-:-NOP']= 'G22SCJYCOU'
contest_name_change_dict_second['Shall Justice Jorge Labarga be retained in Office?-:-No-:-NOP']= 'G22SCJNLAB'
contest_name_change_dict_second['Shall Justice Jorge Labarga be retained in Office?-:-Yes-:-NOP']= 'G22SCJYLAB'
contest_name_change_dict_second['Shall Justice Ricky Polston be retained in Office?-:-No-:-NOP']= 'G22SCJNPOL'
contest_name_change_dict_second['Shall Justice Ricky Polston be retained in Office?-:-Yes-:-NOP']= 'G22SCJYPOL'
contest_name_change_dict_second['State Representative 46-:-De La Torre, Christian-:-REP'] = 'GSL046RDEL'

# %%
pivoted_alt.rename(columns = contest_name_change_dict_second, inplace = True)
contest_name_change_dict_second_rev = {v:k for k,v in contest_name_change_dict_second.items()}

# %% [markdown]
# # Compare Statewide Totals

# %%
{i:contest_name_change_dict_second_rev[i] for i in list(pivoted_alt.columns) if i not in list(pivoted_2022.columns) and i !="CountyName"}
# Out:
# {'GSL015OSTE': 'State Representative 15-:-Steckloff, Jerry-:-WRI',
#  'GSL016OHAR': 'State Representative 16-:-Hartley, Richard-:-WRI',
#  'GSL016OMOO': 'State Representative 16-:-Moore, Harley-:-WRI',
#  'GSL003OMAD': 'State Representative 3-:-Maddox, Sandra-:-WRI',
#  'GSL030OBAK': 'State Representative 30-:-Baker, Vic-:-WRI',
#  'GSU33OVAL': 'State Senator 33-:-Valenta, Robert-:-WRI',
#  'GSU05OCOO': 'State Senator 5-:-Cooper, Patrick-:-WRI',
#  'GCON12OSMI': 'United States Representative 12-:-Smith, Charles-:-WRI',
#  'GCON13OCUR': 'United States Representative 13-:-Curnow, Jacob-:-WRI',
#  'GCON13OYOU': 'United States Representative 13-:-Young, Dwight-:-WRI',
#  'GCON16OHAR': 'United States Representative 16-:-Hartman, Ralph-:-WRI',
#  'GCON18OSER': 'United States Representative 18-:-Serratore, Leonard-:-WRI',
#  'GCON19OPOS': 'United States Representative 19-:-Post, Patrick-:-WRI',
#  'GCON28OSCH': 'United States Representative 28-:-Schaffer, Jeremiah-:-WRI',
#  'GCON04OKON': 'United States Representative 4-:-Koniz, Gary-:-WRI',
#  'GCON07OPOM': 'United States Representative 7-:-Pompey, Cardon-:-WRI',
#  'G22USSOEKP': 'United States Senator-:-Ekpete, Uloma-:-WRI',
#  'G22USSOGRA': 'United States Senator-:-Gray, Edward-:-WRI',
#  'G22USSOKNE': 'United States Senator-:-Knepper, Howard-:-WRI',
#  'G22USSOQUI': 'United States Senator-:-Quiles, Moses-:-WRI'}

# %%
ignore_list = ['UNIQUE_ID',
 'County Code (Three-character abbreviation)',
 'County Name','COUNTYFP','pct_std', 'County Code (Three-character abbreviation)', 'County Name',
       'Unique Precinct Identifier', 'Precinct Polling Location']

# %%
{i:contest_name_change_dict_rev[i] for i in list(pivoted_2022.columns) if i not in list(pivoted_alt.columns) and i not in ignore_list}
# Out:
# {'G22CFOOWRI': 'Chief Financial Officer-:-WriteinVotes-:-PARTY:WRI',
#  'G22GOVOWRI': 'Governor and Lieutenant Governor-:-WriteinVotes-:-PARTY:WRI',
#  'GCON12OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 12',
#  'GCON13OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 13',
#  'GCON16OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 16',
#  'GCON18OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 18',
#  'GCON19OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 19',
#  'GCON28OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 28',
#  'GCON04OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 4',
#  'GCON07OWRI': 'Representative in Congress-:-WriteinVotes-:-PARTY:WRI-:- District 7',
#  'GSL015OWRI': 'State Representative-:-WriteinVotes-:-PARTY:WRI-:- District 15',
#  'GSL016OWRI': 'State Representative-:-WriteinVotes-:-PARTY:WRI-:- District 16',
#  'GSL003OWRI': 'State Representative-:-WriteinVotes-:-PARTY:WRI-:- District 3',
#  'GSL030OWRI': 'State Representative-:-WriteinVotes-:-PARTY:WRI-:- District 30',
#  'GSU33OWRI': 'State Senator-:-WriteinVotes-:-PARTY:WRI-:- District 33',
#  'GSU05OWRI': 'State Senator-:-WriteinVotes-:-PARTY:WRI-:- District 5',
#  'G22USSOWRI': 'United States Senator-:-WriteinVotes-:-PARTY:WRI'}

# %%
# Define a list of columns that appear in both dataframes
shared_cols = [i for i in list(pivoted_2022.columns) if i in list(pivoted_alt.columns)]

# %%
unshared_cols = [i for i in list(pivoted_2022.columns) if i not in list(pivoted_alt.columns)]

# %%
pdv.statewide_totals_check(pivoted_2022, "Precinct-Level", pivoted_alt, "County-Level", shared_cols)
# Out:
# ***Statewide Totals Check***
# G22A1NO has a difference of -1.0 votes
# 	Precinct-Level: 2997124 votes
# 	County-Level: 2997125.0 votes
# G22A1YES has a difference of -1.0 votes
# 	Precinct-Level: 4015948 votes
# 	County-Level: 4015949.0 votes
# G22A2NO is equal 	 both dataframes 3206717
# G22A2YES has a difference of -1.0 votes
# 	Precinct-Level: 3744872 votes
# 	County-Level: 3744873.0 votes
# G22A3NO has a difference of 1.0 votes
# 	Precinct-Level: 2968687 votes
# 	County-Level: 2968686.0 votes
# G22A3YES has a difference of -4.0 votes
# 	Precinct-Level: 4215538 votes
# 	County-Level: 4215542.0 votes
# G22ATGDAYA has a difference of 1.0 votes
# 	Precinct-Level: 3025944 votes
# 	County-Level: 3025943.0 votes
# G22ATGRMOO is equal 	 both dataframes 4651279
# G22CFODHAT is equal 	 both dataframes 3085697
# G22CFORPAT is equal 	 both dataframes 4528811
# G22COADBLE is equal 	 both dataframes 3095786
# G22COARSIM has a difference of -1.0 votes
# 	Precinct-Level: 4510643 votes
# 	County-Level: 4510644.0 votes
# G22GOVDCRI is equal 	 both dataframes 3106313
# G22GOVRDES has a difference of -1.0 votes
# 	Precinct-Level: 4614209 votes
# 	County-Level: 4614210.0 votes
# G22GOVNGIM is equal 	 both dataframes 31577
# G22GOVLROO is equal 	 both dataframes 19299
# GCON04RBEA is equal 	 both dataframes 165696
# GCON02DLAW is equal 	 both dataframes 121153
# GCON15DCOH is equal 	 both dataframes 102835
# GCON17DKAL is equal 	 both dataframes 123798
# GCON13RLUN is equal 	 both dataframes 181487
# GCON27DTAD is equal 	 both dataframes 101404
# GCON08RPOS is equal 	 both dataframes 222128
# GCON21RMAS is equal 	 both dataframes 208614
# GCON19RDON is equal 	 both dataframes 213035
# GCON10RWIM is equal 	 both dataframes 78844
# GCON25RSPA is equal 	 both dataframes 105239
# GCON28RGIM is equal 	 both dataframes 134457
# GCON26DOLI is equal 	 both dataframes 58868
# GCON23NSCO is equal 	 both dataframes 3079
# GCON19DBAN is equal 	 both dataframes 100226
# GCON21DBAL is equal 	 both dataframes 119891
# GCON07RMIL has a difference of -1.0 votes
# 	Precinct-Level: 177965 votes
# 	County-Level: 177966.0 votes
# GCON22RFRA is equal 	 both dataframes 122194
# GCON11RWEB is equal 	 both dataframes 205995
# GCON03DHAW is equal 	 both dataframes 103382
# GCON09DSOT is equal 	 both dataframes 108541
# GCON25DSCH is equal 	 both dataframes 129113
# GCON20RCLA is equal 	 both dataframes 52151
# GCON13DLYN is equal 	 both dataframes 153876
# GCON13LCRA is equal 	 both dataframes 6163
# GCON24DWIL is equal 	 both dataframes 133442
# GCON17RSTE is equal 	 both dataframes 222483
# GCON12RBIL is equal 	 both dataframes 226601
# GCON14RJUD is equal 	 both dataframes 113427
# GCON16DSCH is equal 	 both dataframes 115575
# GCON23DMOS is equal 	 both dataframes 143951
# GCON10NHOL is equal 	 both dataframes 2001
# GCON24RNAV is equal 	 both dataframes 52449
# GCON08DTER is equal 	 both dataframes 120080
# GCON23RBUD is equal 	 both dataframes 130681
# GCON06LHAN is equal 	 both dataframes 74207
# GCON07DGRE is equal 	 both dataframes 126079
# GCON03RCAM is equal 	 both dataframes 178101
# GCON14DCAS is equal 	 both dataframes 149737
# GCON18NHAY is equal 	 both dataframes 56647
# GCON11NPOR is equal 	 both dataframes 4967
# GCON12DWAL is equal 	 both dataframes 95390
# GCON04DHOL is equal 	 both dataframes 108402
# GCON15RLEE is equal 	 both dataframes 145219
# GCON03NBRO is equal 	 both dataframes 3410
# GCON22DFRA is equal 	 both dataframes 150010
# GCON26RDIA is equal 	 both dataframes 143240
# GCON23NNAP is equal 	 both dataframes 1338
# GCON27RSAL is equal 	 both dataframes 136038
# GCON01RGAE is equal 	 both dataframes 197349
# GCON10DFRO is equal 	 both dataframes 117955
# GCON06RWAL is equal 	 both dataframes 226548
# GCON02RDUN is equal 	 both dataframes 180236
# GCON01DJON is equal 	 both dataframes 93467
# GCON28DASE is equal 	 both dataframes 76665
# GCON18RFRA is equal 	 both dataframes 167429
# GCON09RMOO is equal 	 both dataframes 93827
# GCON11DMUN is equal 	 both dataframes 115647
# GCON20DCHE is equal 	 both dataframes 136215
# GCON17NMUR is equal 	 both dataframes 2225
# GCON10NJAI is equal 	 both dataframes 1110
# GCON16RBUC is equal 	 both dataframes 189762
# G22SCJNCAN has a difference of -3.0 votes
# 	Precinct-Level: 2455872 votes
# 	County-Level: 2455875.0 votes
# G22SCJYCAN has a difference of 1.0 votes
# 	Precinct-Level: 4358438 votes
# 	County-Level: 4358437.0 votes
# G22SCJNGRO has a difference of -12.0 votes
# 	Precinct-Level: 2439930 votes
# 	County-Level: 2439942.0 votes
# G22SCJYGRO has a difference of -2.0 votes
# 	Precinct-Level: 4306133 votes
# 	County-Level: 4306135.0 votes
# G22SCJNCOU has a difference of -3.0 votes
# 	Precinct-Level: 2457702 votes
# 	County-Level: 2457705.0 votes
# G22SCJYCOU has a difference of -4.0 votes
# 	Precinct-Level: 4305010 votes
# 	County-Level: 4305014.0 votes
# G22SCJNLAB has a difference of -4.0 votes
# 	Precinct-Level: 2535030 votes
# 	County-Level: 2535034.0 votes
# G22SCJYLAB has a difference of 2.0 votes
# 	Precinct-Level: 4197874 votes
# 	County-Level: 4197872.0 votes
# G22SCJNPOL is equal 	 both dataframes 2486947
# G22SCJYPOL has a difference of -1.0 votes
# 	Precinct-Level: 4240077 votes
# 	County-Level: 4240078.0 votes
# GSL114DBEN is equal 	 both dataframes 25724
# GSL080RBOT is equal 	 both dataframes 63708
# GSL120DGEN is equal 	 both dataframes 20662
# GSL019DMOR is equal 	 both dataframes 31578
# GSL113DD'A is equal 	 both dataframes 20234
# GSL002RAND is equal 	 both dataframes 44459
# GSL115RGAR is equal 	 both dataframes 40393
# GSL045DBRA is equal 	 both dataframes 31160
# GSL069DLEA is equal 	 both dataframes 26824
# GSL091DTHO is equal 	 both dataframes 36361
# GSL013DNIX is equal 	 both dataframes 34059
# GSL042DESK is equal 	 both dataframes 43103
# GSL047DNIE is equal 	 both dataframes 22947
# GSL033DYAN is equal 	 both dataframes 30289
# GSL052DMAR is equal 	 both dataframes 29090
# GSL060RHEN is equal 	 both dataframes 32683
# GSL025NHEL is equal 	 both dataframes 23969
# GSL058DFEN is equal 	 both dataframes 29629
# GSL059RJAC is equal 	 both dataframes 42812
# GSL042RJAC is equal 	 both dataframes 33014
# GSL022DPET is equal 	 both dataframes 32609
# GSL054DSTA is equal 	 both dataframes 24472
# GSL041DANT is equal 	 both dataframes 20207
# GSL037DSMI is equal 	 both dataframes 25652
# GSL045RAME is equal 	 both dataframes 35595
# GSL002DTAY is equal 	 both dataframes 25440
# GSL055CHAC is equal 	 both dataframes 16857
# GSL030RTRA is equal 	 both dataframes 61612
# GSL100RLAM is equal 	 both dataframes 42656
# GSL046RDEL is equal 	 both dataframes 13393
# GSL115DDAV is equal 	 both dataframes 28696
# GSL043RWRI is equal 	 both dataframes 16427
# GSL022RCLE is equal 	 both dataframes 41662
# GSL011DJON is equal 	 both dataframes 18392
# GSL008RBEN is equal 	 both dataframes 14870
# GSL085DTUC is equal 	 both dataframes 28677
# GSL096DDAL is equal 	 both dataframes 33626
# GSL084RTRA is equal 	 both dataframes 40829
# GSL069RALV is equal 	 both dataframes 35123
# GSL089RZAP is equal 	 both dataframes 15782
# GSL089DSIL is equal 	 both dataframes 17395
# GSL038RSMI is equal 	 both dataframes 34309
# GSL066DTIL is equal 	 both dataframes 30027
# GSL059DDOU is equal 	 both dataframes 28507
# GSL015RBLA is equal 	 both dataframes 63594
# GSL036DPOU is equal 	 both dataframes 28162
# GSL114RCAB is equal 	 both dataframes 33282
# GSL073DREI is equal 	 both dataframes 40271
# GSL092RHER is equal 	 both dataframes 37179
# GSL039RBAN is equal 	 both dataframes 35785
# GSL070DSAL is equal 	 both dataframes 28523
# GSL077DENG is equal 	 both dataframes 15388
# GSL106RBAS has a difference of 2.0 votes
# 	Precinct-Level: 26416 votes
# 	County-Level: 26414.0 votes
# GSL067DDRI is equal 	 both dataframes 25504
# GSL073RMCF is equal 	 both dataframes 51795
# GSL084DBLA is equal 	 both dataframes 25779
# GSL001DMAT is equal 	 both dataframes 19087
# GSL035RHAW is equal 	 both dataframes 32858
# GSL119DGON is equal 	 both dataframes 19700
# GSL008DFRA is equal 	 both dataframes 37452
# GSL103RNAV is equal 	 both dataframes 29566
# GSL101RSIL is equal 	 both dataframes 21507
# GSL101DCAS is equal 	 both dataframes 24980
# GSL021RMER is equal 	 both dataframes 18252
# GSL078DSAP is equal 	 both dataframes 23401
# GSL046NRIV is equal 	 both dataframes 1026
# GSL120RMOO is equal 	 both dataframes 31788
# GSL061DWAR is equal 	 both dataframes 36222
# GSL053RHOL is equal 	 both dataframes 50650
# GSL065DMCD is equal 	 both dataframes 33766
# GSL096RHAG is equal 	 both dataframes 21360
# GSL078RPER is equal 	 both dataframes 39416
# GSL062RBRO is equal 	 both dataframes 14839
# GSL088DEDM is equal 	 both dataframes 26045
# GSL017RBAK is equal 	 both dataframes 37989
# GSL003RRUD is equal 	 both dataframes 60263
# GSL043DLOP is equal 	 both dataframes 22146
# GSL028DNAV is equal 	 both dataframes 26709
# GSL086RSNY is equal 	 both dataframes 56838
# GSL052RTEM is equal 	 both dataframes 78601
# GSL118DFAR is equal 	 both dataframes 18187
# GSL106DLEO has a difference of 2.0 votes
# 	Precinct-Level: 26176 votes
# 	County-Level: 26174.0 votes
# GSL090DCAS is equal 	 both dataframes 34526
# GSL119RPOR is equal 	 both dataframes 35574
# GSL118RFER is equal 	 both dataframes 39344
# GSL065RGON is equal 	 both dataframes 39045
# GSL034DGRE is equal 	 both dataframes 27485
# GSL093DWAL is equal 	 both dataframes 33827
# GSL090RFEI is equal 	 both dataframes 28366
# GSL053DLAU is equal 	 both dataframes 21636
# GSL026RTRU is equal 	 both dataframes 48210
# GSL092DSKI is equal 	 both dataframes 50343
# GSL055RSTE is equal 	 both dataframes 58130
# GSL058RBER is equal 	 both dataframes 45048
# GSL016RMIC is equal 	 both dataframes 52145
# GSL046DARR is equal 	 both dataframes 20146
# GSL013NMAS is equal 	 both dataframes 14035
# GSL040DBRA is equal 	 both dataframes 27920
# GSL068RMCC is equal 	 both dataframes 40512
# GSL061RCHA is equal 	 both dataframes 46034
# GSL026DKER is equal 	 both dataframes 23001
# GSL100DGON is equal 	 both dataframes 32003
# GSL060DCRO is equal 	 both dataframes 38707
# GSL067RBON is equal 	 both dataframes 21707
# GSL068DWRI is equal 	 both dataframes 18831
# GSL105DWOO is equal 	 both dataframes 29745
# GSL064RCRU is equal 	 both dataframes 19930
# GSL017DAND is equal 	 both dataframes 24303
# GSL062DRAY is equal 	 both dataframes 34040
# GSL001RSAL is equal 	 both dataframes 43026
# GSL070RBEL is equal 	 both dataframes 48403
# GSL087RCAR is equal 	 both dataframes 44657
# GSL080DSCH is equal 	 both dataframes 26185
# GSL040RROB is equal 	 both dataframes 15040
# GSL019RREN is equal 	 both dataframes 56200
# GSL047RSTA is equal 	 both dataframes 23825
# GSL091RGOS is equal 	 both dataframes 38984
# GSL036RPLA has a difference of 1.0 votes
# 	Precinct-Level: 33935 votes
# 	County-Level: 33934.0 votes
# GSL033RFIN is equal 	 both dataframes 38130
# GSL054RMAG is equal 	 both dataframes 41753
# GSL086DDEN is equal 	 both dataframes 26166
# GSL029DKAR is equal 	 both dataframes 25008
# GSL094RROT is equal 	 both dataframes 41220
# GSL035DBAG is equal 	 both dataframes 26447
# GSL034RBRA is equal 	 both dataframes 58545
# GSL072DDAM is equal 	 both dataframes 27881
# GSL103DBAR is equal 	 both dataframes 34945
# GSL041GHAR is equal 	 both dataframes 4601
# GSL088RSTE is equal 	 both dataframes 10552
# GSL054NOTW is equal 	 both dataframes 1539
# GSL011RGAR is equal 	 both dataframes 51146
# GSL038DHEN has a difference of -1.0 votes
# 	Precinct-Level: 31289 votes
# 	County-Level: 31290.0 votes
# GSL093RBAN is equal 	 both dataframes 32963
# GSL087DOST is equal 	 both dataframes 30662
# GSL064DVAL is equal 	 both dataframes 22745
# GSL037RPLA is equal 	 both dataframes 27720
# GSL025RYAR is equal 	 both dataframes 46542
# GSL094DDAV is equal 	 both dataframes 28062
# GSL077RESP is equal 	 both dataframes 31774
# GSL039DHUG is equal 	 both dataframes 28538
# GSL085ROVE is equal 	 both dataframes 44581
# GSL028RLEE is equal 	 both dataframes 43349
# GSL072RGRE is equal 	 both dataframes 55933
# GSL066RKOS is equal 	 both dataframes 45305
# GSL113RLOP is equal 	 both dataframes 21059
# GSL105RPAR is equal 	 both dataframes 13673
# GSL029RBAR is equal 	 both dataframes 36758
# GSL021DHAY is equal 	 both dataframes 27615
# GSU38RCAL is equal 	 both dataframes 93741
# GSU21DLIO is equal 	 both dataframes 80928
# GSU08DWIL is equal 	 both dataframes 78085
# GSU27RALB is equal 	 both dataframes 141045
# GSU05RKUM is equal 	 both dataframes 64028
# GSU11RING is equal 	 both dataframes 192167
# GSU24DPOW is equal 	 both dataframes 76693
# GSU11GMOO is equal 	 both dataframes 64119
# GSU02DZON is equal 	 both dataframes 43498
# GSU01DNIC is equal 	 both dataframes 58724
# GSU16RPAY is equal 	 both dataframes 52927
# GSU27DPRO is equal 	 both dataframes 56940
# GSU04RYAR is equal 	 both dataframes 149177
# GSU12RBUR is equal 	 both dataframes 102441
# GSU03RSIM is equal 	 both dataframes 113477
# GSU23RBUR is equal 	 both dataframes 123217
# GSU16DROU is equal 	 both dataframes 93839
# GSU13RBAX is equal 	 both dataframes 133755
# GSU01RBRO is equal 	 both dataframes 145155
# GSU21RHOO is equal 	 both dataframes 148673
# GSU24RANK is equal 	 both dataframes 60958
# GSU18DORT is equal 	 both dataframes 97760
# GSU36RGAR is equal 	 both dataframes 75773
# GSU38DPER is equal 	 both dataframes 78625
# GSU14DCRU is equal 	 both dataframes 87213
# GSU10RBRO has a difference of -1.0 votes
# 	Precinct-Level: 114021 votes
# 	County-Level: 114022.0 votes
# GSU14RCOL is equal 	 both dataframes 104776
# GSU02RTRU is equal 	 both dataframes 159041
# GSU33RMAR is equal 	 both dataframes 149922
# GSU10DGOF has a difference of -1.0 votes
# 	Precinct-Level: 95390 votes
# 	County-Level: 95391.0 votes
# GSU09RPER is equal 	 both dataframes 135568
# GSU17DSTE is equal 	 both dataframes 85689
# GSU03DAUS is equal 	 both dataframes 100696
# GSU26DBER is equal 	 both dataframes 122532
# GSU23DHAR is equal 	 both dataframes 71786
# GSU18RDIC is equal 	 both dataframes 128983
# GSU25RVIV is equal 	 both dataframes 63288
# GSU36DPAC is equal 	 both dataframes 52600
# GSU09DLON is equal 	 both dataframes 71276
# GSU04DSMI is equal 	 both dataframes 71472
# GSU13DDUK is equal 	 both dataframes 81472
# GSU26RBYE is equal 	 both dataframes 101072
# GSU17RDIX is equal 	 both dataframes 67170
# GSU30DPOL is equal 	 both dataframes 92119
# GSU08RWRI is equal 	 both dataframes 133012
# GSU05DDAV is equal 	 both dataframes 86784
# GSU12DDOK is equal 	 both dataframes 59734
# GSU25DTOR is equal 	 both dataframes 70120
# GSU30RREI is equal 	 both dataframes 74067
# G22USSLMIS is equal 	 both dataframes 32177
# G22USSRRUB has a difference of -1.0 votes
# 	Precinct-Level: 4474846 votes
# 	County-Level: 4474847.0 votes
# G22USSNGRA is equal 	 both dataframes 31816
# G22USSNNGU is equal 	 both dataframes 17385
# G22USSDDEM is equal 	 both dataframes 3201522
#
# ['G22A1NO', 'G22A1YES', 'G22A2YES', 'G22A3NO', 'G22A3YES', 'G22ATGDAYA', 'G22COARSIM', 'G22GOVRDES', 'GCON07RMIL', 'G22SCJNCAN', 'G22SCJYCAN', 'G22SCJNGRO', 'G22SCJYGRO', 'G22SCJNCOU', 'G22SCJYCOU', 'G22SCJNLAB', 'G22SCJYLAB', 'G22SCJYPOL', 'GSL106RBAS', 'GSL106DLEO', 'GSL036RPLA', 'GSL038DHEN', 'GSU10RBRO', 'GSU10DGOF', 'G22USSRRUB']

# %%
# Minor renaming for the county-level check
pivoted_alt.rename(columns = {"CountyName":"County Name"}, inplace = True)

# %%
pdv.county_totals_check(pivoted_2022, "Precinct-Level", pivoted_alt, "County-Level", shared_cols, "County Name", method = "county")
# Out:
# ***Countywide Totals Check***
#
# Miami-Dade contains differences in these races:
# 	GSL106RBAS has a difference of 2.0 vote(s)
# 		Precinct-Level: 26416 vote(s)
# 		County-Level: 26414.0 vote(s)
# 	GSL106DLEO has a difference of 2.0 vote(s)
# 		Precinct-Level: 26176 vote(s)
# 		County-Level: 26174.0 vote(s)
# /Users/peterhorton/Documents/RDH/pber_collection/FL/2022/pdv_functions.py:65: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   holder_1 = partner_df.groupby(county_col).sum()
# Seminole contains differences in these races:
# 	G22A1NO has a difference of -1.0 vote(s)
# 		Precinct-Level: 79274 vote(s)
# 		County-Level: 79275.0 vote(s)
# 	G22A1YES has a difference of -1.0 vote(s)
# 		Precinct-Level: 86117 vote(s)
# 		County-Level: 86118.0 vote(s)
# 	G22A2YES has a difference of -1.0 vote(s)
# 		Precinct-Level: 80874 vote(s)
# 		County-Level: 80875.0 vote(s)
# 	G22A3NO has a difference of 1.0 vote(s)
# 		Precinct-Level: 65155 vote(s)
# 		County-Level: 65154.0 vote(s)
# 	G22A3YES has a difference of -4.0 vote(s)
# 		Precinct-Level: 104623 vote(s)
# 		County-Level: 104627.0 vote(s)
# 	G22ATGDAYA has a difference of 1.0 vote(s)
# 		Precinct-Level: 76193 vote(s)
# 		County-Level: 76192.0 vote(s)
# 	G22COARSIM has a difference of -1.0 vote(s)
# 		Precinct-Level: 99282 vote(s)
# 		County-Level: 99283.0 vote(s)
# 	G22GOVRDES has a difference of -1.0 vote(s)
# 		Precinct-Level: 102190 vote(s)
# 		County-Level: 102191.0 vote(s)
# 	GCON07RMIL has a difference of -1.0 vote(s)
# 		Precinct-Level: 98275 vote(s)
# 		County-Level: 98276.0 vote(s)
# 	G22SCJNCAN has a difference of -3.0 vote(s)
# 		Precinct-Level: 65303 vote(s)
# 		County-Level: 65306.0 vote(s)
# 	G22SCJYCAN has a difference of 1.0 vote(s)
# 		Precinct-Level: 90424 vote(s)
# 		County-Level: 90423.0 vote(s)
# 	G22SCJNGRO has a difference of -12.0 vote(s)
# 		Precinct-Level: 64898 vote(s)
# 		County-Level: 64910.0 vote(s)
# 	G22SCJYGRO has a difference of -2.0 vote(s)
# 		Precinct-Level: 90373 vote(s)
# 		County-Level: 90375.0 vote(s)
# 	G22SCJNCOU has a difference of -3.0 vote(s)
# 		Precinct-Level: 64969 vote(s)
# 		County-Level: 64972.0 vote(s)
# 	G22SCJYCOU has a difference of -4.0 vote(s)
# 		Precinct-Level: 90182 vote(s)
# 		County-Level: 90186.0 vote(s)
# 	G22SCJNLAB has a difference of -4.0 vote(s)
# 		Precinct-Level: 54975 vote(s)
# 		County-Level: 54979.0 vote(s)
# 	G22SCJYLAB has a difference of 2.0 vote(s)
# 		Precinct-Level: 100079 vote(s)
# 		County-Level: 100077.0 vote(s)
# 	G22SCJYPOL has a difference of -1.0 vote(s)
# 		Precinct-Level: 88078 vote(s)
# 		County-Level: 88079.0 vote(s)
# 	GSL036RPLA has a difference of 1.0 vote(s)
# 		Precinct-Level: 33935 vote(s)
# 		County-Level: 33934.0 vote(s)
# 	GSL038DHEN has a difference of -1.0 vote(s)
# 		Precinct-Level: 31289 vote(s)
# 		County-Level: 31290.0 vote(s)
# 	GSU10RBRO has a difference of -1.0 vote(s)
# 		Precinct-Level: 100416 vote(s)
# 		County-Level: 100417.0 vote(s)
# 	GSU10DGOF has a difference of -1.0 vote(s)
# 		Precinct-Level: 79970 vote(s)
# 		County-Level: 79971.0 vote(s)
# 	G22USSRRUB has a difference of -1.0 vote(s)
# 		Precinct-Level: 97760 vote(s)
# 		County-Level: 97761.0 vote(s)
#
# ['Miami-Dade', 'Seminole']
# Counties that match:
#
# ['Alachua', 'Baker', 'Bay', 'Bradford', 'Brevard', 'Broward', 'Calhoun', 'Charlotte', 'Citrus', 'Clay', 'Collier', 'Columbia', 'Desoto', 'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gadsden', 'Gilchrist', 'Glades', 'Gulf', 'Hamilton', 'Hardee', 'Hendry', 'Hernando', 'Highlands', 'Hillsborough', 'Holmes', 'Indian River', 'Jackson', 'Jefferson', 'Lafayette', 'Lake', 'Lee', 'Leon', 'Levy', 'Liberty', 'Madison', 'Manatee', 'Marion', 'Martin', 'Monroe', 'Nassau', 'Okaloosa', 'Okeechobee', 'Orange', 'Osceola', 'Palm Beach', 'Pasco', 'Pinellas', 'Polk', 'Putnam', 'Santa Rosa', 'Sarasota', 'St. Johns', 'St. Lucie', 'Sumter', 'Suwannee', 'Taylor', 'Union', 'Volusia', 'Wakulla', 'Walton', 'Washington']

# %% [markdown]
# # See If We Can Deduce the OWRI candidates
#
# The county-level data source did not have a catch-all "Other/Write-In" category for these votes, but it did have votes for particular candidates in these races. This is an attempt to see whether these votes are equal. It turns out they are not

# %%
check_write_ins = []

pivoted_alt["G22USSOWRI"] = pivoted_alt['G22USSOEKP'] + pivoted_alt['G22USSOGRA'] + pivoted_alt['G22USSOKNE'] + pivoted_alt['G22USSOQUI']
pivoted_alt['GSL016OWRI'] = pivoted_alt['GSL016OHAR'] + pivoted_alt['GSL016OMOO']

for name in ['GSL015OSTE',
 'GSL003OMAD',
 'GSL030OBAK',
 'GSU33OVAL',
 'GSU05OCOO',
 'GCON12OSMI',
 'GCON13OCUR',
 'GCON13OYOU',
 'GCON16OHAR',
 'GCON18OSER',
 'GCON19OPOS',
 'GCON28OSCH',
 'GCON04OKON',
 'GCON07OPOM']:
    check_write_ins.append(name[:-4]+"OWRI")
    pivoted_alt[name[:-4]+"OWRI"] = pivoted_alt[name]

# %%
pdv.statewide_totals_check(pivoted_2022, "Precinct-Level", pivoted_alt, "County-Level", check_write_ins)
# Out:
# ***Statewide Totals Check***
# GSL015OWRI has a difference of 4019.0 votes
# 	Precinct-Level: 4752 votes
# 	County-Level: 733.0 votes
# GSL003OWRI has a difference of 1970.0 votes
# 	Precinct-Level: 2173 votes
# 	County-Level: 203.0 votes
# GSL030OWRI has a difference of 3466.0 votes
# 	Precinct-Level: 3591 votes
# 	County-Level: 125.0 votes
# GSU33OWRI has a difference of 5548.0 votes
# 	Precinct-Level: 7241 votes
# 	County-Level: 1693.0 votes
# GSU05OWRI has a difference of 450.0 votes
# 	Precinct-Level: 450 votes
# 	County-Level: 0.0 votes
# GCON12OWRI has a difference of 437.0 votes
# 	Precinct-Level: 441 votes
# 	County-Level: 4.0 votes
# GCON13OWRI has a difference of 320.0 votes
# 	Precinct-Level: 337 votes
# 	County-Level: 17.0 votes
# GCON13OWRI has a difference of 320.0 votes
# 	Precinct-Level: 337 votes
# 	County-Level: 17.0 votes
# GCON16OWRI has a difference of 337.0 votes
# 	Precinct-Level: 358 votes
# 	County-Level: 21.0 votes
# GCON18OWRI has a difference of 1152.0 votes
# 	Precinct-Level: 1310 votes
# 	County-Level: 158.0 votes
# GCON19OWRI has a difference of 226.0 votes
# 	Precinct-Level: 239 votes
# 	County-Level: 13.0 votes
# GCON28OWRI has a difference of 313.0 votes
# 	Precinct-Level: 341 votes
# 	County-Level: 28.0 votes
# GCON04OWRI has a difference of 329.0 votes
# 	Precinct-Level: 334 votes
# 	County-Level: 5.0 votes
# GCON07OWRI has a difference of 302.0 votes
# 	Precinct-Level: 312 votes
# 	County-Level: 10.0 votes
#
# ['GSL015OWRI', 'GSL003OWRI', 'GSL030OWRI', 'GSU33OWRI', 'GSU05OWRI', 'GCON12OWRI', 'GCON13OWRI', 'GCON16OWRI', 'GCON18OWRI', 'GCON19OWRI', 'GCON28OWRI', 'GCON04OWRI', 'GCON07OWRI']

# %%
pdv.county_totals_check(pivoted_2022, "Precinct-Level", pivoted_alt, "County-Level", check_write_ins, "County Name", method = "county")
# Out:
# ***Countywide Totals Check***
#
# Brevard contains differences in these races:
# 	GSL030OWRI has a difference of 1090.0 vote(s)
# 		Precinct-Level: 1206 vote(s)
# 		County-Level: 116.0 vote(s)
# Citrus contains differences in these races:
# 	GCON12OWRI has a difference of 69.0 vote(s)
# 		Precinct-Level: 70 vote(s)
# 		County-Level: 1.0 vote(s)
# Clay contains differences in these races:
# 	GCON04OWRI has a difference of 97.0 vote(s)
# 		Precinct-Level: 101 vote(s)
# 		County-Level: 4.0 vote(s)
# Collier contains differences in these races:
# 	GCON18OWRI has a difference of 5.0 vote(s)
# 		Precinct-Level: 5 vote(s)
# 		County-Level: 0.0 vote(s)
# 	GCON19OWRI has a difference of 68.0 vote(s)
# 		Precinct-Level: 73 vote(s)
# 		County-Level: 5.0 vote(s)
# Miami-Dade contains differences in these races:
# 	GCON28OWRI has a difference of 266.0 vote(s)
# 		Precinct-Level: 288 vote(s)
# 		County-Level: 22.0 vote(s)
# Desoto contains differences in these races:
# 	GCON18OWRI has a difference of 18.0 vote(s)
# 		Precinct-Level: 21 vote(s)
# 		County-Level: 3.0 vote(s)
# Duval contains differences in these races:
# 	GSL015OWRI has a difference of 2598.0 vote(s)
# 		Precinct-Level: 2794 vote(s)
# 		County-Level: 196.0 vote(s)
# 	GSU05OWRI has a difference of 450.0 vote(s)
# 		Precinct-Level: 450 vote(s)
# 		County-Level: 0.0 vote(s)
# 	GCON04OWRI has a difference of 169.0 vote(s)
# 		Precinct-Level: 169 vote(s)
# 		County-Level: 0.0 vote(s)
# Glades contains differences in these races:
# 	GCON18OWRI has a difference of 11.0 vote(s)
# 		Precinct-Level: 11 vote(s)
# 		County-Level: 0.0 vote(s)
# Hardee contains differences in these races:
# 	GCON18OWRI has a difference of 12.0 vote(s)
# 		Precinct-Level: 12 vote(s)
# 		County-Level: 0.0 vote(s)
# Hendry contains differences in these races:
# 	GCON18OWRI has a difference of 38.0 vote(s)
# 		Precinct-Level: 38 vote(s)
# 		County-Level: 0.0 vote(s)
# Hernando contains differences in these races:
# 	GCON12OWRI has a difference of 74.0 vote(s)
# 		Precinct-Level: 74 vote(s)
# 		County-Level: 0.0 vote(s)
# Highlands contains differences in these races:
# 	GCON18OWRI has a difference of 109.0 vote(s)
# 		Precinct-Level: 136 vote(s)
# 		County-Level: 27.0 vote(s)
# Hillsborough contains differences in these races:
# 	GCON16OWRI has a difference of 154.0 vote(s)
# 		Precinct-Level: 160 vote(s)
# 		County-Level: 6.0 vote(s)
# Lee contains differences in these races:
# 	GSU33OWRI has a difference of 5548.0 vote(s)
# 		Precinct-Level: 7241 vote(s)
# 		County-Level: 1693.0 vote(s)
# 	GCON19OWRI has a difference of 158.0 vote(s)
# 		Precinct-Level: 166 vote(s)
# 		County-Level: 8.0 vote(s)
# Manatee contains differences in these races:
# 	GCON16OWRI has a difference of 183.0 vote(s)
# 		Precinct-Level: 198 vote(s)
# 		County-Level: 15.0 vote(s)
# Monroe contains differences in these races:
# 	GCON28OWRI has a difference of 47.0 vote(s)
# 		Precinct-Level: 53 vote(s)
# 		County-Level: 6.0 vote(s)
# Nassau contains differences in these races:
# 	GSL015OWRI has a difference of 1421.0 vote(s)
# 		Precinct-Level: 1958 vote(s)
# 		County-Level: 537.0 vote(s)
# 	GCON04OWRI has a difference of 63.0 vote(s)
# 		Precinct-Level: 64 vote(s)
# 		County-Level: 1.0 vote(s)
# Okaloosa contains differences in these races:
# 	GSL003OWRI has a difference of 269.0 vote(s)
# 		Precinct-Level: 293 vote(s)
# 		County-Level: 24.0 vote(s)
# Okeechobee contains differences in these races:
# 	GCON18OWRI has a difference of 22.0 vote(s)
# 		Precinct-Level: 30 vote(s)
# 		County-Level: 8.0 vote(s)
# Pasco contains differences in these races:
# 	GCON12OWRI has a difference of 294.0 vote(s)
# 		Precinct-Level: 297 vote(s)
# 		County-Level: 3.0 vote(s)
# Pinellas contains differences in these races:
# 	GCON13OWRI has a difference of 320.0 vote(s)
# 		Precinct-Level: 337 vote(s)
# 		County-Level: 17.0 vote(s)
# 	GCON13OWRI has a difference of 320.0 vote(s)
# 		Precinct-Level: 337 vote(s)
# 		County-Level: 17.0 vote(s)
# Polk contains differences in these races:
# 	GCON18OWRI has a difference of 937.0 vote(s)
# 		Precinct-Level: 1057 vote(s)
# 		County-Level: 120.0 vote(s)
# Santa Rosa contains differences in these races:
# 	GSL003OWRI has a difference of 1701.0 vote(s)
# 		Precinct-Level: 1880 vote(s)
# 		County-Level: 179.0 vote(s)
# Seminole contains differences in these races:
# 	GCON07OWRI has a difference of 181.0 vote(s)
# 		Precinct-Level: 191 vote(s)
# 		County-Level: 10.0 vote(s)
# Volusia contains differences in these races:
# 	GSL030OWRI has a difference of 2376.0 vote(s)
# 		Precinct-Level: 2385 vote(s)
# 		County-Level: 9.0 vote(s)
# 	GCON07OWRI has a difference of 121.0 vote(s)
# 		Precinct-Level: 121 vote(s)
# 		County-Level: 0.0 vote(s)
#
# ['Brevard', 'Citrus', 'Clay', 'Collier', 'Desoto', 'Duval', 'Glades', 'Hardee', 'Hendry', 'Hernando', 'Highlands', 'Hillsborough', 'Lee', 'Manatee', 'Miami-Dade', 'Monroe', 'Nassau', 'Okaloosa', 'Okeechobee', 'Pasco', 'Pinellas', 'Polk', 'Santa Rosa', 'Seminole', 'Volusia']
# Counties that match:
#
# ['Alachua', 'Baker', 'Bay', 'Bradford', 'Broward', 'Calhoun', 'Charlotte', 'Columbia', 'Dixie', 'Escambia', 'Flagler', 'Franklin', 'Gadsden', 'Gilchrist', 'Gulf', 'Hamilton', 'Holmes', 'Indian River', 'Jackson', 'Jefferson', 'Lafayette', 'Lake', 'Leon', 'Levy', 'Liberty', 'Madison', 'Marion', 'Martin', 'Orange', 'Osceola', 'Palm Beach', 'Putnam', 'Sarasota', 'St. Johns', 'St. Lucie', 'Sumter', 'Suwannee', 'Taylor', 'Union', 'Wakulla', 'Walton', 'Washington']
# /Users/peterhorton/Documents/RDH/pber_collection/FL/2022/pdv_functions.py:65: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   holder_1 = partner_df.groupby(county_col).sum()

# %% [markdown]
# # Finalize File Order and Export

# %%
pivoted_2022.rename(columns = {'Unique Precinct Identifier':'PREC_ID', 
                               'County Name':'CNTY_NAME',
                              'County Code (Three-character abbreviation)':'CNTY_CODE',
                              'Precinct Polling Location':'POLL_LOC'}, inplace = True)

# %%
pivoted_2022 = pivoted_2022[['UNIQUE_ID', 'COUNTYFP', 'CNTY_CODE', 'CNTY_NAME', 'PREC_ID',
       'POLL_LOC']+list(sorted_contest_name_change_dict.values())]

# %%
pivoted_2022["UNIQUE_ID"] = np.where(pivoted_2022["UNIQUE_ID"]=="WAS-0001", pivoted_2022["UNIQUE_ID"]+"-"+pivoted_2022["POLL_LOC"],pivoted_2022["UNIQUE_ID"])

# %%
pivoted_2022.loc[pivoted_2022["POLL_LOC"]=="nan","POLL_LOC"] = "No Location Provided"

# %%
if not os.path.exists("./fl_2022_gen_prec/"):
    os.mkdir("./fl_2022_gen_prec/")

pivoted_2022.to_csv("./fl_2022_gen_prec/fl_2022_gen_prec.csv", index = False)
